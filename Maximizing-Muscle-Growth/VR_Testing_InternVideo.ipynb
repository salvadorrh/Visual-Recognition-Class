# %% [markdown]
# #  Analyzing Qualcom dataset
#
# This is a very big dataset including more than a thousand of labeled classes.

# %%
import json
from collections import Counter
import re

# Load annotations
with open("fine_grained_labels.json", "r") as f:
    data = json.load(f) # Analyzing dataset

# %% [markdown]
# ## Get top labels

# %%
# Flatten all labels
all_labels = [label for item in data for label in item["labels"]]

# Count occurrences
label_counts = Counter(all_labels)

# Print top 30 most common classes
for label, count in label_counts.most_common(100):
    print(f"{label}: {count}")
# Out:
# fire hydrant - head straight: 3377
# fire hydrant - knee on ground: 3343
# fire hydrant - arms shoulder width: 3043
# squats - shoulder-width: 2794
# side plank - elbow below shoulder: 2639
# fire hydrant - no obvious issue: 2161
# fire hydrant (standing) - head straight: 2148
# raised leg circles (clockwise) - clockwise: 2006
# squats - no obvious issue: 1839
# downward dog - heels off the floor: 1804
# squat kick - speed=0.40 rps: 1794
# side plank - both knees on floor: 1643
# squats - 90 degrees: 1641
# fire hydrant (standing) - shin not parallel: 1539
# pushups (on knees) - wide: 1396
# raised leg circles (clockwise) - 70 degres: 1365
# fire hydrant (standing) - torso too high: 1339
# quad stretch (right) - getting into position: 1274
# pushups (on knees) - 90 degrees: 1265
# puddle jump - normal width: 1264
# alternating forward lunges - no obvious issue: 1263
# air jump rope - no obvious issue: 1261
# toe touch - legs straight: 1209
# alternating forward lunges - normal speed: 1207
# quick feet - shoulder-width: 1194
# squat kick - not lifting knees: 1166
# air jump rope - no wrist circles: 1142
# fire hydrant (standing) - torso 90 degrees: 1141
# standing kick (alternate legs) - arms extended: 1124
# jumping lunges - speed=0.80 rps: 1071
# spider man pushup - rom=2: 1050
# puddle jump - not bending front leg: 1043
# alternating forward lunges - normal width: 1036
# puddle jump - speed=0.75 rps: 1031
# jumping lunges - medium steps: 1027
# pushups - wide: 1003
# squat jump - no obvious issue: 1002
# spider man pushup - rom=3: 1000
# yoga pushup - rom=4: 998
# pushups (on knees) - elevated hips: 975
# plank taps - legs apart: 963
# spider man pushup - rom=5: 961
# buttkickers - bringing knees forward: 955
# yoga pushup - rom=2: 955
# fire hydrant (standing) - no obvious issue: 952
# pushups - deep: 931
# side plank - low hips: 910
# yoga pushup - rom=3: 881
# squats - shallow: 873
# air jump rope - side to side: 858
# burpee (no pushup) - high hips: 853
# spider man pushup - rom=1: 827
# pushups (on knees) - shoulder-width: 819
# alternating v ups - rom=3: 817
# quadruped thoracic spine rotation (left) - average: 817
# bunny hops - looking down: 813
# reverse crunches - 90 degrees: 808
# jumping lunges - leaning forward: 796
# shoulder gators - no obvious issue: 794
# yoga pushup - rom=1: 788
# reverse crunches - over 90 degrees: 785
# squats - over 90 degrees: 778
# spider man pushup - rom=4: 777
# burpee - stepping feet back: 759
# puddle jump - shallow: 755
# the hundred (table-top position) - head up: 735
# jumping jacks - arms_rom=4.0: 731
# quad stretch (left) - getting into position: 721
# alternating v ups - rom=5: 713
# dead bugs - rom=1: 706
# alternating v ups - rom=1: 702
# floor touches - rounded back: 702
# alternating v ups - rom=2: 694
# jumping jacks - legs_rom=3.0: 689
# squats - knees over toes: 685
# burpee - no obvious issue: 666
# squats - narrow: 665
# the hundred (table-top position) - legs 90 degrees: 664
# falling over - average: 662
# yoga pushup - rom=5: 659
# squats - back not straight: 656
# standing oblique crunches - speed=0.60 rps: 648
# bunny hops - looking at the camera: 647
# yawning (covering mouth with hand): 645
# glute hamstring walkout - rom=1: 645
# quick feet - leaning forward: 631
# elbow plank - head down: 629
# high knees march - sloppy arms: 628
# fire hydrant (standing) - straight leg: 625
# good morning - rounded back: 620
# running in place - average: 617
# pushups - very wide: 613
# the hundred (extended legs) - head up: 612
# wrist twists (running in-place) - wrists up but not moving: 611
# wrist twists - not moving hands: 609
# running in place - faster: 609
# quad stretch (right) - average: 608
# wrist twists - barely moving hands: 607
# reverse crunches - below 90 degrees: 604
# glute hamstring walkout - rom=4: 601

# %%
# Print labels
print(len(label_counts))

counter = 0
for label, count in label_counts.items():
  if count > 100:
    print('Label: ', label, ' Count: ', count)
    counter += 1

print(counter)
# Out:
# 1851
# Label:  elbow plank - stopping early  Count:  386
# Label:  elbow plank - arms facing inward and legs and hips on the floor  Count:  361
# Label:  elbow plank - arms too wide  Count:  411
# Label:  elbow plank - legs and hips on the floor  Count:  463
# Label:  elbow plank - shaking  Count:  328
# Label:  elbow plank - arms facing inward and on knees  Count:  359
# Label:  alternating v ups - no reach  Count:  300
# Label:  alternating v ups - rom=1  Count:  702
# Label:  criss-cross (feet on the floor) - feet on the floor  Count:  584
# Label:  alternating v ups - touching wrong foot  Count:  294
# Label:  alternating v ups - rom=5  Count:  713
# Label:  alternating v ups - butt off the ground  Count:  289
# Label:  alternating v ups - rom=4  Count:  553
# Label:  alternating v ups - stopping early  Count:  236
# Label:  alternating v ups - legs too low  Count:  288
# Label:  child pose - hands as far as possible  Count:  253
# Label:  criss-cross (feet on the floor) - torso_rotation=4  Count:  172
# Label:  the hundred (extended legs) - head up  Count:  612
# Label:  the hundred (extended legs) - legs straight  Count:  581
# Label:  criss-cross - knees close to chest  Count:  167
# Label:  criss-cross - speed=0.60 rps  Count:  168
# Label:  criss-cross - torso_rotation=3  Count:  314
# Label:  downward dog (frontal) - arms too narrow  Count:  231
# Label:  the hundred (feet on the floor) - head on floor  Count:  188
# Label:  alternating v ups - as fast as possible  Count:  298
# Label:  criss-cross - low knees  Count:  160
# Label:  criss-cross - torso_rotation=1  Count:  467
# Label:  the hundred (feet on the floor) - arms still  Count:  151
# Label:  the hundred (feet on the floor) - head up  Count:  319
# Label:  raised leg circles (clockwise) - 70 degres  Count:  1365
# Label:  raised leg circles (clockwise) - clockwise  Count:  2006
# Label:  criss-cross (feet on the floor) - torso_rotation=3  Count:  117
# Label:  criss-cross - sitting position  Count:  153
# Label:  child pose - knees as wide apart as possible  Count:  246
# Label:  alternating v ups - touching knee  Count:  280
# Label:  raised leg circles (counterclockwise) - counterclockwise  Count:  592
# Label:  criss-cross - head down  Count:  180
# Label:  downward dog - heels off the floor  Count:  1804
# Label:  downward dog - rounded back  Count:  588
# Label:  child pose - knees together  Count:  246
# Label:  alternating v ups - rom=3  Count:  817
# Label:  the hundred (table-top position) - head on floor  Count:  198
# Label:  the hundred (table-top position) - shins not parallel  Count:  382
# Label:  criss-cross (feet on the floor) - torso_rotation=5  Count:  172
# Label:  toe touch - hands at feet  Count:  549
# Label:  toe touch - legs straight  Count:  1209
# Label:  raised leg circles (counterclockwise) - 70 degres  Count:  355
# Label:  alternating v ups - touching knee and knee bent at 90 degrees  Count:  285
# Label:  criss-cross - only legs  Count:  224
# Label:  the hundred (feet on the floor) - moving arms as fast as possible  Count:  141
# Label:  raised leg circles (clockwise) - bent legs  Count:  354
# Label:  downward dog (frontal) - average  Count:  235
# Label:  child pose - high butt  Count:  252
# Label:  the hundred (table-top position) - head up  Count:  735
# Label:  the hundred (table-top position) - legs 90 degrees  Count:  664
# Label:  reverse crunches - not moving  Count:  218
# Label:  reverse crunches - 90 degrees  Count:  808
# Label:  reverse crunches - height=3  Count:  445
# Label:  the hundred (table-top position) - moving arms as fast as possible  Count:  174
# Label:  criss-cross - speed=0.80 rps  Count:  455
# Label:  criss-cross - torso_rotation=4  Count:  318
# Label:  raised leg circles (clockwise) - 45 degres  Count:  372
# Label:  reverse crunches - height=5  Count:  405
# Label:  reverse crunches - slow  Count:  211
# Label:  the hundred (table-top position) - arms still  Count:  179
# Label:  criss-cross - speed=1.00 rps  Count:  525
# Label:  criss-cross - torso_rotation=5  Count:  279
# Label:  roll down - hold  Count:  326
# Label:  criss-cross - torso_rotation=2  Count:  415
# Label:  alternating v ups - very low range of motion  Count:  287
# Label:  alternating v ups - rom=2  Count:  694
# Label:  criss-cross - not extending leg  Count:  198
# Label:  wide-legged forward fold - walking hands back  Count:  305
# Label:  alternating single leg glutes bridge - arms on the ground  Count:  228
# Label:  downward dog (frontal) - heels off the floor  Count:  237
# Label:  side plank - elbow below shoulder  Count:  2639
# Label:  side plank - both knees on floor  Count:  1643
# Label:  side plank - leaning forward  Count:  430
# Label:  the hundred (extended legs) - head on floor  Count:  209
# Label:  downward dog - heels on the floor  Count:  338
# Label:  downward dog - get into position from above  Count:  201
# Label:  reverse crunches - feet down  Count:  206
# Label:  alternating v ups - touching foot  Count:  274
# Label:  criss-cross - legs up not moving  Count:  174
# Label:  the hundred (table-top position) - knees to chest  Count:  206
# Label:  mountain-climbers - not bringing feet forward  Count:  524
# Label:  mountain-climbers - rounded back  Count:  557
# Label:  mountain-climbers - width=2  Count:  278
# Label:  the hundred (table-top position) - head up - too far back  Count:  150
# Label:  downward dog (frontal) - bent knees  Count:  233
# Label:  downward dog (frontal) - arms too wide  Count:  239
# Label:  wide-legged forward fold - hold  Count:  328
# Label:  alternating v ups - starting late  Count:  260
# Label:  bunny hops - single jump left to right  Count:  148
# Label:  raised leg circles (clockwise) - random  Count:  338
# Label:  raised leg circles (clockwise) - one leg  Count:  259
# Label:  reverse crunches - over 90 degrees  Count:  785
# Label:  raised leg circles - early stopping  Count:  314
# Label:  bunny hops - stepping  Count:  212
# Label:  bunny hops - looking down  Count:  813
# Label:  bunny hops - not visible  Count:  128
# Label:  bunny hops - narrow jumps  Count:  202
# Label:  wide-legged forward fold - walk out  Count:  314
# Label:  cross-legged hamstring stretch - left leg, hold  Count:  290
# Label:  alternating single leg glutes bridge - too fast  Count:  238
# Label:  the hundred (extended legs) - one leg down  Count:  200
# Label:  downward dog (frontal) - elbows bent  Count:  236
# Label:  downward dog (frontal) - hips too low  Count:  234
# Label:  reverse crunches - frontal  Count:  229
# Label:  kickback (right leg) - narrow space between arms  Count:  407
# Label:  the hundred (extended legs) - legs not straight  Count:  177
# Label:  raised leg circles (counterclockwise) - bent legs  Count:  110
# Label:  kickback (right leg) - as fast as possible  Count:  405
# Label:  side plank - elbow below head  Count:  418
# Label:  alternating single leg glutes bridge - keeping the hips up  Count:  225
# Label:  alternating v ups - touching shin  Count:  281
# Label:  halfway lift - head down, back not straight  Count:  225
# Label:  reverse crunches - below 90 degrees  Count:  604
# Label:  hip abductions (right leg) - left leg bent, toes facing up  Count:  201
# Label:  downward dog (frontal) - rounded back  Count:  235
# Label:  the hundred (extended legs) - arms still  Count:  194
# Label:  glutes bridge - knees out  Count:  264
# Label:  halfway lift - hands on shins  Count:  222
# Label:  cross-legged hamstring stretch - left leg front  Count:  264
# Label:  alternating single leg glutes bridge - knees out  Count:  222
# Label:  hip abductions (right leg) - as fast as possible  Count:  169
# Label:  upward salute - getting into position  Count:  212
# Label:  alternating v ups - butt off the ground (extreme)  Count:  297
# Label:  boxing bounce-steps  Count:  409
# Label:  bunny hops - speed=0.60 rps  Count:  314
# Label:  bunny hops - wide jumps  Count:  192
# Label:  mountain-climbers - sliding feet back  Count:  194
# Label:  mountain-climbers - speed=2.00 rps  Count:  201
# Label:  mountain-climbers - depth=1  Count:  205
# Label:  mountain-climbers - width=1  Count:  350
# Label:  elbow plank - head up  Count:  497
# Label:  buttkickers - bringing knees forward  Count:  955
# Label:  buttkickers - looking at feet  Count:  187
# Label:  buttkickers - speed=3.00 rps  Count:  460
# Label:  child pose - average  Count:  248
# Label:  glutes bridge - feet too wide  Count:  276
# Label:  reverse crunches - not raising hips  Count:  335
# Label:  glutes bridge - arms up in the air  Count:  283
# Label:  hip abductions (right leg) - not moving, leg down  Count:  218
# Label:  alternating single leg glutes bridge - heels off the ground  Count:  223
# Label:  hip abductions (right leg) - as high as possible  Count:  162
# Label:  kickback (right leg) - average  Count:  378
# Label:  alternating single leg glutes bridge - arms up in the air  Count:  238
# Label:  reverse crunches - extending legs  Count:  234
# Label:  snowboarders - not facing the webcam  Count:  334
# Label:  snowboarders - squat_depth=4  Count:  329
# Label:  snowboarders - rotation_angle=5  Count:  308
# Label:  bunny hops - in-place jump  Count:  195
# Label:  alternating single leg glutes bridge - head off the floor  Count:  187
# Label:  toe touch - hands on floor  Count:  404
# Label:  toe touch - wide feet  Count:  209
# Label:  bunny hops - speed=1.20 rps  Count:  268
# Label:  upward salute - arms and head leaning back, chest popping out  Count:  239
# Label:  side plank - balance on leg  Count:  180
# Label:  alternating single leg glutes bridge - too slow  Count:  212
# Label:  bunny hops - high hips  Count:  152
# Label:  elbow plank - head down  Count:  629
# Label:  glutes bridge - too fast  Count:  261
# Label:  side plank - arm in air  Count:  413
# Label:  side plank - no obvious issue  Count:  446
# Label:  elbow plank - high hips  Count:  562
# Label:  alternating v ups - shoulders on the ground  Count:  296
# Label:  forward stance forward bend (right leg forward) - hold  Count:  304
# Label:  bunny hops - legs not straight  Count:  208
# Label:  bunny hops - narrow space between arms  Count:  191
# Label:  standing hamstring stretch - wrap  Count:  321
# Label:  alternating single leg glutes bridge - starting late  Count:  212
# Label:  high plank - hips too high  Count:  244
# Label:  kickback (right leg) - back not straight  Count:  428
# Label:  criss-cross - speed=1.40 rps  Count:  127
# Label:  alternating single leg glutes bridge - not alternating  Count:  234
# Label:  mountain-climbers - speed=1.00 rps  Count:  207
# Label:  mountain-climbers - depth=2  Count:  229
# Label:  toe touch - hands at ankles  Count:  209
# Label:  alternating single leg glutes bridge - non-working leg bent  Count:  228
# Label:  toe touch - hands at knees  Count:  207
# Label:  jab (right leg front) - punching up  Count:  220
# Label:  elbow plank - butt sinking  Count:  501
# Label:  alternating single leg glutes bridge - shoulders off the ground  Count:  229
# Label:  raised leg circles (counterclockwise) - 45 degres  Count:  146
# Label:  hook left (right leg front) - static legs  Count:  292
# Label:  step feet together - average  Count:  284
# Label:  glute hamstring walkout - butt on the ground  Count:  220
# Label:  jab (right leg front) - punching down  Count:  209
# Label:  downward dog - get into position from the ground  Count:  229
# Label:  air jump rope - side to side  Count:  858
# Label:  air jump rope - no wrist circles  Count:  1142
# Label:  hip abductions (right leg) - upper body not straight  Count:  200
# Label:  glutes bridge - hips very low  Count:  270
# Label:  grabbing an off-screen towel  Count:  379
# Label:  neck warmup (with hands)  Count:  448
# Label:  cross (right leg front) - punching up  Count:  222
# Label:  mountain-climbers - single repetition  Count:  154
# Label:  glutes bridge - arms crossed  Count:  282
# Label:  child pose - getting into position  Count:  216
# Label:  thumb down (hold)  Count:  313
# Label:  forward stance forward bend (right leg forward) - up  Count:  263
# Label:  reverse crunches - fast  Count:  210
# Label:  warrior 1 (left) - leaning forward  Count:  171
# Label:  warrior 1 (left) - bent back knee  Count:  377
# Label:  bunny hops - speed=1.00 rps  Count:  331
# Label:  bunny hops - wide space between arms  Count:  207
# Label:  kickback (right leg) - wide space between arms  Count:  410
# Label:  halfway lift - getting into position  Count:  184
# Label:  side plank - low hips  Count:  910
# Label:  side plank - drooping head  Count:  421
# Label:  downward dog (frontal) - looking up  Count:  218
# Label:  cross + uppercut right (right leg front) - slow  Count:  215
# Label:  mountain-climbers - stopping early  Count:  188
# Label:  side plank - high hips  Count:  517
# Label:  downward dog (frontal) - not holding position  Count:  233
# Label:  dead bugs (legs only) - average  Count:  281
# Label:  dead bugs (legs only) - rom=2  Count:  585
# Label:  reverse crunches - head up  Count:  553
# Label:  cat-cow pose - cat posture, hands too far foward  Count:  253
# Label:  alternating v ups - too slow  Count:  289
# Label:  reverse crunches - height=4  Count:  417
# Label:  alternating single leg glutes bridge - knees in  Count:  223
# Label:  jab (right leg front) - elbow not moving  Count:  211
# Label:  cat-cow pose - cat posture, back as high as possible  Count:  248
# Label:  tree pose (left foot on the floor, right foot on knee joint) - average  Count:  177
# Label:  glute hamstring walkout - stepping in-place  Count:  232
# Label:  quad stretch (right) - average  Count:  608
# Label:  tree pose (left foot on the floor, right foot below knee joint) - no arm  Count:  154
# Label:  mountain-climbers - knees twisting inwards  Count:  374
# Label:  hip abductions (right leg) - toes facing up  Count:  183
# Label:  dead bugs (legs only) - opposite knee close to chest  Count:  284
# Label:  dead bugs (legs only) - rom=4  Count:  531
# Label:  mountain-climbers - no moving  Count:  176
# Label:  standing kick (alternate legs) - arms extended  Count:  1124
# Label:  wrist twists - not moving hands  Count:  609
# Label:  glutes bridge - too slow  Count:  257
# Label:  glutes bridge - heels off the ground  Count:  256
# Label:  catching your breath (hands behind head)  Count:  453
# Label:  elbow plank - shoulders shrugged up toward the ears  Count:  520
# Label:  tricep stretch (left arm) - fake stretch, other arm in position but not stretching  Count:  221
# Label:  downward dog - stopping early  Count:  223
# Label:  dead bugs (legs only) - foot touching the floor  Count:  282
# Label:  glutes bridge - hips slightly too low  Count:  266
# Label:  yawning (covering mouth with hand)  Count:  645
# Label:  hip abductions (right leg) - head on the floor  Count:  221
# Label:  quad stretch (right) - getting into position  Count:  1274
# Label:  bunny hops - speed=1.60 rps  Count:  155
# Label:  tricep stretch (left arm) - hold  Count:  226
# Label:  shoulder gators - not moving back  Count:  213
# Label:  toe touch - bent knees  Count:  382
# Label:  the hundred (table-top position) - head up - hunched  Count:  175
# Label:  reverse crunches - height=2  Count:  454
# Label:  downward dog - wide space legs  Count:  198
# Label:  glute hamstring walkout - starting late  Count:  214
# Label:  air jump rope - no obvious issue  Count:  1261
# Label:  air jump rope - speed=1.50 rps  Count:  309
# Label:  air jump rope - height=4  Count:  285
# Label:  downward dog - bent legs  Count:  570
# Label:  downward dog - head out  Count:  302
# Label:  halfway lift - hands on shins, bent knees  Count:  214
# Label:  warrior 1 (left) - front leg straight  Count:  272
# Label:  downward dog - bent arms  Count:  102
# Label:  boxing bounce steps (side to side) - not moving  Count:  205
# Label:  jab (right leg front) - static legs  Count:  228
# Label:  plie squat - feet out 45 degrees  Count:  280
# Label:  shoulder warmup  Count:  408
# Label:  hip abductions (right leg) - toes facing down  Count:  202
# Label:  wide-legged forward fold - inhale  Count:  297
# Label:  halfway lift - hands on knees  Count:  210
# Label:  glutes bridge - feet too narrow  Count:  262
# Label:  arm circles (forward) - not moving arms  Count:  204
# Label:  glute hamstring walkout - too slow  Count:  229
# Label:  glute hamstring walkout - rom=1  Count:  645
# Label:  opposite arm and leg lifts (on knees) - back not straight, arching up  Count:  286
# Label:  high plank - average  Count:  230
# Label:  high plank - moving feet  Count:  239
# Label:  tabletop position (frontal view) - hands too far foward  Count:  220
# Label:  alternating single leg glutes bridge - arms crossed  Count:  236
# Label:  glutes bridge - stopping early  Count:  263
# Label:  wrist twists (running in-place) - average  Count:  588
# Label:  arm circles (forward) - head down  Count:  197
# Label:  tree pose (left foot on the floor, right foot below knee joint) - getting into position  Count:  161
# Label:  warrior 2 (left) - arms only  Count:  136
# Label:  warrior 2 (left) - front leg straight  Count:  299
# Label:  tree pose (left foot on the floor, right foot below knee joint) - looking down  Count:  163
# Label:  warrior 2 (right) - arms only  Count:  223
# Label:  warrior 2 (right) - front leg straight  Count:  108
# Label:  pushups - 90 degrees  Count:  548
# Label:  pushups - wide  Count:  1003
# Label:  kickback - switching to the other leg  Count:  420
# Label:  bunny hops - looking at the camera  Count:  647
# Label:  warrior 1 (right) - arms only  Count:  248
# Label:  hip abductions (right leg) - average  Count:  171
# Label:  child pose - head  up  Count:  185
# Label:  reverse crunches - height=1  Count:  475
# Label:  thumb down (preparation and hold)  Count:  307
# Label:  jumping jacks - only arms  Count:  396
# Label:  cross (right leg front) - hips not rotating, hips not facing camera  Count:  220
# Label:  quadruped thoracic spine rotation (right) - not moving - down  Count:  235
# Label:  warrior 1 (left) - no obvious issue  Count:  315
# Label:  standing t - not bending torso at all  Count:  214
# Label:  quad stretch (right) - hold onto something  Count:  162
# Label:  quick feet - lifting feet too high  Count:  199
# Label:  quick feet - not leaning forward  Count:  456
# Label:  quick feet - shoulder-width  Count:  1194
# Label:  quick feet - speed=1.50 rps  Count:  265
# Label:  alternating single leg glutes bridge - hips very low  Count:  240
# Label:  elbow plank - average  Count:  525
# Label:  dead bugs - opposite knee close to chest  Count:  322
# Label:  dead bugs - rom=2  Count:  586
# Label:  glute hamstring walkout - rom=3  Count:  587
# Label:  opposite arm and leg lifts (on knees) - only legs  Count:  266
# Label:  tricep stretch (left arm) - other arm not above head, pushing elbow back  Count:  225
# Label:  plank taps (on knees) - not touching shoulders  Count:  158
# Label:  plank taps (on knees) - speed=0.85 rps  Count:  161
# Label:  pretending to towel off sweat (without using a towel)  Count:  383
# Label:  dead bugs (legs only) - moving arms  Count:  288
# Label:  high knees - angle=60.0 degrees  Count:  309
# Label:  hip abductions (right leg) - not moving, leg up  Count:  229
# Label:  kickback (right leg) - as high as possible  Count:  391
# Label:  glutes bridge - starting late  Count:  260
# Label:  opposite arm and leg lifts (on knees) - only arms  Count:  264
# Label:  fire hydrant - arms too wide  Count:  337
# Label:  fire hydrant - head straight  Count:  3377
# Label:  fire hydrant - knee on ground  Count:  3343
# Label:  fire hydrant - no obvious issue  Count:  2161
# Label:  upward salute - shoulders close to ears  Count:  220
# Label:  child pose - not leaning forward enough  Count:  234
# Label:  tricep stretch (left arm) - pulling elbow back as far as possible  Count:  213
# Label:  dead bugs - rom=4  Count:  567
# Label:  opposite arm and leg lifts (on knees) - not alternating  Count:  267
# Label:  dead bugs - moving same side  Count:  316
# Label:  cross + jab (right leg front) - low range of motion  Count:  223
# Label:  deltoid stretch (left arm) - bent elbow  Count:  190
# Label:  upward salute - shoulders away from the ears, hands facing forward  Count:  223
# Label:  quadruped thoracic spine rotation (left) - average  Count:  817
# Label:  criss-cross - speed=1.20 rps  Count:  165
# Label:  tree pose (left foot on the floor, right foot above knee joint) - average  Count:  173
# Label:  bunny hops - looking up and down (moving head)  Count:  484
# Label:  arm circles (forward) - arm lower than shoulder  Count:  195
# Label:  deltoid stretch (left arm) - pull elbow  Count:  167
# Label:  jab (right leg front) - not fully extending arm  Count:  210
# Label:  glute hamstring walkout - dropping hips too low  Count:  232
# Label:  glute hamstring walkout - rom=2  Count:  574
# Label:  kickback (right leg) - hands too far forward  Count:  403
# Label:  wide-legged forward bend - inhale and lengthen  Count:  293
# Label:  moving plank - starting late  Count:  251
# Label:  cat-cow pose - cat posture  Count:  245
# Label:  hip abductions (right leg) - left leg bent, toes facing down  Count:  197
# Label:  high plank - rounded shoulders  Count:  239
# Label:  buttkickers - speed=2.50 rps  Count:  475
# Label:  glutes bridge - head off the floor  Count:  212
# Label:  glute hamstring walkout - average  Count:  223
# Label:  hip abductions (right leg) - leg not straight  Count:  154
# Label:  standing t - too fast  Count:  219
# Label:  high plank - elbows bent  Count:  235
# Label:  bunny hops - early stopping  Count:  106
# Label:  cross + jab (right leg front) - lazy  Count:  226
# Label:  catching your breath (leaning on something)  Count:  449
# Label:  boxing bounce steps (side to side) - slow  Count:  201
# Label:  jab (right leg front) - as fast as possible  Count:  211
# Label:  dead bugs - starting late  Count:  276
# Label:  knee circles - large circles  Count:  200
# Label:  glutes bridge - arms on the ground  Count:  280
# Label:  jab (right leg front) - rear arm low  Count:  218
# Label:  warrior 2 (left) - no obvious issue  Count:  266
# Label:  yoga pushup - hips too low  Count:  270
# Label:  yoga pushup - rom=5  Count:  659
# Label:  burpee (no pushup) - sitting down  Count:  261
# Label:  burpee (no pushup) - not moving feet back  Count:  396
# Label:  burpee (no pushup) - as fast as possible  Count:  291
# Label:  downward dog - no obvious mistake  Count:  184
# Label:  arm circles (forward) - average  Count:  197
# Label:  glute hamstring walkout - feet too narrow  Count:  238
# Label:  neck rolls - alternate looking far left and far right  Count:  154
# Label:  quad stretch (left) - getting into position  Count:  721
# Label:  wrist twists (running in-place) - wrists up but not moving  Count:  611
# Label:  arm circles (forward) - fast  Count:  197
# Label:  glute hamstring walkout - rom=4  Count:  601
# Label:  glute hamstring walkout - foot flat on the ground  Count:  223
# Label:  fire hydrant - arms shoulder width  Count:  3043
# Label:  fire hydrant - too fast  Count:  278
# Label:  jumping jacks - legs_rom=1.0  Count:  238
# Label:  cross + hook right (right leg front) - as fast as possible  Count:  224
# Label:  jabs - slow  Count:  163
# Label:  arm crosses - average  Count:  336
# Label:  high knees - angle=75.0 degrees  Count:  131
# Label:  tree pose (left foot on the floor, right foot on knee joint) - getting into position  Count:  154
# Label:  hook left (right leg front) - average  Count:  279
# Label:  alternating single leg glutes bridge - hips slightly too low  Count:  222
# Label:  opposite arm and leg lifts (on knees) - low arm and leg  Count:  264
# Label:  high plank - knees bent  Count:  232
# Label:  pushups - elevated hips  Count:  235
# Label:  pushups - insufficient  Count:  211
# Label:  pushups - very wide  Count:  613
# Label:  uppercut left (right leg front) - punching up  Count:  209
# Label:  tree pose (left foot on the floor, right foot above knee joint) - no arm  Count:  167
# Label:  high knees - speed=3.00 rps  Count:  162
# Label:  high knees - angle=90.0 degrees  Count:  330
# Label:  dead bugs - moving opposite leg  Count:  312
# Label:  jabs - not alternating  Count:  172
# Label:  uppercut left (right leg front) - static legs  Count:  206
# Label:  wrist twists - average  Count:  582
# Label:  wrist twists (running in-place) - running as fast as possible  Count:  596
# Label:  pushups (on knees) - moving head  Count:  140
# Label:  pushups (on knees) - shallow  Count:  334
# Label:  pushups (on knees) - shoulder-width  Count:  819
# Label:  tree pose (left foot on the floor, right foot above knee joint) - looking down  Count:  172
# Label:  plank taps (on knees) - head down  Count:  178
# Label:  jumping jacks - not jumping  Count:  395
# Label:  garland pose - arms not between thighs  Count:  194
# Label:  high five (hold)  Count:  315
# Label:  glute hamstring walkout - stepping too big  Count:  217
# Label:  uppercut right (right leg front) - as fast as possible  Count:  222
# Label:  cross (right leg front) - as fast as possible  Count:  220
# Label:  keeping hands in pockets  Count:  408
# Label:  upward salute - legs together  Count:  225
# Label:  uppercut right (right leg front) - punching arm going too low  Count:  214
# Label:  cobra pose - looking far up  Count:  176
# Label:  plank taps - speed=0.95 rps  Count:  242
# Label:  plank taps - legs apart  Count:  963
# Label:  plank taps - no obvious issue  Count:  595
# Label:  knee circles - as fast as possible  Count:  200
# Label:  cobra pose - head down  Count:  191
# Label:  tree pose (left foot on the floor, right foot above knee joint) - getting into position  Count:  154
# Label:  grabbing a towel (towel visible from the start)  Count:  383
# Label:  boxing bounce steps (front to back) - feet facing sideways  Count:  193
# Label:  high kicks - average  Count:  350
# Label:  inchworm - hands too far from feet  Count:  247
# Label:  high knees - speed=2.50 rps  Count:  281
# Label:  shoulder gators - looking down  Count:  285
# Label:  shoulder gators - range_of_motion=2  Count:  320
# Label:  quadruped thoracic spine rotation (left) - not moving - up  Count:  167
# Label:  shoulder gators - range_of_motion=3  Count:  294
# Label:  hook left (right leg front) - hips not rotating, hips not facing camera  Count:  294
# Label:  warrior 2 (left) - low arm  Count:  295
# Label:  quick feet - shaking knees  Count:  271
# Label:  quad stretch (right) - hopping  Count:  153
# Label:  tricep stretch (left arm) - not using other arm  Count:  227
# Label:  air jump rope - height=3  Count:  479
# Label:  neck rolls - alternate tilting head up and down, too fast  Count:  131
# Label:  dead bugs - low back off the floor  Count:  316
# Label:  dead bugs - rom=1  Count:  706
# Label:  halfway lift - stopping early  Count:  194
# Label:  jabs - uppercut  Count:  167
# Label:  dead bugs (legs only) - start moving opposite leg too early  Count:  281
# Label:  thumb down (quick)  Count:  297
# Label:  dead bugs - too fast  Count:  322
# Label:  dead bugs - rom=3  Count:  558
# Label:  dead bugs - opposite knee too bent  Count:  307
# Label:  halfway lift - head up  Count:  192
# Label:  glute hamstring walkout - shoulders off the ground  Count:  183
# Label:  glute hamstring walkout - head off ground  Count:  200
# Label:  fire hydrant (standing) - head straight  Count:  2148
# Label:  fire hydrant (standing) - shin not parallel  Count:  1539
# Label:  fire hydrant (standing) - too fast  Count:  235
# Label:  fire hydrant (standing) - torso too high  Count:  1339
# Label:  fire hydrant (standing) - rom=4  Count:  402
# Label:  alternating forward lunges - hands behind head  Count:  297
# Label:  alternating forward lunges - no obvious issue  Count:  1263
# Label:  standing t - torso not low enough  Count:  222
# Label:  warrior 2 (left) - leaning forward  Count:  268
# Label:  glute hamstring walkout - feet too wide  Count:  225
# Label:  inchworm - not going far enough out  Count:  257
# Label:  arm circles (forward) - medium circles  Count:  193
# Label:  garland pose - feet below hips, butt as low as possible  Count:  192
# Label:  fire hydrant - arms too close  Count:  245
# Label:  inchworm - feet too narrow  Count:  252
# Label:  glutes bridge - knees in  Count:  258
# Label:  catching your breath (walking around)  Count:  377
# Label:  dead bugs (legs only) - too fast  Count:  291
# Label:  halfway lift - hands on shins, feet wide apart  Count:  214
# Label:  burpee - leaning too far forward  Count:  200
# Label:  wrist twists - barely moving hands  Count:  607
# Label:  criss-cross - elbow reaching knee  Count:  119
# Label:  squats - back not straight  Count:  656
# Label:  squats - shallow  Count:  873
# Label:  squats - shoulder-width  Count:  2794
# Label:  warrior 2 (left) - bent back knee  Count:  510
# Label:  buttkickers - not in place  Count:  287
# Label:  inchworm - arms too narrow  Count:  247
# Label:  burpee (no pushup) - no upright position  Count:  289
# Label:  yoga pushup - no pushup  Count:  301
# Label:  quadruped thoracic spine rotation (left) - as fast as possible  Count:  170
# Label:  pushups - side to side  Count:  370
# Label:  standing kick (alternate legs) - not visible  Count:  374
# Label:  running in place - faster  Count:  609
# Label:  scratching arm  Count:  399
# Label:  standing t - chin not tucked, looking at the screen  Count:  211
# Label:  standing kicks (right leg) - average  Count:  170
# Label:  hook right + cross (right leg front) - average  Count:  210
# Label:  catching your breath (hand on knees)  Count:  446
# Label:  knee circles - small circles  Count:  198
# Label:  high knees - not straight  Count:  326
# Label:  dead bugs - opposite knee too straight  Count:  330
# Label:  high plank - looking up  Count:  192
# Label:  tree pose (left foot on the floor, right foot below knee joint) - losing balance  Count:  158
# Label:  cross + uppercut right (right leg front) - low range of motion  Count:  220
# Label:  air jump rope - speed=1.75 rps  Count:  217
# Label:  kickback (right leg) - single repetition  Count:  386
# Label:  air jump rope - speed=2.00 rps  Count:  122
# Label:  tricep stretch (left arm) - pulling hand instead of elbow  Count:  218
# Label:  uppercut left (right leg front) - hips not rotating, hips facing camera  Count:  216
# Label:  knee circles - without hands  Count:  191
# Label:  mountain-climbers - knees outward  Count:  285
# Label:  reverse crunches - getting into position  Count:  208
# Label:  glute hamstring walkout - knees in  Count:  229
# Label:  cross + hook right (right leg front) - slow  Count:  231
# Label:  yoga pushup - rounded back  Count:  311
# Label:  yoga pushup - rom=2  Count:  955
# Label:  hook left (right leg front) - low range of motion  Count:  284
# Label:  glute hamstring walkout - on your toes  Count:  223
# Label:  glute hamstring walkout - knees out  Count:  222
# Label:  standing t - arms hanging down  Count:  230
# Label:  inchworm - average  Count:  253
# Label:  jumping jacks - arms_rom=2.0  Count:  317
# Label:  cross + uppercut right (right leg front) - as fast as possible  Count:  228
# Label:  high plank - moving arms  Count:  227
# Label:  knee circles - not moving  Count:  212
# Label:  opposite arm and leg lifts (on knees) - arm and leg as high as possible  Count:  260
# Label:  high knees - not in place  Count:  339
# Label:  cross (right leg front) - hips not rotating, hips facing camera  Count:  224
# Label:  grabbing a bottle (bottle visible from the start)  Count:  401
# Label:  opposite arm and leg lifts (on knees) - not moving  Count:  284
# Label:  quick feet - leaning forward  Count:  631
# Label:  quick feet - narrow  Count:  168
# Label:  quick feet - speed=2.00 rps  Count:  316
# Label:  quick feet - no obvious issue  Count:  584
# Label:  fire hydrant - kicking sideways  Count:  322
# Label:  plank taps - moving hips  Count:  214
# Label:  plank taps - speed=1.20 rps  Count:  155
# Label:  buttkickers - feet disappear behind knees  Count:  539
# Label:  squat jacks - average  Count:  542
# Label:  lunges (right leg out in front) - not moving  Count:  234
# Label:  plank taps - head down  Count:  192
# Label:  plank taps - speed=1.05 rps  Count:  140
# Label:  upward salute - shoulders away from the ears, hands facing each other  Count:  224
# Label:  opposite arm and leg lifts (on knees) - average  Count:  259
# Label:  squat kick - butt below knees  Count:  257
# Label:  squat kick - not lifting knees  Count:  1166
# Label:  squat kick - speed=0.40 rps  Count:  1794
# Label:  squat kick - squat_depth=5  Count:  462
# Label:  squat kick - kick_height=3  Count:  410
# Label:  hook right and hook left (right leg front) - slow  Count:  217
# Label:  standing t - stopping early  Count:  197
# Label:  high knees - arms down  Count:  192
# Label:  standing groin stretch - lean right  Count:  255
# Label:  air jump rope - height=5  Count:  329
# Label:  dead bugs - start moving opposite leg too early  Count:  326
# Label:  high knees - speed=2.00 rps  Count:  313
# Label:  open and drink from a bottle  Count:  422
# Label:  hook right (right leg front) - average  Count:  225
# Label:  glute hamstring walkout - rom=5  Count:  465
# Label:  arm circles (forward) - no circles, arms moving up and down  Count:  198
# Label:  standing knee-to-elbow (not bouncing) - elbows not touching  Count:  597
# Label:  standing knee-to-elbow (not bouncing) - not moving arms  Count:  269
# Label:  high knees - angle=45.0 degrees  Count:  253
# Label:  puddle jump - speed=1.00 rps  Count:  398
# Label:  puddle jump - in-place  Count:  108
# Label:  puddle jump - not bending front leg  Count:  1043
# Label:  tree pose (left foot on the floor, right foot above knee joint) - losing balance  Count:  165
# Label:  uppercut right + hook left (right leg front) - lazy  Count:  215
# Label:  dead bugs (legs only) - rom=5  Count:  571
# Label:  uppercut left + jab (right leg front) - low range of motion  Count:  219
# Label:  burpee - no upright position  Count:  202
# Label:  hook right (right leg front) - stopping after first rep  Count:  232
# Label:  arm circles (forward) - slow  Count:  201
# Label:  dead bugs (legs only) - rom=1  Count:  577
# Label:  arm circles (forward) - arm not straight  Count:  190
# Label:  cross (right leg front) - static legs  Count:  220
# Label:  quick feet - wide  Count:  241
# Label:  running in place - average  Count:  617
# Label:  jabs - feet flat, not moving hips  Count:  162
# Label:  glute hamstring walkout - too fast  Count:  227
# Label:  bunny hops - speed=2.00 rps  Count:  124
# Label:  squat kick - speed=0.20 rps  Count:  245
# Label:  squat kick - squat_depth=2  Count:  350
# Label:  shoulder gators - snappy  Count:  258
# Label:  shoulder gators - range_of_motion=5  Count:  229
# Label:  high knees - single repetition  Count:  331
# Label:  feet apart - average  Count:  286
# Label:  using towel to remove sweat  Count:  399
# Label:  arm circles (forward) - stopping early  Count:  178
# Label:  quadruped thoracic spine rotation (left) - slow  Count:  164
# Label:  yoga pushup - arms too wide  Count:  315
# Label:  yoga pushup - rom=4  Count:  998
# Label:  buttkickers - feet stay below knees  Count:  274
# Label:  neck rolls - tilting head left and right, too fast  Count:  163
# Label:  cross (right leg front) - average  Count:  222
# Label:  toe touch - stopping early  Count:  188
# Label:  lunges stance - left leg back  Count:  246
# Label:  cross (right leg front) - fast but low range of motion  Count:  213
# Label:  standing oblique crunches - no rotation  Count:  205
# Label:  opposite arm and leg lifts (on knees) - hands too far forward, not under shoulders  Count:  270
# Label:  hook left (right leg front) - punching down  Count:  276
# Label:  mountain-climbers - speed=2.50 rps  Count:  202
# Label:  mountain-climbers - depth=5  Count:  201
# Label:  mountain-climbers - width=5  Count:  348
# Label:  mountain-climbers - no obvious issue  Count:  144
# Label:  high knees - speed=1.00 rps  Count:  321
# Label:  air jump rope - not moving  Count:  206
# Label:  changing the webcam view while lying down - average  Count:  103
# Label:  fire hydrant (standing) - no obvious issue  Count:  952
# Label:  opposite arm and leg lifts (on knees) - knees not under hips  Count:  270
# Label:  dead bugs (legs only) - not fully extending legs  Count:  273
# Label:  dead bugs (legs only) - rom=3  Count:  571
# Label:  boxing bounce steps (front to back) - not moving  Count:  207
# Label:  shoulder gators - no obvious issue  Count:  794
# Label:  cross (right leg front) - stopping after first rep  Count:  221
# Label:  boxing bounce steps (front to back) - feet together  Count:  196
# Label:  standing t - arms too overhead  Count:  209
# Label:  cross + uppercut right (right leg front) - lazy  Count:  233
# Label:  glutes bridge - shoulders off the ground  Count:  282
# Label:  boxing bounce steps (front to back) - slow  Count:  192
# Label:  jabs - arms too low  Count:  163
# Label:  uppercut left (right leg front) - stopping after first rep  Count:  220
# Label:  pushups - waiting position  Count:  355
# Label:  air jump rope - speed=1.00 rps  Count:  261
# Label:  air jump rope - height=2  Count:  300
# Label:  snowboarders - rotation_angle=4  Count:  390
# Label:  cross + hook right (right leg front) - low range of motion  Count:  228
# Label:  squats - 90 degrees  Count:  1641
# Label:  squats - no obvious issue  Count:  1839
# Label:  plank taps - high hips  Count:  200
# Label:  wrist twists - as fast as possible  Count:  589
# Label:  standing kick (alternate legs) - moving slow  Count:  105
# Label:  jumping jacks - puppet dance  Count:  206
# Label:  fixing hair (short, one hand)  Count:  249
# Label:  child pose - stopping early  Count:  207
# Label:  deltoid stretch (left arm) - pull forearm  Count:  114
# Label:  hook left + jab (right leg front) - low range of motion  Count:  206
# Label:  tricep stretch (left arm) - getting into position  Count:  198
# Label:  inchworm - bending knees too much  Count:  248
# Label:  tuck jump - feet behind  Count:  253
# Label:  falling over - average  Count:  662
# Label:  jabs - on tip-toes, moving hips  Count:  153
# Label:  leg lifts - left leg  Count:  234
# Label:  jabs - only left arm  Count:  133
# Label:  fist bump (hold)  Count:  320
# Label:  stretching arms  Count:  418
# Label:  tree pose (left foot on the floor, right foot above knee joint) - knee facing forward  Count:  172
# Label:  opposite arm and leg lifts (on knees) - losing balance  Count:  268
# Label:  uppercut right + uppercut left (right leg front) - low range of motion  Count:  211
# Label:  quick feet - hunched back  Count:  513
# Label:  quick feet - speed=2.50 rps  Count:  329
# Label:  fire hydrant (standing) - head up  Count:  328
# Label:  fire hydrant (standing) - moving spine  Count:  211
# Label:  fire hydrant (standing) - rom=1  Count:  408
# Label:  wrist twists (running in-place) - walking  Count:  567
# Label:  boxing bounce steps (side to side) - average  Count:  207
# Label:  standing kick (alternate legs) - kicking high  Count:  518
# Label:  uppercut right + hook left (right leg front) - average  Count:  209
# Label:  uppercut left (right leg front) - as fast as possible  Count:  210
# Label:  quick feet - not visible  Count:  142
# Label:  moving plank - butt moving side-to-side  Count:  268
# Label:  moving plank - head down  Count:  219
# Label:  moving plank - speed=0.40 rps  Count:  242
# Label:  moving plank - legs together  Count:  437
# Label:  punch right (feet next to each other) - average  Count:  212
# Label:  low lunge pose (right leg back) - upper body leaning forward  Count:  183
# Label:  jab + uppercut left (right leg front) - slow  Count:  198
# Label:  uppercut left + jab (right leg front) - average  Count:  206
# Label:  jab (right leg front) - fast but low range of motion  Count:  213
# Label:  dead bugs - foot touching the floor  Count:  330
# Label:  dead bugs - rom=5  Count:  465
# Label:  cross + hook right (right leg front) - lazy  Count:  229
# Label:  garland pose - head down  Count:  218
# Label:  standing kick (alternate legs) - moving fast  Count:  150
# Label:  halfway lift - hands on thighs  Count:  194
# Label:  thumb up (hold)  Count:  306
# Label:  jabs - rolling hands  Count:  167
# Label:  jabs - as fast as possible  Count:  160
# Label:  high plank - hips too low  Count:  215
# Label:  high knees - speed=2.25 rps  Count:  103
# Label:  wide-legged forward fold - exhale and fold  Count:  274
# Label:  uppercut left (right leg front) - average  Count:  205
# Label:  uppercut left + uppercut right (right leg front) - average  Count:  210
# Label:  mountain-climbers - running feet  Count:  399
# Label:  mountain-climbers - width=4  Count:  279
# Label:  squats - narrow  Count:  665
# Label:  hook right (feet next to each other) - average  Count:  229
# Label:  standing kicks (right leg) - slow  Count:  170
# Label:  squat jump - butt below knees  Count:  458
# Label:  squat jump - speed=0.60 rps  Count:  542
# Label:  squat jump - jump_height=4  Count:  448
# Label:  tree pose (left foot on the floor, right foot below knee joint) - knee facing forward  Count:  180
# Label:  hook right (right leg front) - punching down  Count:  221
# Label:  uppercut left + uppercut right (right leg front) - slow  Count:  215
# Label:  squat jump - starting late  Count:  288
# Label:  high knees - not jumping  Count:  383
# Label:  dead bugs (legs only) - low back off the floor  Count:  288
# Label:  quad stretch (right) - knee forward  Count:  152
# Label:  squat kick - squat_depth=4  Count:  417
# Label:  squat kick - wide space between legs  Count:  170
# Label:  dead bugs (legs only) - moving opposite leg  Count:  279
# Label:  hook right and hook left (right leg front) - as fast as possible  Count:  219
# Label:  mountain-climbers - looking down  Count:  460
# Label:  high knees march - no issues  Count:  585
# Label:  high knees march - speed=1.30 rps  Count:  167
# Label:  high knees march - height=5  Count:  356
# Label:  squats - knees over toes  Count:  685
# Label:  squats - over 90 degrees  Count:  778
# Label:  inchworm - excessively short  Count:  260
# Label:  bending windmill stretch - average  Count:  383
# Label:  shrugging (long)  Count:  265
# Label:  upward salute - arms leaning back, chest popping out  Count:  218
# Label:  backwards windmills - average  Count:  329
# Label:  floor touches - insufficient reach  Count:  408
# Label:  warrior 2 (left) - starting  Count:  167
# Label:  neck rolls - random movements  Count:  153
# Label:  hook left (right leg front) - punching up  Count:  282
# Label:  scratching back of the head  Count:  401
# Label:  burpee (no pushup) - good form  Count:  232
# Label:  air jump rope - speed=1.25 rps  Count:  292
# Label:  drinking something from a bottle  Count:  457
# Label:  standing knee-to-elbow (not bouncing) - speed=0.75 rps  Count:  330
# Label:  jumping jacks - arms_rom=3.0  Count:  336
# Label:  uppercut left + hook right (right leg front) - low range of motion  Count:  221
# Label:  jumping jacks - speed=1.00 rps  Count:  253
# Label:  jumping jacks - arms_rom=4.0  Count:  731
# Label:  jumping jacks - legs_rom=2.0  Count:  409
# Label:  inchworm - not going far enough in  Count:  246
# Label:  jab + cross (right leg front) - average  Count:  195
# Label:  air jump rope - no jump  Count:  200
# Label:  air jump rope - height=1  Count:  373
# Label:  quick feet - looking down  Count:  176
# Label:  quick feet - speed=3.00 rps  Count:  251
# Label:  cross + hook right (right leg front) - average  Count:  241
# Label:  squat jump - speed=0.50 rps  Count:  456
# Label:  squat jump - squat_depth=3  Count:  452
# Label:  squat jump - jump_height=2  Count:  385
# Label:  squat jump - no obvious issue  Count:  1002
# Label:  uppercut right (right leg front) - rear arm low  Count:  210
# Label:  pushups - fast  Count:  206
# Label:  pushups - shallow  Count:  519
# Label:  pushups - shoulder-width  Count:  426
# Label:  jabs - not fully extending arms  Count:  177
# Label:  standing t - very low range of motion  Count:  227
# Label:  floor touches - opposite  Count:  178
# Label:  high plank - knees on floor  Count:  186
# Label:  neck warmup (without hands)  Count:  393
# Label:  garland pose - feet as wide apart as possible, horizontal arms  Count:  190
# Label:  opposite arm and leg lifts (on knees) - as fast as possible  Count:  256
# Label:  standing kicks (right leg) - hands on hips  Count:  183
# Label:  standing knee-to-elbow (bouncing) - no elbows down  Count:  234
# Label:  standing knee-to-elbow (bouncing) - not twisting body  Count:  451
# Label:  standing knee-to-elbow (bouncing) - speed=1.25 rps  Count:  291
# Label:  standing oblique crunches - head down  Count:  363
# Label:  standing oblique crunches - speed=0.60 rps  Count:  648
# Label:  spider man pushup - arms too wide  Count:  354
# Label:  spider man pushup - rom=2  Count:  1050
# Label:  yoga pushup - bent knees  Count:  311
# Label:  garland pose - feet below hips, horizontal arms  Count:  186
# Label:  jab (right leg front) - average  Count:  210
# Label:  arm circles (forward) - big circles  Count:  189
# Label:  uppercut right (right leg front) - punching down  Count:  209
# Label:  shoulder gators - too fast  Count:  404
# Label:  spider man - too fast  Count:  206
# Label:  spider man - rom=4  Count:  533
# Label:  uppercut left + hook right (right leg front) - as fast as possible  Count:  215
# Label:  standing knee-to-elbow (bouncing) - elbows not touching  Count:  425
# Label:  standing knee-to-elbow (bouncing) - not moving arms  Count:  167
# Label:  neck rolls - random movements, too fast  Count:  152
# Label:  dead bugs (legs only) - opposite knee too bent  Count:  283
# Label:  yoga pushup - shallow pushup  Count:  305
# Label:  yoga pushup - rom=1  Count:  788
# Label:  cross (right leg front) - not fully extending arm  Count:  223
# Label:  uppercut right + uppercut left (right leg front) - lazy  Count:  212
# Label:  spider man pushup - hips too high  Count:  362
# Label:  spider man pushup - rom=1  Count:  827
# Label:  deltoid stretch (left arm) - early stopping  Count:  156
# Label:  standing kicks (right leg) - hands behind head  Count:  191
# Label:  spider man - small rotation  Count:  177
# Label:  high knees march - looking down  Count:  187
# Label:  high knees march - speed=1.20 rps  Count:  348
# Label:  high knees march - height=3  Count:  313
# Label:  garland pose - high butt  Count:  192
# Label:  oblique twists - average  Count:  293
# Label:  fire hydrant - stopping early  Count:  237
# Label:  hook right (right leg front) - punching up  Count:  234
# Label:  fire hydrant - straight leg  Count:  263
# Label:  standing kick (alternate legs) - kneeing  Count:  422
# Label:  give up gesture  Count:  243
# Label:  cross (right leg front) - punching down  Count:  209
# Label:  dead bugs - not fully extending legs  Count:  317
# Label:  bunny hops - speed=0.80 rps  Count:  285
# Label:  alternating forward lunges - narrow  Count:  509
# Label:  alternating forward lunges - normal speed  Count:  1207
# Label:  alternating forward lunges - depth=1  Count:  390
# Label:  uppercut right (right leg front) - average  Count:  222
# Label:  dead bugs (legs only) - opposite knee too straight  Count:  293
# Label:  jump feet together - average  Count:  295
# Label:  burpee - as fast as possible  Count:  225
# Label:  jab + hook left (right leg front) - average  Count:  202
# Label:  standing hamstring stretch - roll up  Count:  290
# Label:  jab + hook left (right leg front) - slow  Count:  191
# Label:  hip circles - not moving  Count:  197
# Label:  front lunge kick (right leg) - not bending left knee  Count:  163
# Label:  air jump rope - heels only  Count:  225
# Label:  floor touches - feet not under knees  Count:  558
# Label:  floor touches - speed=0.70 rps  Count:  197
# Label:  floor touches - width=4  Count:  207
# Label:  knee circles - no circle, forward-backward movement only  Count:  203
# Label:  high knees march - arms only  Count:  242
# Label:  high knees march - sloppy arms  Count:  628
# Label:  spider man pushup - too fast  Count:  326
# Label:  standing t - torso parallel to the ground, thumbs pointed up  Count:  218
# Label:  nodding head to say yes (short)  Count:  245
# Label:  shoulder gators - not moving forward  Count:  284
# Label:  dead bugs (legs only) - starting late  Count:  244
# Label:  boxing bounce steps (side to side) - as fast as possible  Count:  207
# Label:  fire hydrant (standing) - torso 90 degrees  Count:  1141
# Label:  elbow plank - arms facing inward  Count:  472
# Label:  tree pose (left foot on the floor, right foot below knee joint) - average  Count:  173
# Label:  standing oblique crunches - arms together  Count:  193
# Label:  jumping lunges - losing balance  Count:  474
# Label:  jumping lunges - small steps  Count:  441
# Label:  jumping lunges - speed=1.00 rps  Count:  314
# Label:  jumping lunges - squat_depth=1  Count:  356
# Label:  cat-cow pose - cow posture  Count:  194
# ...
# Label:  hook right and uppercut left (right leg front) - slow  Count:  207
# Label:  snowboarders - rotation_angle=1  Count:  395
# Label:  spider man - back knee on the ground  Count:  177
# Label:  spider man - rom=1  Count:  502
# Label:  jab + cross (right leg front) - as fast as possible  Count:  186
# Label:  jab + uppercut left (right leg front) - low range of motion  Count:  197
# Label:  fire hydrant (standing) - losing balance  Count:  301
# Label:  jumping jacks - only legs  Count:  404
# Label:  uppercut left + uppercut right (right leg front) - as fast as possible  Count:  210
# Label:  tabletop position (frontal view) - hands under shoulders  Count:  210
# Label:  spider man pushup - shallow pushup  Count:  331
# Label:  standing ytw - thumbs pointed down  Count:  266
# Label:  quadruped thoracic spine rotation (right) - insufficient - high  Count:  105
# Label:  alternating lateral lunge - too fast  Count:  263
# Label:  alternating lateral lunge - rom=4  Count:  545
# Label:  snowboarders - stepping  Count:  189
# Label:  hook left + uppercut right (right leg front) - as fast as possible  Count:  212
# Label:  standing t - thumbs pointed sideway  Count:  215
# Label:  high knees march - speed=1.00 rps  Count:  300
# Label:  yoga pushup - average  Count:  306
# Label:  high knees march - moving wrong arm  Count:  237
# Label:  jab + uppercut left (right leg front) - lazy  Count:  195
# Label:  pushups (on knees) - very wide  Count:  413
# Label:  squats - hold  Count:  303
# Label:  snowboarders - squat_depth=2  Count:  312
# Label:  spider man pushup - average  Count:  313
# Label:  alternating lateral lunge - too narrow  Count:  250
# Label:  alternating lateral lunge - rom=2  Count:  519
# Label:  sitting down - average  Count:  166
# Label:  snowboarders - squat_depth=3  Count:  417
# Label:  buttkickers - stepping  Count:  269
# Label:  small kicks while waiting  Count:  397
# Label:  quad stretch (right) - quick drop  Count:  145
# Label:  squat punch - speed=0.40 rps  Count:  234
# Label:  jumping jacks - legs_rom=3.0  Count:  689
# Label:  hook left + hook right (right leg front) - as fast as possible  Count:  211
# Label:  spider man pushup - not bringing leg far enough  Count:  331
# Label:  cobra pose - lower, keeping shoulders away from the ears  Count:  134
# Label:  yawning (short)  Count:  265
# Label:  good morning - rounded back  Count:  620
# Label:  puddle jump - speed=0.50 rps  Count:  475
# Label:  standing kick (alternate legs) - hands on hips  Count:  309
# Label:  plank taps - not touching shoulders  Count:  163
# Label:  high plank - stopping early  Count:  173
# Label:  squats - plie  Count:  504
# Label:  squats - wide  Count:  404
# Label:  hip circles (counterclockwise) - large circles  Count:  130
# Label:  moving plank - speed=0.30 rps  Count:  249
# Label:  plank taps - whole body moving side to side  Count:  146
# Label:  quadruped thoracic spine rotation (right) - average  Count:  173
# Label:  squat punch - punches not on target  Count:  141
# Label:  squat punch - squat_depth=5  Count:  149
# Label:  quad stretch (right) - early stopping  Count:  148
# Label:  jab + uppercut left (right leg front) - average  Count:  193
# Label:  spider man - arms too wide, stepping too narrow  Count:  181
# Label:  alternating lateral lunge - stepping foot pointing away  Count:  250
# Label:  lunges (right leg out in front) - upper body leaning forward  Count:  210
# Label:  yoga pushup - too shallow downward dog  Count:  316
# Label:  high plank - starting late  Count:  214
# Label:  alternating lateral lunge - knee straight, toes out  Count:  243
# Label:  alternating lateral lunge - rom=3  Count:  409
# Label:  fire hydrant (standing) - too slow  Count:  147
# Label:  moving plank - high hips  Count:  234
# Label:  yawning (long)  Count:  259
# Label:  spider man pushup - hips too low  Count:  297
# Label:  puddle jump - back feet touching floor  Count:  315
# Label:  good morning - no issues  Count:  272
# Label:  squat kick - leaning forward  Count:  289
# Label:  front lunge kick (right leg) - average  Count:  530
# Label:  snowboarders - no squat  Count:  192
# Label:  quick feet - speed=3.50 rps  Count:  110
# Label:  squat kick - speed=0.60 rps  Count:  160
# Label:  fire hydrant (standing) - straight leg  Count:  625
# Label:  alternating forward lunges - not alternating  Count:  203
# Label:  tuck jump - insufficient  Count:  289
# Label:  spider man - arm not extended  Count:  179
# Label:  alternating lateral lunge - too shallow  Count:  261
# Label:  high knees march - speed=0.80 rps  Count:  290
# Label:  high knees march - height=4  Count:  356
# Label:  jab + hook left (right leg front) - low range of motion  Count:  200
# Label:  hook left + jab (right leg front) - slow  Count:  209
# Label:  buttkickers - speed=1.00 rps  Count:  149
# Label:  standing kicks (right leg) - as fast as possible  Count:  176
# Label:  buttkickers - early stopping  Count:  264
# Label:  standing ywt - wrong order  Count:  258
# Label:  cross-legged hamstring stretch - left leg front, fold down  Count:  260
# Label:  shrugging (short)  Count:  253
# Label:  lunges (right leg out in front) - hands on hips  Count:  227
# Label:  nodding head to say yes (long)  Count:  253
# Label:  picking up the camera  Count:  231
# Label:  fire hydrant (standing) - starting late  Count:  204
# Label:  burpee - high hips  Count:  204
# Label:  plank taps (on knees) - legs together  Count:  184
# Label:  standing ytw - too fast  Count:  255
# Label:  puddle jump - deep  Count:  259
# Label:  pushups - legs on the floor  Count:  221
# Label:  standing t - lower range of motion, arms too low  Count:  228
# Label:  front lunge kick (left leg) - shallow and low  Count:  130
# Label:  alternating forward lunges - not bending back leg  Count:  258
# Label:  good morning - insufficient  Count:  174
# Label:  hook left + uppercut right (right leg front) - slow  Count:  204
# Label:  hook left + hook right (right leg front) - slow  Count:  202
# Label:  warrior 1 (left) - starting  Count:  174
# Label:  uppercut left + jab (right leg front) - lazy  Count:  210
# Label:  cat-cow pose - tabletop to cat posture  Count:  206
# Label:  spider man - arms too wide, still stepping out  Count:  198
# Label:  toe touch - getting into position  Count:  192
# Label:  pushups - early stopping  Count:  304
# Label:  wide-legged forward fold - inhale up  Count:  274
# Label:  hook left (right leg front) - front arm low  Count:  270
# Label:  floor touches - stopping early  Count:  211
# Label:  fixing hair (long, both hands)  Count:  248
# Label:  standing ytw - torso parallel to the ground, thumbs pointed up  Count:  252
# Label:  jab + uppercut left (right leg front) - as fast as possible  Count:  196
# Label:  lunges (right leg out in front) - not bending back leg  Count:  232
# Label:  puddle jump - shallow  Count:  755
# Label:  puddle jump - wide  Count:  263
# Label:  roll down - back up  Count:  255
# Label:  fire hydrant (standing) - stopping early  Count:  206
# Label:  burpee (no pushup) - leaning too far forward  Count:  263
# Label:  inchworm - getting into position  Count:  229
# Label:  standing up - average  Count:  157
# Label:  burpee - on knees  Count:  227
# Label:  good morning - too low  Count:  173
# Label:  fire hydrant - starting late  Count:  230
# Label:  squat punch - squat_depth=4  Count:  155
# Label:  alternating forward lunges - wide  Count:  430
# Label:  squat punch - starting late  Count:  278
# Label:  standing ytw - too slow  Count:  278
# Label:  standing knee-to-elbow (not bouncing) - hand to knee  Count:  163
# Label:  yoga pushup - looking up  Count:  288
# Label:  squat jump - squat_depth=4  Count:  435
# Label:  yoga pushup - hips too high during pushup phase  Count:  312
# Label:  alternating lateral lunge - heel off the floor  Count:  251
# Label:  alternating lateral lunge - rom=5  Count:  514
# Label:  burpee - no obvious issue  Count:  666
# Label:  hook right and hook left (right leg front) - low range of motion  Count:  210
# Label:  pushups (on knees) - insufficient  Count:  105
# Label:  standing kick (alternate legs) - hands down  Count:  150
# Label:  air jump rope - speed=0.75 rps  Count:  142
# Label:  pushups (on knees) - waiting position  Count:  209
# Label:  curtsy lunges - left leg back  Count:  234
# Label:  alternating lateral lunge - knee over toe  Count:  241
# Label:  hip circles (counterclockwise) - medium circles  Count:  124
# Label:  burpee (no pushup) - stepping feet forward  Count:  321
# Label:  going down on knees - average  Count:  160
# Label:  standing wyt - wrong order  Count:  273
# Label:  spider man pushup - too slow  Count:  328
# Label:  good morning - as low as possible  Count:  165
# Label:  low lunge pose (right leg back) - knee above ankle  Count:  204
# Label:  standing wty - wrong order  Count:  255
# Label:  cross-legged hamstring stretch - left leg front, fold up  Count:  265
# Label:  spider man - not alternating  Count:  178
# Label:  spider man - no rotation  Count:  208
# Label:  jumping lunges - not alternating legs  Count:  182
# Label:  alternating lateral lunge - rom=1  Count:  536
# Label:  hook right and cross (right leg front) - lazy  Count:  206
# Label:  inchworm - getting into position, hands too far from feet  Count:  232
# Label:  neck rolls - alternate looking left and right, too fast  Count:  155
# Label:  puddle jump - speed=1.25 rps  Count:  111
# Label:  clapping hands (long)  Count:  242
# Label:  jab + hook left (right leg front) - lazy  Count:  193
# Label:  low lunge pose (right leg back) - looking down  Count:  196
# Label:  squat jump - lazy  Count:  364
# Label:  standing ytw - thumbs pointed sideway  Count:  275
# Label:  squat jump - leaning forward  Count:  258
# Label:  neck rolls - tilting head left and right, barely moving head  Count:  164
# Label:  spider man - arms too narrow  Count:  195
# Label:  moving plank - speed=0.35 rps  Count:  258
# Label:  standing tyw - wrong order  Count:  253
# Label:  floor touches - perfect form  Count:  107
# Label:  floor touches - width=3  Count:  196
# Label:  spider man - no stepping  Count:  174
# Label:  cobra pose - lower, arms wide apart  Count:  143
# Label:  alternating lateral lunge - wrong knee bent  Count:  260
# Label:  garland pose - no arms  Count:  186
# Label:  floor touches - no obvious issue  Count:  190
# Label:  low lunge pose (right leg back) - bending knee too far forward  Count:  195
# Label:  moving plank - speed=0.25 rps  Count:  261
# Label:  cobra pose - arms fully extended, shrugging shoulders  Count:  164
# Label:  lunges (right leg out in front) - front knee going forward over toes  Count:  209
# Label:  floor touches - not bringing feet together  Count:  204
# Label:  alternating forward lunges - knee over toes  Count:  112
# Label:  standing knee-to-elbow (not bouncing) - speed=1.00 rps  Count:  213
# Label:  puddle jump - no jump  Count:  459
# Label:  bobbing head (imagine there is music)  Count:  239
# Label:  hip circles (counterclockwise) - hands on hips, feet shoulder-width apart  Count:  124
# Label:  squat jump - squat_depth=2  Count:  379
# Label:  squat jump - jump_height=1  Count:  582
# Label:  squat jump - wide space between legs  Count:  194
# Label:  jumping jacks - early stopping  Count:  133
# Label:  hook right and uppercut left (right leg front) - low range of motion  Count:  208
# Label:  garland pose - getting into position  Count:  175
# Label:  snowboarders - single repetition  Count:  181
# Label:  standing ytw - not low enough  Count:  207
# Label:  alternating lateral lunge - torso bent sideways  Count:  267
# Label:  squat jump - speed=1.00 rps  Count:  341
# Label:  squat jacks - shallow squat  Count:  183
# Label:  floor touches - speed=0.60 rps  Count:  175
# Label:  puddle jump - early stopping  Count:  130
# Label:  yoga pushup - starting late  Count:  255
# Label:  alternating lateral lunge - knee out, toes straight  Count:  240
# Label:  spider man pushup - starting late  Count:  306
# Label:  jumping lunges - squat_depth=3  Count:  293
# Label:  spider man - back leg extended, back knee just off the ground  Count:  168
# Label:  alternating lateral lunge - starting late  Count:  267
# Label:  floor touches - width=5  Count:  183
# Label:  jumping jacks - legs_rom=4.0  Count:  129
# Label:  plank taps (on knees) - speed=0.60 rps  Count:  140
# Label:  cat-cow pose - cat posture to cow posture  Count:  197
# Label:  neck rolls - too fast  Count:  147
# Label:  uppercut left (right leg front) - front arm low  Count:  206
# Label:  lunges (right leg out in front) - very wide space between legs, front leg not vertical  Count:  213
# Label:  hook right and hook left (right leg front) - average  Count:  208
# Label:  hip circles (counterclockwise) - small circles  Count:  122
# Label:  squat jump - jump_height=5  Count:  490
# Label:  floor touches - hand on knees  Count:  216
# Label:  low lunge pose (right leg back) - losing balance  Count:  182
# Label:  puddle jump - sliding feet  Count:  128
# Label:  standing ytw - hands flat  Count:  251
# Label:  cat-cow pose - tabletop to cow posture  Count:  184
# Label:  good morning - no arms  Count:  155
# Label:  lunges (right leg out in front) - average  Count:  217
# Label:  hook left + uppercut right (right leg front) - average  Count:  207
# Label:  pushups - child pose cheat  Count:  338
# Label:  standing knee-to-elbow - stopping early  Count:  123
# Label:  puddle jump - narrow  Count:  414
# Label:  hook left + hook right (right leg front) - low range of motion  Count:  214
# Label:  puddle jump - single jump (left to right)  Count:  123
# Label:  alternating lateral lunge - knee in line with toe, stepping foot pointing towards the camera  Count:  240
# Label:  lunges (right leg out in front) - fast  Count:  235
# Label:  squat punch - speed=0.30 rps  Count:  131
# Label:  jumping lunges - large steps  Count:  286
# Label:  squat jump - knees over toes  Count:  245
# Label:  squat jump - speed=0.40 rps  Count:  127
# Label:  squat jump - squat_depth=5  Count:  334
# Label:  fixing hair (long, one hand)  Count:  250
# Label:  moving plank - on knees  Count:  154
# Label:  jumping lunges - starting late  Count:  274
# Label:  puddle jump - sloppy  Count:  128
# Label:  alternating lateral lunge - not alternating  Count:  257
# Label:  snowboarders - stopping early  Count:  155
# Label:  cat-cow pose - cow posture to cat posture  Count:  203
# Label:  squat jump - speed=0.20 rps  Count:  127
# Label:  hip circles (counterclockwise) - no hands  Count:  111
# Label:  jumping lunges - knees touching ground  Count:  161
# Label:  low lunge pose (right leg back) - stopping early  Count:  193
# Label:  alternating forward lunges - starting late  Count:  267
# Label:  plank preparation - average  Count:  155
# Label:  puddle jump - high jump  Count:  143
# Label:  floor touches - speed=0.40 rps  Count:  201
# Label:  cobra pose - medium height, arms wide apart  Count:  165
# Label:  squat jump - narrow space between legs  Count:  189
# Label:  cobra pose - medium height, keeping shoulders away from the ears  Count:  138
# Label:  floor touches - stepping  Count:  196
# Label:  standing ytw - bent legs  Count:  247
# Label:  puddle jump - leaning forward  Count:  121
# Label:  cobra pose - medium height, shrugging shoulders  Count:  150
# Label:  alternating lateral lunge - torso bent forward  Count:  253
# Label:  squat jacks - low turnover  Count:  182
# Label:  shoulder swipe  Count:  238
# Label:  low lunge pose (right leg back) - knee above ankle, butt as low as possible  Count:  204
# Label:  cobra pose - getting into position  Count:  151
# Label:  cobra pose - hands too far forward  Count:  163
# Label:  squat jacks - no jump  Count:  175
# Label:  cobra pose - stopping early  Count:  134
# Label:  low lunge pose (right leg back) - getting into position  Count:  179
# Label:  lying down after pushup - average  Count:  125
# Label:  jumping lunges - not visible  Count:  132
# Label:  cobra pose - higher, keeping shoulders away from the ears  Count:  156
# Label:  sitting on a chair  Count:  225
# Label:  coming closer to the webcam - average  Count:  122
# Label:  leaving plank position - average  Count:  139
# Label:  moving plank - legs on the floor  Count:  133
# Label:  lying down in random position - average  Count:  120
# 1423

# %%
tempo_keywords = ['slow', 'fast', 'tempo', 'controlled', 'jerky', 'shaking', 'explosive', 'pause', 'unstable', 'swing', 'bounce']

tempo_related = [item for item in data if any(
    any(kw in label.lower() for kw in tempo_keywords) for label in item["labels_descriptive"]
)]

print(f"Found {len(tempo_related)} tempo-related clips.")

# Optional: print some examples
for item in tempo_related[:5]:
    print(item["video_path"], "-", item["labels_descriptive"])
# Out:
# Found 30417 tempo-related clips.
# ./00000004.mp4 - ['elbow plank - User is shaking']
# ./00000021.mp4 - ['alternating v ups - User is going as fast as possible', 'alternating v ups - rom=5']
# ./00000041.mp4 - ['the hundred (feet on the floor) - head up - hunched', 'the hundred (feet on the floor) - User is moving their arms as fast as possible']
# ./00000043.mp4 - ["the hundred (feet on the floor) - User's head is up", 'the hundred (feet on the floor) - User is moving their arms as fast as possible']
# ./00000052.mp4 - ["the hundred (table-top position) - User's head is up", "the hundred (table-top position) - User's legs are bent 90 degrees", 'the hundred (table-top position) - User is moving their arms as fast as possible']

# %%
pushup_clips = [item for item in data if any("pushup" in label for label in item["labels"])]
print(f"Push-up clips: {len(pushup_clips)}")

# You can then filter those with tempo cues
pushup_with_tempo = [item for item in pushup_clips if any(
    any(kw in desc.lower() for kw in tempo_keywords) for desc in item["labels_descriptive"]
)]

for item in pushup_with_tempo[:5]:
    print(item["video_path"], "-", item["labels_descriptive"])
# Out:
# Push-up clips: 19526
# ./00001222.mp4 - ["burpee (no pushup) - User isn't stepping their feet back", 'burpee (no pushup) - User is going as fast as possible']
# ./00003041.mp4 - ['pushups - User is going fast', 'pushups - Push-ups are too shallow', "pushups - User has good arm placement that's shoulder width apart"]
# ./00003542.mp4 - ['spider man pushup - User is going too fast', 'spider man pushup - rom=1']
# ./00004152.mp4 - ['burpee (no pushup) - User has good form', 'burpee (no pushup) - User is going as fast as possible']
# ./00004902.mp4 - ["burpee (no pushup) - User's hips are too high", 'burpee (no pushup) - User is going as fast as possible']

# %%
# Filter items by ID >= 228000
subset = [
    item for item in data
    if int(item["video_path"].split("/")[-1].split(".")[0]) >= 228000
]

print(f"Subset size from 228000 onwards: {len(subset)}")

all_labels_subset = [label for item in subset for label in item["labels"]]

label_counts_subset = Counter(all_labels_subset)

print("\nTop labels in subset:")
for label, count in label_counts_subset.most_common(30):
    print(f"{label}: {count}")
# Out:
# Subset size from 228000 onwards: 70089
#
# Top labels in subset:
# squats - shoulder-width: 932
# squat kick - speed=0.40 rps: 801
# fire hydrant - knee on ground: 756
# fire hydrant - head straight: 740
# fire hydrant - arms shoulder width: 676
# squats - no obvious issue: 569
# squats - 90 degrees: 529
# fire hydrant (standing) - head straight: 527
# squat kick - not lifting knees: 510
# pushups (on knees) - wide: 489
# fire hydrant - no obvious issue: 472
# alternating forward lunges - normal speed: 466
# alternating forward lunges - no obvious issue: 418
# alternating forward lunges - normal width: 402
# pushups (on knees) - 90 degrees: 399
# squat jump - no obvious issue: 398
# raised leg circles (clockwise) - clockwise: 393
# fire hydrant (standing) - torso too high: 392
# jumping lunges - medium steps: 384
# fire hydrant (standing) - shin not parallel: 383
# quad stretch (right) - getting into position: 378
# jumping lunges - speed=0.80 rps: 354
# puddle jump - normal width: 344
# quick feet - shoulder-width: 341
# pushups - wide: 313
# puddle jump - speed=0.75 rps: 312
# burpee - stepping feet back: 310
# elbow plank - stopping early: 305
# pushups - deep: 302
# pushups (on knees) - elevated hips: 300

# %% [markdown]
# ## Get subset from Qualcom dataset

# %%
import json

# Load the QEVD annotations
with open("fine_grained_labels.json", "r") as f:
    data = json.load(f)

# Define keyword lists
tempo_keywords = [
    "too fast", "too slow"
]
form_keywords = [
    "sloppy form", "not straight"
]
rom_keywords = [
    "low range of motion"
]

# Function to check if any keywords exist in a text
def matches_keywords(text, keywords):
    return any(kw in text.lower() for kw in keywords)

# Filter videos
bad_tempo, bad_form, bad_rom = [], [], []

for item in data:
    labels_text = " ".join(item["labels_descriptive"]).lower()

    if matches_keywords(labels_text, tempo_keywords):
        bad_tempo.append(item)
    elif matches_keywords(labels_text, form_keywords):
        bad_form.append(item)
    elif matches_keywords(labels_text, rom_keywords):
        bad_rom.append(item)

print(f"Bad Tempo: {len(bad_tempo)}")
print(f"Bad Form: {len(bad_form)}")
print(f"Bad Range of Motion: {len(bad_rom)}")

# %% [markdown]
# # Testing InternVideo (Bad videos only)

# %%
# Install dependencies
# !pip install -q decord transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 112.2 MB/s eta 0:00:00

# %%
import numpy as np
import torch
import torchvision.transforms as T
from decord import VideoReader, cpu
import matplotlib.pyplot as plt
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer

# model setting
model_path = 'OpenGVLab/InternVideo2_5_Chat_8B'

tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
model = AutoModel.from_pretrained(model_path, trust_remote_code=True).half().cuda().to(torch.bfloat16)

IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)

def build_transform(input_size):
    MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
    transform = T.Compose([T.Lambda(lambda img: img.convert("RGB") if img.mode != "RGB" else img), T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC), T.ToTensor(), T.Normalize(mean=MEAN, std=STD)])
    return transform


def find_closest_aspect_ratio(aspect_ratio, target_ratios, width, height, image_size):
    best_ratio_diff = float("inf")
    best_ratio = (1, 1)
    area = width * height
    for ratio in target_ratios:
        target_aspect_ratio = ratio[0] / ratio[1]
        ratio_diff = abs(aspect_ratio - target_aspect_ratio)
        if ratio_diff < best_ratio_diff:
            best_ratio_diff = ratio_diff
            best_ratio = ratio
        elif ratio_diff == best_ratio_diff:
            if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                best_ratio = ratio
    return best_ratio


def dynamic_preprocess(image, min_num=1, max_num=6, image_size=448, use_thumbnail=False):
    orig_width, orig_height = image.size
    aspect_ratio = orig_width / orig_height

    # calculate the existing image aspect ratio
    target_ratios = set((i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if i * j <= max_num and i * j >= min_num)
    target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

    # find the closest aspect ratio to the target
    target_aspect_ratio = find_closest_aspect_ratio(aspect_ratio, target_ratios, orig_width, orig_height, image_size)

    # calculate the target width and height
    target_width = image_size * target_aspect_ratio[0]
    target_height = image_size * target_aspect_ratio[1]
    blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

    # resize the image
    resized_img = image.resize((target_width, target_height))
    processed_images = []
    for i in range(blocks):
        box = ((i % (target_width // image_size)) * image_size, (i // (target_width // image_size)) * image_size, ((i % (target_width // image_size)) + 1) * image_size, ((i // (target_width // image_size)) + 1) * image_size)
        # split the image
        split_img = resized_img.crop(box)
        processed_images.append(split_img)
    assert len(processed_images) == blocks
    if use_thumbnail and len(processed_images) != 1:
        thumbnail_img = image.resize((image_size, image_size))
        processed_images.append(thumbnail_img)
    return processed_images


def load_image(image, input_size=448, max_num=6):
    transform = build_transform(input_size=input_size)
    images = dynamic_preprocess(image, image_size=input_size, use_thumbnail=True, max_num=max_num)
    pixel_values = [transform(image) for image in images]
    pixel_values = torch.stack(pixel_values)
    return pixel_values


def get_index(bound, fps, max_frame, first_idx=0, num_segments=32):
    if bound:
        start, end = bound[0], bound[1]
    else:
        start, end = -100000, 100000
    start_idx = max(first_idx, round(start * fps))
    end_idx = min(round(end * fps), max_frame)
    seg_size = float(end_idx - start_idx) / num_segments
    frame_indices = np.array([int(start_idx + (seg_size / 2) + np.round(seg_size * idx)) for idx in range(num_segments)])
    return frame_indices

def get_num_frames_by_duration(duration):
        local_num_frames = 4
        num_segments = int(duration // local_num_frames)
        if num_segments == 0:
            num_frames = local_num_frames
        else:
            num_frames = local_num_frames * num_segments

        num_frames = min(512, num_frames)
        num_frames = max(128, num_frames)

        return num_frames

def load_video(video_path, bound=None, input_size=448, max_num=1, num_segments=32, get_frame_by_duration = False):
    vr = VideoReader(video_path, ctx=cpu(0), num_threads=1)
    max_frame = len(vr) - 1
    fps = float(vr.get_avg_fps())

    pixel_values_list, num_patches_list = [], []
    transform = build_transform(input_size=input_size)
    if get_frame_by_duration:
        duration = max_frame / fps
        num_segments = get_num_frames_by_duration(duration)
    frame_indices = get_index(bound, fps, max_frame, first_idx=0, num_segments=num_segments)
    for frame_index in frame_indices:
        img = Image.fromarray(vr[frame_index].asnumpy()).convert("RGB")
        img = dynamic_preprocess(img, image_size=input_size, use_thumbnail=True, max_num=max_num)
        pixel_values = [transform(tile) for tile in img]
        pixel_values = torch.stack(pixel_values)
        num_patches_list.append(pixel_values.shape[0])
        pixel_values_list.append(pixel_values)
    pixel_values = torch.cat(pixel_values_list)
    return pixel_values, num_patches_list
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/5.24k [00:00<?, ?B/s]
# tokenization_internlm2.py:   0%|          | 0.00/8.79k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - tokenization_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer.model:   0%|          | 0.00/1.48M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.58k [00:00<?, ?B/s]
# configuration_internvl_chat.py:   0%|          | 0.00/4.03k [00:00<?, ?B/s]
# configuration_intern_vit.py:   0%|          | 0.00/5.55k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - configuration_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# configuration_internlm2.py:   0%|          | 0.00/7.00k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - configuration_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - configuration_internvl_chat.py
# - configuration_intern_vit.py
# - configuration_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_internvl_chat_hico2.py:   0%|          | 0.00/19.4k [00:00<?, ?B/s]
# modeling_internlm2.py:   0%|          | 0.00/61.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - modeling_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# conversation.py:   0%|          | 0.00/15.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - conversation.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_intern_vit.py:   0%|          | 0.00/18.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B:
# - modeling_internvl_chat_hico2.py
# - modeling_internlm2.py
# - conversation.py
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# FlashAttention2 is not installed.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# model.safetensors.index.json:   0%|          | 0.00/51.2k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.03G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# InternLM2ForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Warning: Flash attention is not available, using eager attention instead.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/VR/Visual_Recognition/subset
# Out:
# bad_form  bad_tempo		  selected_bad_rom.json
# bad_rom   selected_bad_form.json  selected_bad_tempo.json

# %%
# !ls /content/drive/MyDrive/VR/Visual_Recognition/good_bad_videos
# Out:
# bad_form_250   good_rom_250		   selected_bad_tempo_250.json
# bad_rom_250    good_tempo_250		   selected_good_form_250.json
# bad_tempo_250  selected_bad_form_250.json  selected_good_rom_250.json
# good_form_250  selected_bad_rom_250.json   selected_good_tempo_250.json

# %%
import csv

# Setup
root_folder = "/content/drive/MyDrive/VR/Visual_Recognition/subset"
categories = {
    "bad_tempo": "tempo",
    "bad_form": "form",
    "bad_rom": "rom"
}

for subfolder in categories:
    folder_path = os.path.join(root_folder, subfolder)
    if os.path.isdir(folder_path):
        print(f"✅ Folder exists: {folder_path}")
    else:
        print(f"❌ Folder NOT found: {folder_path}")
# Out:
# ✅ Folder exists: /content/drive/MyDrive/VR/Visual_Recognition/subset/bad_tempo
# ✅ Folder exists: /content/drive/MyDrive/VR/Visual_Recognition/subset/bad_form
# ✅ Folder exists: /content/drive/MyDrive/VR/Visual_Recognition/subset/bad_rom

# %% [markdown]
# ## Zero-Shot Prompt

# %%
csv_path = "exercise_eval_results.csv"
header = ["filename", "predicted_label", "predicted_reason", "ground_truth_label", "ground_truth_reason", "correct"]

# Generation Config
max_num_frames = 512
generation_config = dict(
    do_sample=False,
    temperature=0.0,
    max_new_tokens=512,
    top_p=0.1,
    num_beams=1
)

# CSV Setup
with open(csv_path, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

    for subfolder, ground_truth_reason in categories.items():
        folder_path = os.path.join(root_folder, subfolder)
        for filename in os.listdir(folder_path):
            if any(filename.endswith(ext) for ext in [".mp4"]):
                video_path = os.path.join(folder_path, filename)
                print(f"\nEvaluating: {subfolder}/{filename}")
                try:
                    with torch.no_grad():
                        pixel_values, num_patches_list = load_video(video_path, num_segments=64, max_num=1)
                        pixel_values = pixel_values.to(torch.bfloat16).to(model.device)
                        video_prefix = "".join([f"Frame{i+1}: \n" for i in range(len(num_patches_list))])

                        prompt = f"""We are evaluating whether a video clip of an exercise is being performed correctly for hypertrophy-focused training.
                        There are three main criteria to assess:

                        - **Tempo**: This refers to the speed of movement during each phase of the exercise. For optimal hypertrophy, the eccentric (lowering) phase should be slow and controlled, while the concentric (lifting) phase should be fast and explosive.

                        - **Form**: This includes the alignment, posture, and technique of the movement. Proper form means the exercise is performed with the correct joint positioning, body alignment, and grip/stance. Common issues include flaring elbows, improper back posture, or hands/feet placed too wide or narrow.

                        - **Range of Motion (ROM)**: This measures whether the exercise goes through the full intended motion. A proper ROM means the movement starts from a full stretch and ends in a full contraction, without cutting the motion short or stopping midway.

                        Now, assess the following:
                        **Is this exercise being done correctly?**
                        Respond with only the following format:
                        1. Yes / No
                        2. (If No) tempo / form / rom
                        3. Briefly explain the issue in one sentence.
                        """

                        question = video_prefix + prompt
                        output, _ = model.chat(
                            tokenizer, pixel_values, question, generation_config,
                            num_patches_list=num_patches_list, history=None, return_history=True
                        )
                        print("Model Output: \n", output)

                        lines = output.strip().splitlines()
                        lines = [line.strip() for line in lines if line.strip() != ""]

                        # Defaults
                        predicted_label = "Unclear"
                        predicted_reason = "unclear"
                        explanation = ""

                        if len(lines) >= 1:
                            first_line = lines[0].lower()
                            if "yes" in first_line:
                                predicted_label = "Good"
                                predicted_reason = "none"
                            elif "no" in first_line:
                                predicted_label = "Bad"
                                if len(lines) >= 2:
                                    second_line = lines[1].lower()
                                    if "tempo" in second_line:
                                        predicted_reason = "tempo"
                                    elif "form" in second_line:
                                        predicted_reason = "form"
                                    elif "rom" in second_line or "range" in second_line or "motion" in second_line:
                                        predicted_reason = "rom"
                                    else:
                                        predicted_reason = "unclear"
                                if len(lines) >= 3:
                                    explanation = lines[2]

                        print("Predicted Label:", predicted_label)
                        print("Predicted Reason:", predicted_reason)
                        print("Explanation:", explanation)
                        print("Ground Truth Reason:", ground_truth_reason)

                        writer.writerow([
                            filename,
                            predicted_label,
                            predicted_reason,
                            "Bad",
                            ground_truth_reason,
                            predicted_label == "Bad" and predicted_reason == ground_truth_reason
                        ])
                except Exception as e:
                    print(f"Error processing {filename}: {e}")
# Out:
# Evaluating: bad_tempo/00012249.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and muscles.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and muscles.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00011556.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, which can lead to improper form and potential strain.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, which can lead to improper form and potential strain.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00016532.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the person's lower back arching excessively and the movement not being controlled.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the person's lower back arching excessively and the movement not being controlled.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00023161.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072444.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not optimal, as they are not maintaining proper joint positioning and body alignment during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not optimal, as they are not maintaining proper joint positioning and body alignment during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00059311.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not in a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not in a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00066581.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual's elbows flaring out and the back not maintaining a neutral position. Additionally, the range of motion is limited, and the tempo is not controlled, with the movement appearing too rapid.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual's elbows flaring out and the back not maintaining a neutral position. Additionally, the range of motion is limited, and the tempo is not controlled, with the movement appearing too rapid.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00229773.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, which can lead to improper joint positioning and potential strain.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, which can lead to improper joint positioning and potential strain.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00029963.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, which can put unnecessary stress on the joints.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, which can put unnecessary stress on the joints.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00046088.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual's lower back arching excessively and feet not reaching the ground, limiting the range of motion.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual's lower back arching excessively and feet not reaching the ground, limiting the range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00023949.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's form appears to be incorrect, with potential issues such as improper back posture and hand placement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's form appears to be incorrect, with potential issues such as improper back posture and hand placement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013106.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's head is not aligned with their spine, which can lead to improper posture and potential strain.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's head is not aligned with their spine, which can lead to improper posture and potential strain.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00239845.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, as the person is not performing any specific exercise but is simply standing and moving their head.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, as the person is not performing any specific exercise but is simply standing and moving their head.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00017048.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper range of motion.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00235069.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018821.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00014632.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00238832.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00024722.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00258229.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00286641.mp4
# Model Output:
#  1. No
# 2. No movement observed.
# Predicted Label: Bad
# Predicted Reason: unclear
# Explanation:
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00291149.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The knee is not properly aligned, which can lead to incorrect muscle engagement and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The knee is not properly aligned, which can lead to incorrect muscle engagement and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00066392.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072413.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly in the alignment and posture, which can lead to ineffective muscle engagement and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly in the alignment and posture, which can lead to ineffective muscle engagement and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00062102.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out excessively during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out excessively during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00230184.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is incorrect, as they are not maintaining proper joint positioning and body alignment during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is incorrect, as they are not maintaining proper joint positioning and body alignment during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00268039.mp4
# Model Output:
#  1. No
# 2. No
# 3. The video does not show any exercise being performed.
# Predicted Label: Bad
# Predicted Reason: unclear
# Explanation: 3. The video does not show any exercise being performed.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013434.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018275.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00042853.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064538.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036057.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00002281.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00034681.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, which can lead to improper joint positioning and potential strain.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, which can lead to improper joint positioning and potential strain.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036501.mp4
# Model Output:
#  1. No
# 2. Tempo / Form
# 3. The exercise lacks proper form, particularly with the leg positioning and the speed of movement.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, particularly with the leg positioning and the speed of movement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00024667.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00002408.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072033.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is incorrect, as they are not maintaining proper joint positioning and body alignment during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is incorrect, as they are not maintaining proper joint positioning and body alignment during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00063198.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00050198.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks a clear eccentric and concentric phase, and the form appears to be incorrect with the person standing still rather than performing a dynamic movement.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric and concentric phase, and the form appears to be incorrect with the person standing still rather than performing a dynamic movement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037016.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00015940.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is not properly aligned, which can lead to improper technique and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is not properly aligned, which can lead to improper technique and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00074679.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their elbow is flaring outward during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their elbow is flaring outward during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00027507.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not in a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not in a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00008409.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00272872.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, indicating improper elbow positioning.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, indicating improper elbow positioning.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00230586.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual is not maintaining proper form, particularly in the alignment and posture during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual is not maintaining proper form, particularly in the alignment and posture during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00247622.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00038776.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00268734.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their knees are extending past their toes during the squat.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their knees are extending past their toes during the squat.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037346.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbow is flaring outwards during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbow is flaring outwards during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00005636.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, which can indicate improper posture during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, which can indicate improper posture during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00271325.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the legs not fully extending during the lift and the body not maintaining a stable position.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the legs not fully extending during the lift and the body not maintaining a stable position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00239670.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013496.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual's elbows flaring out and the movement not being controlled.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual's elbows flaring out and the movement not being controlled.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00025620.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283446.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00012588.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out, which is a common issue in push-ups that can lead to improper joint positioning.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out, which is a common issue in push-ups that can lead to improper joint positioning.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00269501.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper execution of the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper execution of the movement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00246049.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037722.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and reduce the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00289062.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00246765.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00054254.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00287232.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The eccentric phase of the exercise is not slow and controlled.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase of the exercise is not slow and controlled.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064039.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00051104.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out, which is a common issue with improper form during push-ups.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out, which is a common issue with improper form during push-ups.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00296494.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00053253.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00231364.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00048538.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is incorrect, as their elbows are flaring out too much during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is incorrect, as their elbows are flaring out too much during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00062444.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's elbows are flaring out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's elbows are flaring out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018140.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched excessively, which can put unnecessary strain on the spine and may not effectively target the intended muscles.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched excessively, which can put unnecessary strain on the spine and may not effectively target the intended muscles.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00053044.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00011496.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064975.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, as the person is not maintaining a stable posture and the movement is not aligned with standard exercise technique.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, as the person is not maintaining a stable posture and the movement is not aligned with standard exercise technique.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00231220.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00041812.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00007380.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly supported, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly supported, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036778.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00290008.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual not maintaining a controlled posture and the movement not being executed with the correct joint positioning.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual not maintaining a controlled posture and the movement not being executed with the correct joint positioning.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00259571.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, which can put unnecessary stress on the shoulders and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, which can put unnecessary stress on the shoulders and reduce the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00071162.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00021800.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their back is arched and their hands are not positioned correctly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their back is arched and their hands are not positioned correctly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00052183.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00274174.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's feet are not reaching a full extension during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's feet are not reaching a full extension during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00273574.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00249865.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00019322.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00057922.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00006465.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00032740.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly supported, which can lead to improper form and potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly supported, which can lead to improper form and potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00060934.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper execution of the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper execution of the movement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00247114.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00039298.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00282824.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283360.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283462.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and muscles.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the joints and muscles.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00052625.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00049807.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out excessively during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out excessively during the push-up, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_form/00264059.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00258716.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00298054.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The eccentric phase of the exercise appears to be slow and controlled, while the concentric phase is fast and explosive, which is appropriate for hypertrophy training.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase of the exercise appears to be slow and controlled, while the concentric phase is fast and explosive, which is appropriate for hypertrophy training.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00056422.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the person not maintaining a controlled tempo and not achieving a full range of motion.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the person not maintaining a controlled tempo and not achieving a full range of motion.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00245832.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00289458.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not optimal, as the movement appears to be more of a dance routine rather than a controlled exercise focused on hypertrophy.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not optimal, as the movement appears to be more of a dance routine rather than a controlled exercise focused on hypertrophy.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00254654.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's form appears to be incorrect, with potential issues such as improper joint positioning and body alignment.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's form appears to be incorrect, with potential issues such as improper joint positioning and body alignment.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00264754.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much during the push-up, which can put unnecessary stress on the shoulders and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much during the push-up, which can put unnecessary stress on the shoulders and reduce the effectiveness of the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00257040.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not consistent, with varying arm positions and movements that do not maintain proper joint alignment and body posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not consistent, with varying arm positions and movements that do not maintain proper joint alignment and body posture.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00259695.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00232934.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00026364.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00273762.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00271676.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual not maintaining a controlled posture and the movement not involving a full range of motion.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual not maintaining a controlled posture and the movement not involving a full range of motion.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00231356.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00236461.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00263762.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual's elbows flaring out and the movement not being controlled.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual's elbows flaring out and the movement not being controlled.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00270565.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00005486.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00243778.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual's feet not remaining stationary and the movement not being controlled.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual's feet not remaining stationary and the movement not being controlled.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00272177.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out excessively during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out excessively during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00023278.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00274320.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00248276.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00235407.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual not maintaining a controlled posture and the movement not involving a full range of motion.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual not maintaining a controlled posture and the movement not involving a full range of motion.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00268401.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00260961.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out, which can indicate improper form during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out, which can indicate improper form during the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00022393.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their movements appear to be more of a dance routine rather than a controlled exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their movements appear to be more of a dance routine rather than a controlled exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00228111.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out too much, which can put unnecessary stress on the joints and reduce the effectiveness of the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00233859.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The concentric phase appears to be fast, while the eccentric phase is slow, which is not ideal for hypertrophy training.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The concentric phase appears to be fast, while the eccentric phase is slow, which is not ideal for hypertrophy training.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00239371.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the push-up, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the push-up, indicating improper form.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00252402.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not optimal, as their elbow flares outward during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not optimal, as their elbow flares outward during the exercise.
# Ground Truth Reason: form
#
# ...
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00285154.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00281478.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00065480.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their elbows flare out during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their elbows flare out during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00043495.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00065194.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with elbows flaring outward and the range of motion not fully utilized.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with elbows flaring outward and the range of motion not fully utilized.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00051144.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's form is not optimal, as the elbows flare out during the movement, which can lead to improper joint positioning and potential strain.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's form is not optimal, as the elbows flare out during the movement, which can lead to improper joint positioning and potential strain.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00278800.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00057934.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00276184.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not optimal, as their elbows flare out during the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not optimal, as their elbows flare out during the movement.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00066218.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00273970.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00015772.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00288404.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not in a neutral position, which can affect the proper execution of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not in a neutral position, which can affect the proper execution of the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00252818.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00048708.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00045145.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the arms not extending fully and the tempo not being controlled, especially during the eccentric phase.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the arms not extending fully and the tempo not being controlled, especially during the eccentric phase.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00241350.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's form appears to be incorrect, with potential issues such as improper joint positioning and body alignment.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's form appears to be incorrect, with potential issues such as improper joint positioning and body alignment.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00259971.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The individual's elbows are flaring outwards, which is a common issue in form during exercises like this.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The individual's elbows are flaring outwards, which is a common issue in form during exercises like this.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00060864.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00001497.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00231630.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00258831.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00234416.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is incorrect, as they are not performing a proper exercise but rather making gestures.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is incorrect, as they are not performing a proper exercise but rather making gestures.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00064409.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00028611.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not optimal, as their elbows flare out during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not optimal, as their elbows flare out during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00251797.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00073197.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their elbows are flaring outwards during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their elbows are flaring outwards during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00043550.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their elbows flare out during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their elbows flare out during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00004965.mp4
# Model Output:
#  1. No
# 2. Tempo / Form / ROM
# 3. The exercise lacks proper form, with the individual's elbows flaring out and the back not maintaining a neutral position. The range of motion is also limited, as the movement does not fully extend the arms and legs.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the individual's elbows flaring out and the back not maintaining a neutral position. The range of motion is also limited, as the movement does not fully extend the arms and legs.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00231645.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00054859.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise is not being performed correctly due to improper form, specifically with the elbows flaring out and the posture not being aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise is not being performed correctly due to improper form, specifically with the elbows flaring out and the posture not being aligned properly.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00044079.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00034999.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture, as the person is not maintaining a stable position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture, as the person is not maintaining a stable position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00002117.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their elbow flares out during the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their elbow flares out during the movement.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00044580.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the proper form and ROM.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00264460.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the elbow flaring outward during the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the elbow flaring outward during the movement.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00035725.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows flare out during the exercise, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows flare out during the exercise, indicating improper form.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00053394.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00270085.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not performing an exercise; they are adjusting their hair.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not performing an exercise; they are adjusting their hair.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00000069.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00251566.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00291965.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their hands are not reaching the back of their head during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their hands are not reaching the back of their head during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00252547.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring outwards, which is improper form for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00072874.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as their elbows flare out during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as their elbows flare out during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00045196.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The exercise lacks proper form, particularly with the alignment and posture, as the individual's back is not maintaining a neutral position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The exercise lacks proper form, particularly with the alignment and posture, as the individual's back is not maintaining a neutral position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00006341.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person is not maintaining proper form, as indicated by the incorrect posture and hand positioning.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person is not maintaining proper form, as indicated by the incorrect posture and hand positioning.
# Ground Truth Reason: rom

# %% [markdown]
# ## Chain of Thought Prompt

# %%
csv_path = "exercise_eval_results_part2.csv"
header = ["filename", "predicted_label", "predicted_reason", "ground_truth_label", "ground_truth_reason", "correct"]

# Generation Config
max_num_frames = 512
generation_config = dict(
    do_sample=False,
    temperature=0.0,
    max_new_tokens=512,
    top_p=0.1,
    num_beams=1
)

# CSV Setup
with open(csv_path, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

    for subfolder, ground_truth_reason in categories.items():
        folder_path = os.path.join(root_folder, subfolder)
        for filename in os.listdir(folder_path):
            if any(filename.endswith(ext) for ext in [".mp4"]):
                video_path = os.path.join(folder_path, filename)
                print(f"\nEvaluating: {subfolder}/{filename}")
                try:
                    with torch.no_grad():
                        pixel_values, num_patches_list = load_video(video_path, num_segments=64, max_num=1)
                        pixel_values = pixel_values.to(torch.bfloat16).to(model.device)
                        video_prefix = "".join([f"Frame{i+1}: \n" for i in range(len(num_patches_list))])

                        prompt = f"""

                        We are evaluating whether a video clip of an exercise is being performed correctly for hypertrophy training.

                        Step-by-step:
                        1. Analyze the **tempo**. Is the eccentric phase slow and the concentric phase explosive?
                        2. Analyze the **form**. Are the joints aligned properly? Are the hands in correct position?
                        3. Analyze the **range of motion**. Does the movement go from full extension to full contraction?

                        Now, assess the following:
                        **Is this exercise being done correctly?**
                        Respond with only the following format:
                        1. Yes / No
                        2. (If No) tempo / form / rom
                        3. Briefly explain the issue in one sentence.
                        """

                        question = video_prefix + prompt
                        output, _ = model.chat(
                            tokenizer, pixel_values, question, generation_config,
                            num_patches_list=num_patches_list, history=None, return_history=True
                        )
                        print("Model Output: \n", output)

                        lines = output.strip().splitlines()
                        lines = [line.strip() for line in lines if line.strip() != ""]

                        # Defaults
                        predicted_label = "Unclear"
                        predicted_reason = "unclear"
                        explanation = ""

                        if len(lines) >= 1:
                            first_line = lines[0].lower()
                            if "yes" in first_line:
                                predicted_label = "Good"
                                predicted_reason = "none"
                            elif "no" in first_line:
                                predicted_label = "Bad"
                                if len(lines) >= 2:
                                    second_line = lines[1].lower()
                                    if "tempo" in second_line:
                                        predicted_reason = "tempo"
                                    elif "form" in second_line:
                                        predicted_reason = "form"
                                    elif "rom" in second_line or "range" in second_line or "motion" in second_line:
                                        predicted_reason = "rom"
                                    else:
                                        predicted_reason = "unclear"
                                if len(lines) >= 3:
                                    explanation = lines[2]

                        print("Predicted Label:", predicted_label)
                        print("Predicted Reason:", predicted_reason)
                        print("Explanation:", explanation)
                        print("Ground Truth Reason:", ground_truth_reason)

                        writer.writerow([
                            filename,
                            predicted_label,
                            predicted_reason,
                            "Bad",
                            ground_truth_reason,
                            predicted_label == "Bad" and predicted_reason == ground_truth_reason
                        ])
                except Exception as e:
                    print(f"Error processing {filename}: {e}")
# Out:
# Evaluating: bad_tempo/00012249.mp4
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00011556.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a clear eccentric and concentric phase, and the form is not optimal with the hands positioned too far apart.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric and concentric phase, and the form is not optimal with the hands positioned too far apart.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00016532.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining contact with the floor during the exercise, which is important for proper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining contact with the floor during the exercise, which is important for proper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00023161.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the arms not extending fully and the range of motion being limited.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the arms not extending fully and the range of motion being limited.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072444.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper tempo, form, and range of motion. The person is not performing the movement with controlled eccentric and concentric phases, and the joints are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper tempo, form, and range of motion. The person is not performing the movement with controlled eccentric and concentric phases, and the joints are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00059311.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly aligned, which can lead to potential injury.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly aligned, which can lead to potential injury.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00066581.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a clear eccentric phase, and the form is not optimal for hypertrophy training.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric phase, and the form is not optimal for hypertrophy training.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00229773.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hips are not in a straight line during the lunge, which affects the proper alignment of the joints.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hips are not in a straight line during the lunge, which affects the proper alignment of the joints.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00029963.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the hands not positioned correctly and the range of motion not fully utilized.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the hands not positioned correctly and the range of motion not fully utilized.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00046088.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not in contact with the floor during the exercise, which can affect the proper execution of the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not in contact with the floor during the exercise, which can affect the proper execution of the movement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00023949.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013106.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00239845.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's head is moving excessively, which can affect the alignment of the spine and the effectiveness of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's head is moving excessively, which can affect the alignment of the spine and the effectiveness of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00017048.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00235069.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018821.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00014632.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the arms not extending fully and the range of motion being limited.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the arms not extending fully and the range of motion being limited.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00238832.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not fully extended during the eccentric phase.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not fully extended during the eccentric phase.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00024722.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a clear eccentric and concentric phase, and the range of motion is limited.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric and concentric phase, and the range of motion is limited.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00258229.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not positioned correctly; they are too close together.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not positioned correctly; they are too close together.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00286641.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks movement, making it impossible to assess tempo, form, or range of motion.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks movement, making it impossible to assess tempo, form, or range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00291149.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The knee is not properly aligned during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The knee is not properly aligned during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00066392.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the hands positioned too far apart and the body not maintaining a straight line.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the hands positioned too far apart and the body not maintaining a straight line.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072413.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The knee is not aligned properly during the movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The knee is not aligned properly during the movement.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00062102.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not in a straight line, which can affect the proper execution of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not in a straight line, which can affect the proper execution of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00230184.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and hips.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and hips.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00268039.mp4
# Model Output:
#  1. No
# 2. No
# 3. The person is standing still without performing any exercise.
# Predicted Label: Bad
# Predicted Reason: unclear
# Explanation: 3. The person is standing still without performing any exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013434.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly supported, which can affect the alignment of the spine during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly supported, which can affect the alignment of the spine during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018275.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining contact with the mat, which can affect the proper execution of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining contact with the mat, which can affect the proper execution of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00042853.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064538.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036057.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly aligned, and the hands are not positioned correctly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly aligned, and the hands are not positioned correctly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00002281.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00034681.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not in a neutral position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not in a neutral position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036501.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the eccentric phase.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the eccentric phase.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00024667.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the head is not in a neutral position, which can affect proper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the head is not in a neutral position, which can affect proper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00002408.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly aligned during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly aligned during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072033.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The knee is not aligned properly during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The knee is not aligned properly during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00063198.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow; it appears to be performed at a moderate pace.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow; it appears to be performed at a moderate pace.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00050198.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The exercise lacks the slow eccentric phase and explosive concentric phase typical for hypertrophy training.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks the slow eccentric phase and explosive concentric phase typical for hypertrophy training.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037016.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining contact with the floor, which is important for proper form during this exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining contact with the floor, which is important for proper form during this exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00015940.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with their legs not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with their legs not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00074679.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the knee not aligned properly and the range of motion not fully utilized.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the knee not aligned properly and the range of motion not fully utilized.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00027507.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the knees not aligned properly and the range of motion not fully utilized.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the knees not aligned properly and the range of motion not fully utilized.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00008409.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper tempo and form, and the range of motion is insufficient.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper tempo and form, and the range of motion is insufficient.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00272872.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's head is not aligned properly with their body during the push-up.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's head is not aligned properly with their body during the push-up.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00230586.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00247622.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is not straight, and the arms are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is not straight, and the arms are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00038776.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the hands not positioned correctly and the range of motion not fully extended.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the hands not positioned correctly and the range of motion not fully extended.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00268734.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knees are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knees are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037346.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbow is not aligned properly; it is bending inward rather than staying straight.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbow is not aligned properly; it is bending inward rather than staying straight.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00005636.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00271325.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a slow eccentric phase and the range of motion is limited.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a slow eccentric phase and the range of motion is limited.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00239670.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the back not maintaining a straight position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the back not maintaining a straight position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013496.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00025620.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which is important for proper form during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which is important for proper form during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283446.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00012588.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00269501.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00246049.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The eccentric phase is not slow; it appears to be performed quickly.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow; it appears to be performed quickly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037722.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flared out too much, which can put unnecessary stress on the shoulders and wrists.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flared out too much, which can put unnecessary stress on the shoulders and wrists.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00289062.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position; they should be placed wider apart for proper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position; they should be placed wider apart for proper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00246765.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00054254.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00287232.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064039.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knees are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knees are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00051104.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position, and the knees are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position, and the knees are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00296494.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the knees not in a straight line and the hands not positioned correctly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the knees not in a straight line and the hands not positioned correctly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00053253.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00231364.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knees are not fully extended during the eccentric phase, which is important for proper form in this exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knees are not fully extended during the eccentric phase, which is important for proper form in this exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00048538.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knees are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knees are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00062444.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018140.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the head is not in a neutral position, indicating improper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the head is not in a neutral position, indicating improper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00053044.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00011496.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064975.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper tempo and form, and the range of motion is not fully utilized.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper tempo and form, and the range of motion is not fully utilized.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00231220.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the hands positioned too far apart and the body not maintaining a straight line.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the hands positioned too far apart and the body not maintaining a straight line.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00041812.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a clear eccentric and concentric phase, and the range of motion is limited.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric and concentric phase, and the range of motion is limited.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00007380.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly supported, which can affect the form of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly supported, which can affect the form of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036778.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not maintaining a neutral position, which is important for proper form during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not maintaining a neutral position, which is important for proper form during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00290008.mp4
# Model Output:
#  1. No
# 2. Tempo and form are not clearly visible due to the angle and quality of the video.
# 3. The range of motion is not clearly visible due to the angle and quality of the video.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The range of motion is not clearly visible due to the angle and quality of the video.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00259571.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and elbows.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and elbows.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00071162.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00021800.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knee is not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knee is not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00052183.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly aligned, and the knees are not in a neutral position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly aligned, and the knees are not in a neutral position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00274174.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00273574.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the back not maintaining a straight position during the push-up.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the back not maintaining a straight position during the push-up.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00249865.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00019322.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00057922.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's head is not aligned properly with their body during the push-up.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's head is not aligned properly with their body during the push-up.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00006465.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00032740.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's lower back is not properly supported, which can affect the form of the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's lower back is not properly supported, which can affect the form of the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00060934.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00247114.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the hands positioned too far apart and the body not maintaining a straight line.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the hands positioned too far apart and the body not maintaining a straight line.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00039298.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position; they should be placed wider apart for proper form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position; they should be placed wider apart for proper form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00282824.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise, which affects the range of motion.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283360.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283462.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is not in a straight line, which is important for proper form during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is not in a straight line, which is important for proper form during the exercise.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00052625.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's back is arched, and the head is not in a neutral position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's back is arched, and the head is not in a neutral position.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00049807.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's head is not aligned properly with their body during the push-up.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's head is not aligned properly with their body during the push-up.
# Ground Truth Reason: tempo
#
# Evaluating: bad_form/00264059.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00258716.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00298054.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The knee is not properly aligned during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The knee is not properly aligned during the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00056422.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly the knees and feet during the lunges.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly the knees and feet during the lunges.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00245832.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00289458.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly the knees and feet positioning.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly the knees and feet positioning.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00254654.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbows and knees.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbows and knees.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00264754.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00257040.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbow and wrist positions.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbow and wrist positions.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00259695.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00232934.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's body is not aligned properly during the push-up.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's body is not aligned properly during the push-up.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00026364.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the hands not positioned correctly and the range of motion not fully utilized.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the hands not positioned correctly and the range of motion not fully utilized.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00273762.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00271676.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper tempo control, form, and range of motion.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper tempo control, form, and range of motion.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00231356.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00236461.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow, which is important for hypertrophy training.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow, which is important for hypertrophy training.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00263762.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbow and wrist positions.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbow and wrist positions.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00270565.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00005486.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knees are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knees are not aligned properly.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00243778.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00272177.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00023278.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00274320.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00248276.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's head is not aligned properly with their body during the push-up.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's head is not aligned properly with their body during the push-up.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00235407.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and feet during the jump.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and feet during the jump.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00268401.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly the position of the hands and the body alignment during the push-up movement.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly the position of the hands and the body alignment during the push-up movement.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00260961.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00022393.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and feet during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and feet during the exercise.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00228111.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00233859.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and hips.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and hips.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00239371.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00252402.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and hips.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and hips.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00248119.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly the knee and foot positioning during the jump.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly the knee and foot positioning during the jump.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00263916.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow and the concentric phase is not explosive.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00229803.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly; they are flared out too much.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly; they are flared out too much.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00270333.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the head moving forward and the elbows not reaching full extension.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the head moving forward and the elbows not reaching full extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00285771.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and hips.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and hips.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00030697.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a clear eccentric phase, and the form is not optimal for hypertrophy training.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric phase, and the form is not optimal for hypertrophy training.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00281495.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00240669.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00268346.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the head and body not maintaining a straight line.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the head and body not maintaining a straight line.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00228817.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the knees and feet.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the knees and feet.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00246007.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly, and the hands are not in the correct position.
# ...
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00033397.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not properly aligned, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not properly aligned, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00063225.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00278050.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The eccentric phase is not slow; it appears to be performed at a moderate pace.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow; it appears to be performed at a moderate pace.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00257230.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not properly aligned during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not properly aligned during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00034540.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00285154.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00281478.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's knees are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's knees are not aligned properly.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00065480.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00043495.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00065194.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00051144.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbows and shoulders.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbows and shoulders.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00278800.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00057934.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's elbows are not aligned properly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's elbows are not aligned properly.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00276184.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the head and torso leaning forward.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the head and torso leaning forward.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00066218.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the hands not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the hands not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00273970.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00015772.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00288404.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the leg not extending fully and the body not maintaining a stable position.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the leg not extending fully and the body not maintaining a stable position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00252818.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper form, with the knees not fully extending and the hands not positioned correctly.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper form, with the knees not fully extending and the hands not positioned correctly.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00048708.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a slow eccentric phase and explosive concentric phase, and the form of the hands and joints needs improvement.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a slow eccentric phase and explosive concentric phase, and the form of the hands and joints needs improvement.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00045145.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The arms are not extending fully during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The arms are not extending fully during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00241350.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbows and wrists.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbows and wrists.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00259971.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks a clear eccentric phase, and the form of the hands and joints needs improvement.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks a clear eccentric phase, and the form of the hands and joints needs improvement.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00060864.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00001497.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00231630.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00258831.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00234416.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00064409.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbows and shoulders.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbows and shoulders.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00028611.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with their hands not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with their hands not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00251797.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00073197.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper tempo, form, and range of motion. The movements appear to be too fast and the form is not aligned properly.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper tempo, form, and range of motion. The movements appear to be too fast and the form is not aligned properly.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00043550.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00004965.mp4
# Model Output:
#  1. No
# 2. Tempo and form are not clearly visible in the video.
# 3. The range of motion is not clearly visible in the video.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The range of motion is not clearly visible in the video.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00231645.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00054859.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00044079.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00034999.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, and the hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00002117.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the elbows not positioned correctly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the elbows not positioned correctly.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00044580.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's legs are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's legs are not fully extended during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00264460.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00035725.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's arms are not fully extended during the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's arms are not fully extended during the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00053394.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00270085.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise is not being done correctly as the range of motion is limited and the form is not proper.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise is not being done correctly as the range of motion is limited and the form is not proper.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00000069.mp4
# Model Output:
#  1. No
# 2. Tempo
# 3. The eccentric phase is not slow; it appears to be performed at a moderate pace.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The eccentric phase is not slow; it appears to be performed at a moderate pace.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00251566.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's hands are not in the correct position for the exercise.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's hands are not in the correct position for the exercise.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00291965.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The exercise lacks proper tempo, form, and range of motion. The person is not performing the exercise with controlled movements, and the range of motion is not adequate.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The exercise lacks proper tempo, form, and range of motion. The person is not performing the exercise with controlled movements, and the range of motion is not adequate.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00252547.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The hands are not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The hands are not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00072874.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, particularly with the elbows and head position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, particularly with the elbows and head position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00045196.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the hands not in the correct position.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the hands not in the correct position.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00006341.mp4
# Model Output:
#  1. No
# 2. Form
# 3. The person's form is not aligned properly, with the elbows not positioned correctly.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. The person's form is not aligned properly, with the elbows not positioned correctly.
# Ground Truth Reason: rom

# %% [markdown]
# ## Few-Shot Prompt

# %%
import os
import csv
import torch

csv_path = "exercise_eval_results_part3.csv"
header = ["filename", "predicted_label", "predicted_reason", "ground_truth_label", "ground_truth_reason", "correct"]

# Generation Config
generation_config = dict(
    do_sample=False,
    temperature=0.0,
    max_new_tokens=512,
    top_p=0.1,
    num_beams=1
)

def get_few_shot_examples():
    return """\
Frame1: 
Frame2: 
Frame3: 
Frame4: 
Step-by-step analysis:
1. The eccentric phase is too fast and the concentric is slow.
2. Form is correct.
3. Range of motion is complete.

Answer:
1. No
2. tempo
3. Poor tempo — slow concentric, fast eccentric.

---

Frame1: 
Frame2: 
Frame3: 
Frame4: 
Step-by-step analysis:
1. Tempo is appropriate.
2. Form is incorrect — elbows flare and back arches.
3. Full range of motion is performed.

Answer:
1. No
2. form
3. Incorrect form due to flared elbows and lumbar extension.

---

Frame1: 
Frame2: 
Frame3: 
Frame4: 
Step-by-step analysis:
1. Tempo is appropriate.
2. Form is clean.
3. The person cuts the movement short — doesn’t reach full extension.

Answer:
1. No
2. rom
3. Incomplete range of motion, rep ends early.
---
"""

# CSV Setup
with open(csv_path, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

    for subfolder, ground_truth_reason in categories.items():
        folder_path = os.path.join(root_folder, subfolder)
        for filename in os.listdir(folder_path):
            if filename.endswith(".mp4"):
                video_path = os.path.join(folder_path, filename)
                print(f"\nEvaluating: {subfolder}/{filename}")
                try:
                    with torch.no_grad():
                        pixel_values, num_patches_list = load_video(video_path, num_segments=64, max_num=1)
                        pixel_values = pixel_values.to(torch.bfloat16).to(model.device)

                        # Construct video input for the model
                        video_prefix = "".join([f"Frame{i+1}: \n" for i in range(len(num_patches_list))])

                        # Prompt with CoT + few-shot
                        prompt = f"""
We are evaluating whether a video clip of an exercise is being performed correctly for hypertrophy training.

Please follow these steps:
1. Evaluate the **tempo**. Is the eccentric phase slow and the concentric explosive?
2. Evaluate the **form**. Are joints aligned and posture stable?
3. Evaluate the **range of motion**. Is the motion full from start to end?

Use this format:
1. Yes / No
2. tempo / form / rom (if No)
3. Brief explanation of the issue.

Now analyze the next video:
"""

                        full_prompt = get_few_shot_examples() + video_prefix + prompt

                        output, _ = model.chat(
                            tokenizer, pixel_values, full_prompt, generation_config,
                            num_patches_list=num_patches_list, history=None, return_history=True
                        )

                        print("Model Output: \n", output)

                        # Process model response
                        lines = [line.strip() for line in output.strip().splitlines() if line.strip()]
                        predicted_label = "Unclear"
                        predicted_reason = "unclear"
                        explanation = ""

                        if len(lines) >= 1:
                            if "yes" in lines[0].lower():
                                predicted_label = "Good"
                                predicted_reason = "none"
                            elif "no" in lines[0].lower():
                                predicted_label = "Bad"
                                if len(lines) >= 2:
                                    if "tempo" in lines[1].lower():
                                        predicted_reason = "tempo"
                                    elif "form" in lines[1].lower():
                                        predicted_reason = "form"
                                    elif "rom" in lines[1].lower() or "range" in lines[1].lower():
                                        predicted_reason = "rom"
                                    else:
                                        predicted_reason = "unclear"
                                if len(lines) >= 3:
                                    explanation = lines[2]

                        print("Predicted Label:", predicted_label)
                        print("Predicted Reason:", predicted_reason)
                        print("Explanation:", explanation)
                        print("Ground Truth Reason:", ground_truth_reason)

                        writer.writerow([
                            filename,
                            predicted_label,
                            predicted_reason,
                            "Bad",
                            ground_truth_reason,
                            predicted_label == "Bad" and predicted_reason == ground_truth_reason
                        ])
                except Exception as e:
                    print(f"Error processing {filename}: {e}")
# Out:
# Evaluating: bad_tempo/00012249.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00011556.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00016532.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00023161.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072444.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom
# 3. The tempo is too fast, and the form is incorrect with flared elbows and lumbar extension. The range of motion is not full, as the person cuts the movement short.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The tempo is too fast, and the form is incorrect with flared elbows and lumbar extension. The range of motion is not full, as the person cuts the movement short.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00059311.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00066581.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00229773.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00029963.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00046088.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00023949.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013106.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00239845.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00017048.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00235069.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018821.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00014632.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00238832.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00024722.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00258229.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00286641.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00291149.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00066392.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072413.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00062102.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00230184.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00268039.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013434.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018275.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00042853.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064538.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036057.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00002281.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00034681.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036501.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00024667.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00002408.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00072033.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00063198.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00050198.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037016.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00015940.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00074679.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00027507.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00008409.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00272872.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00230586.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00247622.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00038776.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00268734.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037346.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00005636.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00271325.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00239670.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00013496.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00025620.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283446.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00012588.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00269501.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00246049.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00037722.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00289062.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00246765.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00054254.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00287232.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064039.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00051104.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00296494.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00053253.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00231364.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00048538.mp4
# Model Output:
#  1. No
# 2. form
# 3. Elbows flare and back arches, indicating incorrect form.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Elbows flare and back arches, indicating incorrect form.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00062444.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00018140.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00053044.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00011496.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00064975.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00231220.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00041812.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00007380.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00036778.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00290008.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00259571.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00071162.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00021800.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00052183.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00274174.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom (if No)
# 3. The tempo is too fast and the form is incorrect due to flared elbows and lumbar extension. The range of motion is not complete as the person cuts the movement short.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The tempo is too fast and the form is incorrect due to flared elbows and lumbar extension. The range of motion is not complete as the person cuts the movement short.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00273574.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00249865.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00019322.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00057922.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00006465.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00032740.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00060934.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00247114.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00039298.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00282824.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283360.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00283462.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00052625.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_tempo/00049807.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: tempo
#
# Evaluating: bad_form/00264059.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00258716.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00298054.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00056422.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00245832.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00289458.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00254654.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00264754.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00257040.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00259695.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00232934.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00026364.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00273762.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00271676.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00231356.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00236461.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00263762.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00270565.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00005486.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00243778.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00272177.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00023278.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00274320.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00248276.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00235407.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00268401.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00260961.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00022393.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00228111.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00233859.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00239371.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00252402.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00248119.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00263916.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00229803.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00270333.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00285771.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00030697.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom (if No)
# 3. The person is performing the exercise with a slow eccentric phase and an explosive concentric phase. The form appears to be correct, with joints aligned and posture stable. The range of motion is full from start to end.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The person is performing the exercise with a slow eccentric phase and an explosive concentric phase. The form appears to be correct, with joints aligned and posture stable. The range of motion is full from start to end.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00281495.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00240669.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00268346.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00228817.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00246007.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00294016.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00255147.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00296516.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00016923.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00062793.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00279540.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00005974.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00254444.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00244851.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00287692.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00240744.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00026308.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00017414.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00064443.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00284788.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00026882.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00054456.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00242829.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00236226.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00236478.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00011926.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00285921.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00010503.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00048047.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00012180.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00025593.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00284320.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00017164.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00266745.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00050517.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00012406.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00073809.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00018766.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00265878.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00023206.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00053230.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00260575.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00268834.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00022513.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00007723.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00047117.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom (if No)
# 3. The tempo is too fast and the concentric phase is slow. The form is correct, and the range of motion is complete.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The tempo is too fast and the concentric phase is slow. The form is correct, and the range of motion is complete.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00001655.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: form
#
# Evaluating: bad_form/00047239.mp4
# Model Output:
#  1. No
# 2. tempo
# ...
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00028182.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00020808.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00040364.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00228275.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00011758.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00295249.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00236587.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00289469.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00237739.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00290919.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00021967.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00033397.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00063225.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00278050.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00257230.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00034540.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00285154.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00281478.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00065480.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00043495.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00065194.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00051144.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00278800.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00057934.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00276184.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00066218.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00273970.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00015772.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00288404.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00252818.mp4
# Model Output:
#  1. No
# 2. form
# 3. Elbows flare and back arches.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Elbows flare and back arches.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00048708.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00045145.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00241350.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00259971.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00060864.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00001497.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Slow concentric, fast eccentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00231630.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00258831.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00234416.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00064409.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom (if No)
# 3. Brief explanation of the issue: The tempo is too fast and the concentric phase is slow. The form is incorrect with flared elbows and lumbar extension. The range of motion is incomplete as the movement ends early.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Brief explanation of the issue: The tempo is too fast and the concentric phase is slow. The form is incorrect with flared elbows and lumbar extension. The range of motion is incomplete as the movement ends early.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00028611.mp4
# Model Output:
#  1. No
# 2. tempo / form / rom (if No)
# 3. The tempo is too fast and the concentric is slow. The form is incorrect with flared elbows and lumbar extension. The range of motion is incomplete as the person cuts the movement short.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. The tempo is too fast and the concentric is slow. The form is incorrect with flared elbows and lumbar extension. The range of motion is incomplete as the person cuts the movement short.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00251797.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00073197.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00043550.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00004965.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00231645.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00054859.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00044079.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00034999.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00002117.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric and slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric and slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00044580.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00264460.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00035725.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Poor tempo — slow concentric, fast eccentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Poor tempo — slow concentric, fast eccentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00053394.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00270085.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00000069.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00251566.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00291965.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00252547.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00072874.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00045196.mp4
# Model Output:
#  1. No
# 2. form
# 3. Incorrect form due to flared elbows and lumbar extension.
# Predicted Label: Bad
# Predicted Reason: form
# Explanation: 3. Incorrect form due to flared elbows and lumbar extension.
# Ground Truth Reason: rom
#
# Evaluating: bad_rom/00006341.mp4
# Model Output:
#  1. No
# 2. tempo
# 3. Fast eccentric, slow concentric.
# Predicted Label: Bad
# Predicted Reason: tempo
# Explanation: 3. Fast eccentric, slow concentric.
# Ground Truth Reason: rom

# %% [markdown]
# # Testing InternVideo (Good and Bad videos)

# %%
import os
import csv
import json
import torch

# Config
root_folder = "/content/drive/MyDrive/VR/Visual_Recognition/good_bad_videos"
generation_config = dict(
    do_sample=False,
    temperature=0.2,
    max_new_tokens=512,
    top_p=0.1,
    num_beams=1
)

header = ["filename", "predicted_label", "ground_truth_label", "explanation", "correct"]

def ensure_csv_with_header(csv_path):
    if not os.path.exists(csv_path):
        with open(csv_path, mode='w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(header)

def evaluate_category(reasoning_category, prompt):
    """
    Evaluate both bad and good examples for a given reasoning category.
    Saves results incrementally to a single CSV file.
    """
    print(f"\n=== Evaluating Category: {reasoning_category.upper()} ===")

    csv_path = f"exercise_eval_results_{reasoning_category}.csv"
    ensure_csv_with_header(csv_path)

    cases = [
        ("bad", f"bad_{reasoning_category}_250", f"selected_bad_{reasoning_category}_250.json"),
        ("good", f"good_{reasoning_category}_250", f"selected_good_{reasoning_category}_250.json")
    ]

    for label_type, folder_name, json_file in cases:
        ground_truth_label = "Bad" if label_type == "bad" else "Good"

        json_path = os.path.join(root_folder, json_file)
        folder_path = os.path.join(root_folder, folder_name)

        if not os.path.exists(json_path) or not os.path.exists(folder_path):
            print(f"Skipping: {json_path} or {folder_path} not found.")
            continue

        with open(json_path, "r") as f:
            items = json.load(f)

        # Sort deterministically
        items.sort(key=lambda item: os.path.basename(item["video_path"]))
        # items = items[:5]
        total = len(items)

        for idx, item in enumerate(items, start=1):
            filename = os.path.basename(item["video_path"])
            video_path = os.path.join(folder_path, filename)

            if not os.path.exists(video_path):
                print(f"File not found: {video_path}")
                continue

            print(f"\n[{idx}/{total}] Evaluating {label_type.upper()} video: {filename}")

            try:
                with torch.no_grad():
                    pixel_values, num_patches_list = load_video(video_path, num_segments=64, max_num=1)
                    pixel_values = pixel_values.to(torch.bfloat16).to(model.device)
                    video_prefix = "".join([f"Frame{i+1}: \n" for i in range(len(num_patches_list))])

                    question = video_prefix + prompt
                    output, _ = model.chat(
                        tokenizer, pixel_values, question, generation_config,
                        num_patches_list=num_patches_list, history=None, return_history=True
                    )

                    lines = [line.strip() for line in output.strip().splitlines() if line.strip()]
                    predicted_label = "Unclear"
                    explanation = ""

                    if len(lines) >= 1:
                        if "yes" in lines[0].lower():
                            predicted_label = "Good"
                        elif "no" in lines[0].lower():
                            predicted_label = "Bad"
                        if len(lines) >= 2:
                            explanation = lines[1]

                    correct = (predicted_label == ground_truth_label)

                    print(f"Predicted: {predicted_label} | GT: {ground_truth_label} | Correct: {correct}")
                    print("Explanation:", explanation)

                    # Write result immediately
                    with open(csv_path, mode='a', newline='') as f:
                        writer = csv.writer(f)
                        writer.writerow([
                            filename,
                            predicted_label,
                            ground_truth_label,
                            explanation,
                            correct
                        ])

            except Exception as e:
                print(f"Error processing {filename}: {e}")

# %%
# Evaluate Tempo
prompt = f"""

You are a highly experienced personal trainer. Your task is to evaluate the **tempo** of the exercise shown in this video clip.

Focus only on the **overall speed of each repetition**.

Guidelines:
- The perfect repetition should be balanced (1-2 seconds).
- A **very very fast** repetition (less than 1 second total) may indicate rushing or poor control.
- A **very very slow** repetition (more than 3–4 seconds) may indicate inefficiency or loss of intensity.
- Ignore all other aspects like form or range of motion.

Note:
These videos are performed by amateurs, not professionals, but also trying to improve the efficiency of the workout.
Only call out clear tempo issues (e.g., obviously too fast or too slow).
Do not penalize minor imperfections in speed or rhythm.

Now answer the following:

**Is this exercise being performed at a correct and balanced tempo?**

Respond using only the following format:
1. Yes / No
2. One-sentence explanation describing your reasoning.
"""

evaluate_category("tempo", prompt)
# Out:
# === Evaluating Category: TEMPO ===
#
# [1/250] Evaluating BAD video: 00001649.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [2/250] Evaluating BAD video: 00001716.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [3/250] Evaluating BAD video: 00001724.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [4/250] Evaluating BAD video: 00002281.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [5/250] Evaluating BAD video: 00002408.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [6/250] Evaluating BAD video: 00002549.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [7/250] Evaluating BAD video: 00003135.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [8/250] Evaluating BAD video: 00004230.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [9/250] Evaluating BAD video: 00004309.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [10/250] Evaluating BAD video: 00005636.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [11/250] Evaluating BAD video: 00006360.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [12/250] Evaluating BAD video: 00006465.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [13/250] Evaluating BAD video: 00006726.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [14/250] Evaluating BAD video: 00007380.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [15/250] Evaluating BAD video: 00007437.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [16/250] Evaluating BAD video: 00008409.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [17/250] Evaluating BAD video: 00009510.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [18/250] Evaluating BAD video: 00010721.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [19/250] Evaluating BAD video: 00010731.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [20/250] Evaluating BAD video: 00011161.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [21/250] Evaluating BAD video: 00011203.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [22/250] Evaluating BAD video: 00011496.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [23/250] Evaluating BAD video: 00011556.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [24/250] Evaluating BAD video: 00012249.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [25/250] Evaluating BAD video: 00012283.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [26/250] Evaluating BAD video: 00012588.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [27/250] Evaluating BAD video: 00012958.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [28/250] Evaluating BAD video: 00012971.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [29/250] Evaluating BAD video: 00013106.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very fast tempo, with the movements blurring together.
#
# [30/250] Evaluating BAD video: 00013434.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [31/250] Evaluating BAD video: 00013496.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [32/250] Evaluating BAD video: 00013564.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [33/250] Evaluating BAD video: 00014209.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very fast tempo, with repetitions appearing to be less than 1 second each.
#
# [34/250] Evaluating BAD video: 00014632.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [35/250] Evaluating BAD video: 00014962.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [36/250] Evaluating BAD video: 00015940.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [37/250] Evaluating BAD video: 00016532.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [38/250] Evaluating BAD video: 00016953.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very fast tempo, with each repetition lasting less than 1 second.
#
# [39/250] Evaluating BAD video: 00017048.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [40/250] Evaluating BAD video: 00017082.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [41/250] Evaluating BAD video: 00018140.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [42/250] Evaluating BAD video: 00018234.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [43/250] Evaluating BAD video: 00018275.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [44/250] Evaluating BAD video: 00018381.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [45/250] Evaluating BAD video: 00018821.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [46/250] Evaluating BAD video: 00019322.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [47/250] Evaluating BAD video: 00020424.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [48/250] Evaluating BAD video: 00020889.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [49/250] Evaluating BAD video: 00021800.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [50/250] Evaluating BAD video: 00021840.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [51/250] Evaluating BAD video: 00022185.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [52/250] Evaluating BAD video: 00022570.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [53/250] Evaluating BAD video: 00022770.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [54/250] Evaluating BAD video: 00023161.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [55/250] Evaluating BAD video: 00023949.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [56/250] Evaluating BAD video: 00024546.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very fast tempo, with repetitions appearing to be less than 1 second each.
#
# [57/250] Evaluating BAD video: 00024667.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [58/250] Evaluating BAD video: 00024722.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [59/250] Evaluating BAD video: 00025620.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [60/250] Evaluating BAD video: 00027507.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [61/250] Evaluating BAD video: 00027594.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [62/250] Evaluating BAD video: 00028786.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [63/250] Evaluating BAD video: 00029963.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [64/250] Evaluating BAD video: 00031004.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [65/250] Evaluating BAD video: 00032121.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [66/250] Evaluating BAD video: 00032740.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [67/250] Evaluating BAD video: 00032919.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [68/250] Evaluating BAD video: 00032987.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [69/250] Evaluating BAD video: 00033173.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [70/250] Evaluating BAD video: 00033405.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [71/250] Evaluating BAD video: 00034026.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [72/250] Evaluating BAD video: 00034043.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [73/250] Evaluating BAD video: 00034677.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [74/250] Evaluating BAD video: 00034681.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [75/250] Evaluating BAD video: 00034808.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [76/250] Evaluating BAD video: 00035042.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [77/250] Evaluating BAD video: 00035221.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [78/250] Evaluating BAD video: 00035771.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [79/250] Evaluating BAD video: 00035909.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [80/250] Evaluating BAD video: 00036057.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [81/250] Evaluating BAD video: 00036501.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [82/250] Evaluating BAD video: 00036778.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [83/250] Evaluating BAD video: 00037016.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [84/250] Evaluating BAD video: 00037346.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [85/250] Evaluating BAD video: 00037722.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [86/250] Evaluating BAD video: 00038776.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [87/250] Evaluating BAD video: 00039298.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [88/250] Evaluating BAD video: 00039299.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [89/250] Evaluating BAD video: 00041281.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [90/250] Evaluating BAD video: 00041812.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [91/250] Evaluating BAD video: 00042853.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [92/250] Evaluating BAD video: 00043290.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [93/250] Evaluating BAD video: 00044156.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [94/250] Evaluating BAD video: 00044838.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [95/250] Evaluating BAD video: 00045385.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [96/250] Evaluating BAD video: 00045665.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [97/250] Evaluating BAD video: 00046088.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [98/250] Evaluating BAD video: 00046265.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [99/250] Evaluating BAD video: 00046292.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [100/250] Evaluating BAD video: 00047228.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [101/250] Evaluating BAD video: 00047324.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very fast tempo, with each repetition lasting less than 1 second.
#
# [102/250] Evaluating BAD video: 00048538.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [103/250] Evaluating BAD video: 00048581.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [104/250] Evaluating BAD video: 00049807.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [105/250] Evaluating BAD video: 00049846.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very fast tempo, with repetitions appearing to be less than 1 second each.
#
# [106/250] Evaluating BAD video: 00050198.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, as the repetition takes more than 3-4 seconds.
#
# [107/250] Evaluating BAD video: 00051104.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [108/250] Evaluating BAD video: 00052183.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [109/250] Evaluating BAD video: 00052625.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [110/250] Evaluating BAD video: 00053044.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [111/250] Evaluating BAD video: 00053253.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [112/250] Evaluating BAD video: 00053824.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [113/250] Evaluating BAD video: 00054254.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [114/250] Evaluating BAD video: 00054940.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [115/250] Evaluating BAD video: 00056007.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [116/250] Evaluating BAD video: 00056261.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [117/250] Evaluating BAD video: 00056725.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [118/250] Evaluating BAD video: 00057614.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [119/250] Evaluating BAD video: 00057922.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [120/250] Evaluating BAD video: 00058947.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [121/250] Evaluating BAD video: 00059311.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [122/250] Evaluating BAD video: 00059357.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [123/250] Evaluating BAD video: 00060737.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [124/250] Evaluating BAD video: 00060934.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [125/250] Evaluating BAD video: 00060950.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [126/250] Evaluating BAD video: 00062102.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [127/250] Evaluating BAD video: 00062444.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [128/250] Evaluating BAD video: 00062783.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [129/250] Evaluating BAD video: 00063198.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [130/250] Evaluating BAD video: 00063201.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [131/250] Evaluating BAD video: 00064010.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [132/250] Evaluating BAD video: 00064039.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [133/250] Evaluating BAD video: 00064491.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [134/250] Evaluating BAD video: 00064538.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [135/250] Evaluating BAD video: 00064975.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [136/250] Evaluating BAD video: 00065650.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [137/250] Evaluating BAD video: 00066169.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [138/250] Evaluating BAD video: 00066392.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [139/250] Evaluating BAD video: 00066581.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [140/250] Evaluating BAD video: 00066874.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [141/250] Evaluating BAD video: 00067267.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [142/250] Evaluating BAD video: 00067407.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [143/250] Evaluating BAD video: 00067845.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [144/250] Evaluating BAD video: 00068332.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [145/250] Evaluating BAD video: 00070485.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [146/250] Evaluating BAD video: 00070740.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [147/250] Evaluating BAD video: 00071162.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [148/250] Evaluating BAD video: 00072033.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [149/250] Evaluating BAD video: 00072413.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [150/250] Evaluating BAD video: 00072444.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [151/250] Evaluating BAD video: 00072453.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [152/250] Evaluating BAD video: 00074051.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [153/250] Evaluating BAD video: 00074632.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [154/250] Evaluating BAD video: 00074679.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [155/250] Evaluating BAD video: 00075071.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [156/250] Evaluating BAD video: 00229081.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [157/250] Evaluating BAD video: 00229451.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [158/250] Evaluating BAD video: 00229773.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [159/250] Evaluating BAD video: 00230073.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, taking more than 3-4 seconds for each movement.
#
# [160/250] Evaluating BAD video: 00230121.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [161/250] Evaluating BAD video: 00230184.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [162/250] Evaluating BAD video: 00230586.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [163/250] Evaluating BAD video: 00230837.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [164/250] Evaluating BAD video: 00231032.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [165/250] Evaluating BAD video: 00231220.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [166/250] Evaluating BAD video: 00231364.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [167/250] Evaluating BAD video: 00232650.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [168/250] Evaluating BAD video: 00233876.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [169/250] Evaluating BAD video: 00235069.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [170/250] Evaluating BAD video: 00235772.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The repetitions appear to be performed at a balanced tempo, around 1-2 seconds per repetition.
#
# [171/250] Evaluating BAD video: 00236741.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [172/250] Evaluating BAD video: 00238832.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [173/250] Evaluating BAD video: 00239670.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [174/250] Evaluating BAD video: 00239845.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [175/250] Evaluating BAD video: 00239982.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [176/250] Evaluating BAD video: 00240320.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [177/250] Evaluating BAD video: 00240514.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very fast pace, indicating rushing and poor control.
#
# [178/250] Evaluating BAD video: 00240824.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [179/250] Evaluating BAD video: 00244331.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [180/250] Evaluating BAD video: 00245650.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [181/250] Evaluating BAD video: 00245823.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [182/250] Evaluating BAD video: 00246049.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [183/250] Evaluating BAD video: 00246765.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [184/250] Evaluating BAD video: 00247114.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [185/250] Evaluating BAD video: 00247622.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [186/250] Evaluating BAD video: 00247709.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [187/250] Evaluating BAD video: 00247897.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [188/250] Evaluating BAD video: 00249079.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [189/250] Evaluating BAD video: 00249408.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [190/250] Evaluating BAD video: 00249865.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [191/250] Evaluating BAD video: 00249888.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise appears to be performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [192/250] Evaluating BAD video: 00250921.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [193/250] Evaluating BAD video: 00251412.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [194/250] Evaluating BAD video: 00251886.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [195/250] Evaluating BAD video: 00253960.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [196/250] Evaluating BAD video: 00254590.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [197/250] Evaluating BAD video: 00255675.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [198/250] Evaluating BAD video: 00255783.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [199/250] Evaluating BAD video: 00258229.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [200/250] Evaluating BAD video: 00259571.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [201/250] Evaluating BAD video: 00260088.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [202/250] Evaluating BAD video: 00261334.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [203/250] Evaluating BAD video: 00261714.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [204/250] Evaluating BAD video: 00268039.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, as the repetition takes more than 3-4 seconds.
#
# [205/250] Evaluating BAD video: 00268067.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [206/250] Evaluating BAD video: 00268250.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [207/250] Evaluating BAD video: 00268734.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [208/250] Evaluating BAD video: 00269501.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [209/250] Evaluating BAD video: 00270540.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [210/250] Evaluating BAD video: 00271325.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [211/250] Evaluating BAD video: 00272604.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [212/250] Evaluating BAD video: 00272872.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [213/250] Evaluating BAD video: 00273574.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [214/250] Evaluating BAD video: 00274174.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [215/250] Evaluating BAD video: 00274514.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [216/250] Evaluating BAD video: 00274724.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [217/250] Evaluating BAD video: 00275460.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [218/250] Evaluating BAD video: 00275698.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [219/250] Evaluating BAD video: 00276076.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, which may indicate inefficiency or loss of intensity.
#
# [220/250] Evaluating BAD video: 00276500.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [221/250] Evaluating BAD video: 00277305.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [222/250] Evaluating BAD video: 00278395.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, as the repetition takes more than 3-4 seconds.
#
# [223/250] Evaluating BAD video: 00279463.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [224/250] Evaluating BAD video: 00280508.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very fast tempo, with each repetition appearing to be completed in less than 1 second.
#
# [225/250] Evaluating BAD video: 00282231.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [226/250] Evaluating BAD video: 00282519.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [227/250] Evaluating BAD video: 00282792.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [228/250] Evaluating BAD video: 00282824.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# ...
#
# [176/250] Evaluating GOOD video: 00263635.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [177/250] Evaluating GOOD video: 00263777.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [178/250] Evaluating GOOD video: 00263914.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [179/250] Evaluating GOOD video: 00263943.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [180/250] Evaluating GOOD video: 00263986.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [181/250] Evaluating GOOD video: 00264025.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [182/250] Evaluating GOOD video: 00264168.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [183/250] Evaluating GOOD video: 00264176.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [184/250] Evaluating GOOD video: 00264510.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [185/250] Evaluating GOOD video: 00264923.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [186/250] Evaluating GOOD video: 00265074.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, indicating inefficiency or loss of intensity.
#
# [187/250] Evaluating GOOD video: 00265082.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [188/250] Evaluating GOOD video: 00265200.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [189/250] Evaluating GOOD video: 00265231.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [190/250] Evaluating GOOD video: 00265465.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [191/250] Evaluating GOOD video: 00265646.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [192/250] Evaluating GOOD video: 00265843.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [193/250] Evaluating GOOD video: 00266087.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [194/250] Evaluating GOOD video: 00266184.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [195/250] Evaluating GOOD video: 00266340.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [196/250] Evaluating GOOD video: 00266482.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [197/250] Evaluating GOOD video: 00266611.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, exceeding the recommended 3-4 seconds.
#
# [198/250] Evaluating GOOD video: 00266630.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, exceeding the recommended 3-4 seconds.
#
# [199/250] Evaluating GOOD video: 00266768.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [200/250] Evaluating GOOD video: 00266837.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, exceeding the recommended 3-4 seconds.
#
# [201/250] Evaluating GOOD video: 00266936.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [202/250] Evaluating GOOD video: 00267037.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [203/250] Evaluating GOOD video: 00267516.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [204/250] Evaluating GOOD video: 00267723.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [205/250] Evaluating GOOD video: 00267819.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [206/250] Evaluating GOOD video: 00267821.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [207/250] Evaluating GOOD video: 00267901.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [208/250] Evaluating GOOD video: 00268038.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [209/250] Evaluating GOOD video: 00268188.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [210/250] Evaluating GOOD video: 00268245.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [211/250] Evaluating GOOD video: 00268306.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [212/250] Evaluating GOOD video: 00268329.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [213/250] Evaluating GOOD video: 00268525.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [214/250] Evaluating GOOD video: 00268571.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [215/250] Evaluating GOOD video: 00268611.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very fast tempo, with repetitions appearing to be less than 1 second each.
#
# [216/250] Evaluating GOOD video: 00270272.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, taking more than 3-4 seconds for each repetition.
#
# [217/250] Evaluating GOOD video: 00270383.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [218/250] Evaluating GOOD video: 00271031.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [219/250] Evaluating GOOD video: 00271092.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [220/250] Evaluating GOOD video: 00271630.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [221/250] Evaluating GOOD video: 00272216.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [222/250] Evaluating GOOD video: 00272306.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [223/250] Evaluating GOOD video: 00272909.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [224/250] Evaluating GOOD video: 00273115.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [225/250] Evaluating GOOD video: 00275621.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, as the repetition takes more than 3-4 seconds.
#
# [226/250] Evaluating GOOD video: 00275747.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [227/250] Evaluating GOOD video: 00276008.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [228/250] Evaluating GOOD video: 00279981.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise appears to be performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [229/250] Evaluating GOOD video: 00280084.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [230/250] Evaluating GOOD video: 00282212.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, exceeding the recommended 3-4 seconds per repetition.
#
# [231/250] Evaluating GOOD video: 00282370.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [232/250] Evaluating GOOD video: 00282488.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [233/250] Evaluating GOOD video: 00282837.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [234/250] Evaluating GOOD video: 00282937.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [235/250] Evaluating GOOD video: 00283046.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, exceeding the recommended 3-4 seconds per repetition.
#
# [236/250] Evaluating GOOD video: 00283206.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [237/250] Evaluating GOOD video: 00283702.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [238/250] Evaluating GOOD video: 00284157.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [239/250] Evaluating GOOD video: 00284410.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition taking approximately 1-2 seconds.
#
# [240/250] Evaluating GOOD video: 00284598.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [241/250] Evaluating GOOD video: 00284874.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, as it takes more than 3-4 seconds for each repetition.
#
# [242/250] Evaluating GOOD video: 00285577.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [243/250] Evaluating GOOD video: 00293032.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [244/250] Evaluating GOOD video: 00293042.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The exercise is being performed at a balanced tempo, with each repetition lasting approximately 1-2 seconds.
#
# [245/250] Evaluating GOOD video: 00293891.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [246/250] Evaluating GOOD video: 00294493.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [247/250] Evaluating GOOD video: 00296561.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The repetitions appear to be performed at a very slow tempo, exceeding the recommended 3-4 seconds per repetition.
#
# [248/250] Evaluating GOOD video: 00297232.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [249/250] Evaluating GOOD video: 00297519.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.
#
# [250/250] Evaluating GOOD video: 00297870.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The exercise is being performed at a very slow tempo, with each repetition taking more than 3-4 seconds.

# %%
# Evaluate Form
prompt = f"""

You are a highly experienced personal trainer. Your task is to evaluate the **form** of the exercise shown in this video clip.

Focus only on **body alignment and control** during the movement.

Guidelines:
- Watch for **sloppy form**, such as lack of control or inconsistent motion.
- Check for **poor posture**, like a rounded back, knees caving in, or wrists bending awkwardly.
- Watch for **exaggerated movements**, such as knees bending too much, arms locking out too much, or overextension too much.
- Ignore aspects like tempo or range of motion (e.g., how far the person goes — unless it's clearly due to bad form).

Note:
These videos are performed by **amateurs**, not professionals, but they are trying to exercise safely and effectively.
Only flag **obvious form problems** that may reduce safety or efficiency.
Do not penalize small imperfections.

Now answer the following:

**Is this exercise being performed with correct and safe form?**

Respond using only the following format:
1. Yes / No
2. One-sentence explanation describing your reasoning.
"""

evaluate_category("form", prompt)
# Out:
# === Evaluating Category: FORM ===
#
# [1/250] Evaluating BAD video: 00001051.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not positioned correctly, which can lead to poor posture and potential strain.
#
# [2/250] Evaluating BAD video: 00001087.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not in a neutral position, which can lead to poor posture and potential strain on the neck and back.
#
# [3/250] Evaluating BAD video: 00001655.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are not aligned properly, which can lead to poor posture and potential injury.
#
# [4/250] Evaluating BAD video: 00002436.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in an inconsistent manner.
#
# [5/250] Evaluating BAD video: 00002553.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [6/250] Evaluating BAD video: 00002820.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of control and potential strain on the lower back.
#
# [7/250] Evaluating BAD video: 00003707.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, indicating poor posture and lack of control.
#
# [8/250] Evaluating BAD video: 00004827.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain and injury. The arms are not fully extended, and the legs are not fully straight, which can reduce the effectiveness of the exercise.
#
# [9/250] Evaluating BAD video: 00004947.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [10/250] Evaluating BAD video: 00005486.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [11/250] Evaluating BAD video: 00005974.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [12/250] Evaluating BAD video: 00007723.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [13/250] Evaluating BAD video: 00008536.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, which can lead to poor posture and potential strain.
#
# [14/250] Evaluating BAD video: 00010209.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury. Additionally, the arms are not maintaining a neutral position, which can affect the overall stability of the exercise.
#
# [15/250] Evaluating BAD video: 00010503.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are not moving in a controlled manner, and their posture is not optimal.
#
# [16/250] Evaluating BAD video: 00011125.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the arms are not reaching towards the feet, indicating poor form and control.
#
# [17/250] Evaluating BAD video: 00011260.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are bending too much, indicating poor posture and potential strain on the lower back.
#
# [18/250] Evaluating BAD video: 00011926.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of control and potential strain.
#
# [19/250] Evaluating BAD video: 00012180.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can indicate a lack of control and potential strain on the back.
#
# [20/250] Evaluating BAD video: 00012406.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not in a neutral position, indicating poor posture and potential strain on the back.
#
# [21/250] Evaluating BAD video: 00012678.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, indicating poor posture and form.
#
# [22/250] Evaluating BAD video: 00012835.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate poor posture and potential strain. Additionally, the arms are not fully extended, which may affect the effectiveness of the exercise.
#
# [23/250] Evaluating BAD video: 00013900.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate poor posture and potential strain.
#
# [24/250] Evaluating BAD video: 00014155.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back arches excessively, and the arms are not fully extended, indicating potential lack of control and form.
#
# [25/250] Evaluating BAD video: 00014696.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [26/250] Evaluating BAD video: 00015502.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are not moving in a controlled manner, and their posture is not optimal.
#
# [27/250] Evaluating BAD video: 00015929.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury.
#
# [28/250] Evaluating BAD video: 00016923.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [29/250] Evaluating BAD video: 00016943.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not fully extended, indicating poor posture and form.
#
# [30/250] Evaluating BAD video: 00017042.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [31/250] Evaluating BAD video: 00017164.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of proper form and control during the exercise.
#
# [32/250] Evaluating BAD video: 00017414.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [33/250] Evaluating BAD video: 00017429.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The person maintains a straight back and controlled arm movements, indicating correct and safe form.
#
# [34/250] Evaluating BAD video: 00018173.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of proper form and control during the exercise.
#
# [35/250] Evaluating BAD video: 00018193.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's legs are not fully extended, and the arms are not reaching towards the feet, indicating a lack of proper form and control.
#
# [36/250] Evaluating BAD video: 00018766.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are not aligned properly, indicating poor posture and potential risk of injury.
#
# [37/250] Evaluating BAD video: 00018989.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is bending backward, which can lead to loss of control and potential injury.
#
# [38/250] Evaluating BAD video: 00019343.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the back.
#
# [39/250] Evaluating BAD video: 00019645.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can indicate a lack of control and potential strain on the lower back.
#
# [40/250] Evaluating BAD video: 00020075.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not aligned properly, which can lead to strain on the neck and back.
#
# [41/250] Evaluating BAD video: 00020200.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of control and potential strain on the back.
#
# [42/250] Evaluating BAD video: 00021131.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate poor posture and potential strain.
#
# [43/250] Evaluating BAD video: 00021369.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate poor posture and potential strain on the back.
#
# [44/250] Evaluating BAD video: 00022393.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in an inconsistent manner.
#
# [45/250] Evaluating BAD video: 00022513.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's knees are caving in, which can lead to poor posture and potential injury.
#
# [46/250] Evaluating BAD video: 00023206.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their knees are not aligned with their ankles, indicating poor posture and potential strain on the lower back.
#
# [47/250] Evaluating BAD video: 00023278.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their core is not engaged, which can lead to strain on the neck and shoulders.
#
# [48/250] Evaluating BAD video: 00023629.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain and injury. The arms are not positioned correctly, and the legs are not straight, which can affect the effectiveness of the exercise.
#
# [49/250] Evaluating BAD video: 00023760.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the back.
#
# [50/250] Evaluating BAD video: 00024907.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can indicate a lack of proper form and control during the exercise.
#
# [51/250] Evaluating BAD video: 00025012.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is bending forward with their back rounded, which can lead to strain on the back and poor posture.
#
# [52/250] Evaluating BAD video: 00025593.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not aligned with their spine, which can lead to strain on the neck and back.
#
# [53/250] Evaluating BAD video: 00025893.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, which can lead to poor posture and potential strain.
#
# [54/250] Evaluating BAD video: 00025907.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the arms are not reaching towards the feet, indicating poor form and control.
#
# [55/250] Evaluating BAD video: 00025920.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and the leg movement is not controlled, which can lead to potential strain or injury.
#
# [56/250] Evaluating BAD video: 00026308.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not aligned with their spine, which can lead to strain on the neck and back.
#
# [57/250] Evaluating BAD video: 00026364.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [58/250] Evaluating BAD video: 00026882.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not fully extended, which can lead to poor posture and lack of control during the exercise.
#
# [59/250] Evaluating BAD video: 00029323.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are not aligned properly, indicating poor posture and form.
#
# [60/250] Evaluating BAD video: 00029940.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [61/250] Evaluating BAD video: 00030487.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury.
#
# [62/250] Evaluating BAD video: 00030697.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be sloppy, with exaggerated movements and lack of control, particularly noticeable in the arm and leg motions.
#
# [63/250] Evaluating BAD video: 00031558.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain and injury. Additionally, the arms are not fully extended, which may reduce the effectiveness of the exercise.
#
# [64/250] Evaluating BAD video: 00032222.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are not aligned properly, which can lead to potential injury and inefficiency.
#
# [65/250] Evaluating BAD video: 00033067.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [66/250] Evaluating BAD video: 00034332.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain. The arms are not fully extended, and the legs are not straight, which can affect the effectiveness of the exercise.
#
# [67/250] Evaluating BAD video: 00035812.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the arms are not maintaining a straight line, indicating potential form issues.
#
# [68/250] Evaluating BAD video: 00036064.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [69/250] Evaluating BAD video: 00036183.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and potential strain on the back.
#
# [70/250] Evaluating BAD video: 00037535.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, which can lead to strain on the neck and back.
#
# [71/250] Evaluating BAD video: 00037544.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched excessively, and their arms are not fully extended, which can lead to potential strain and reduced effectiveness of the exercise.
#
# [72/250] Evaluating BAD video: 00037852.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury.
#
# [73/250] Evaluating BAD video: 00037947.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury. Additionally, the arms are not fully extended, which may reduce the effectiveness of the exercise.
#
# [74/250] Evaluating BAD video: 00037963.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form is inconsistent, with exaggerated movements and lack of control, particularly noticeable in the leg movements.
#
# [75/250] Evaluating BAD video: 00038639.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can indicate a lack of proper form and control during the exercise.
#
# [76/250] Evaluating BAD video: 00039996.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury. Additionally, the arms are not fully extended, which may reduce the effectiveness of the exercise.
#
# [77/250] Evaluating BAD video: 00040979.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not in a neutral position, which can lead to poor posture and potential injury.
#
# [78/250] Evaluating BAD video: 00041404.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, which can lead to poor posture and potential strain.
#
# [79/250] Evaluating BAD video: 00042206.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, and their arms are not maintaining a straight line, indicating poor form and potential risk of injury.
#
# [80/250] Evaluating BAD video: 00042887.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and the arms are not fully extended, indicating poor posture and form.
#
# [81/250] Evaluating BAD video: 00043168.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can indicate a lack of control and potential strain on the back.
#
# [82/250] Evaluating BAD video: 00043787.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [83/250] Evaluating BAD video: 00044296.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [84/250] Evaluating BAD video: 00044398.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury.
#
# [85/250] Evaluating BAD video: 00045264.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are bending too much, indicating poor posture and potential strain on the lower back.
#
# [86/250] Evaluating BAD video: 00047117.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The person maintains a straight back and controlled arm movements throughout the exercise.
#
# [87/250] Evaluating BAD video: 00047239.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The individual maintains a straight back and controlled arm movements, ensuring proper form and safety during the exercise.
#
# [88/250] Evaluating BAD video: 00048045.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury. Additionally, the arms are not maintaining a neutral position, which can affect the overall stability and effectiveness of the exercise.
#
# [89/250] Evaluating BAD video: 00048047.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the lower back is not properly supported, which could lead to poor posture and potential discomfort.
#
# [90/250] Evaluating BAD video: 00048263.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, indicating poor posture and form.
#
# [91/250] Evaluating BAD video: 00050458.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the back.
#
# [92/250] Evaluating BAD video: 00050517.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can indicate a lack of proper form and control during the exercise.
#
# [93/250] Evaluating BAD video: 00051696.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, indicating poor posture and form.
#
# [94/250] Evaluating BAD video: 00051952.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential loss of control during the high kicks.
#
# [95/250] Evaluating BAD video: 00052683.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain and injury. Additionally, the arms are not fully extended, and the legs are not fully elevated, which can reduce the effectiveness of the exercise.
#
# [96/250] Evaluating BAD video: 00052784.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and potential strain on the back.
#
# [97/250] Evaluating BAD video: 00053009.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, which can lead to strain and potential injury.
#
# [98/250] Evaluating BAD video: 00053230.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of control and potential strain on the back.
#
# [99/250] Evaluating BAD video: 00053835.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the arms are not reaching towards the feet, indicating poor form and control.
#
# [100/250] Evaluating BAD video: 00053925.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, indicating poor form and potential risk of injury.
#
# [101/250] Evaluating BAD video: 00054456.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of control and potential strain.
#
# [102/250] Evaluating BAD video: 00056422.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential loss of control during the movements.
#
# [103/250] Evaluating BAD video: 00059141.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [104/250] Evaluating BAD video: 00060097.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, and their arms are not fully extended, indicating poor form and potential risk of injury.
#
# [105/250] Evaluating BAD video: 00061747.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not positioned correctly, which can lead to poor posture and potential injury.
#
# [106/250] Evaluating BAD video: 00062397.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [107/250] Evaluating BAD video: 00062793.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's lower back is arched, which can lead to strain and injury. Additionally, the leg movement is not controlled, with the knee bending too much and the foot not reaching a full extension.
#
# [108/250] Evaluating BAD video: 00064443.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of proper form and control during the exercise.
#
# [109/250] Evaluating BAD video: 00066714.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [110/250] Evaluating BAD video: 00067417.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's lower back is arching excessively, and the arms are not maintaining a straight line, indicating potential strain and inefficient form.
#
# [111/250] Evaluating BAD video: 00068028.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are moving in a circular motion, but there is a lack of control and consistency in the movement.
#
# [112/250] Evaluating BAD video: 00068439.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [113/250] Evaluating BAD video: 00069105.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, and their arms are not fully extended, which can lead to poor posture and potential strain.
#
# [114/250] Evaluating BAD video: 00069319.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not fully extended, indicating poor posture and form.
#
# [115/250] Evaluating BAD video: 00069583.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain and is not a safe form for the exercise.
#
# [116/250] Evaluating BAD video: 00070137.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their knees are not aligned properly, which can lead to strain and potential injury.
#
# [117/250] Evaluating BAD video: 00071054.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the back.
#
# [118/250] Evaluating BAD video: 00071090.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form is inconsistent, with exaggerated movements and potential overextension, which may reduce safety and efficiency.
#
# [119/250] Evaluating BAD video: 00071409.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arching excessively, and their arms are not fully extended, indicating poor form and potential risk of injury.
#
# [120/250] Evaluating BAD video: 00071432.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's knees are bending too much, which can lead to potential knee strain.
#
# [121/250] Evaluating BAD video: 00071732.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their knees are not aligned with their ankles, indicating poor posture and potential strain on the lower back.
#
# [122/250] Evaluating BAD video: 00072590.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in an inconsistent manner.
#
# [123/250] Evaluating BAD video: 00073594.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, which can lead to poor posture and potential strain.
#
# [124/250] Evaluating BAD video: 00073648.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [125/250] Evaluating BAD video: 00073809.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's knees are caving in and their back is rounded, indicating poor posture and lack of control.
#
# [126/250] Evaluating BAD video: 00074009.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the back.
#
# [127/250] Evaluating BAD video: 00075675.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and their arms are not fully extended, indicating poor form and potential risk of injury.
#
# [128/250] Evaluating BAD video: 00075857.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are not moving in a controlled manner, and their posture appears to be slightly slouched.
#
# [129/250] Evaluating BAD video: 00075940.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the arms are not reaching fully, indicating a lack of control and proper form.
#
# [130/250] Evaluating BAD video: 00228111.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [131/250] Evaluating BAD video: 00228817.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [132/250] Evaluating BAD video: 00229799.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [133/250] Evaluating BAD video: 00229803.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [134/250] Evaluating BAD video: 00231356.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [135/250] Evaluating BAD video: 00231937.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [136/250] Evaluating BAD video: 00232934.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [137/250] Evaluating BAD video: 00233859.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's form appears to be inconsistent, with exaggerated movements and potential overextension, which may reduce the safety and efficiency of the exercise.
#
# [138/250] Evaluating BAD video: 00235137.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, and the arms are not fully extended, indicating poor posture and form.
#
# [139/250] Evaluating BAD video: 00235215.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's form shows a lack of control and stability, particularly in the lower body, which may lead to injury or inefficiency.
#
# [140/250] Evaluating BAD video: 00235407.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [141/250] Evaluating BAD video: 00235831.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's form shows exaggerated movements, particularly in the arm and leg positions, which may reduce the safety and efficiency of the exercise.
#
# [142/250] Evaluating BAD video: 00236226.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are not moving in a controlled manner, and their posture is not optimal.
#
# [143/250] Evaluating BAD video: 00236340.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [144/250] Evaluating BAD video: 00236461.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's form shows a lack of control and stability, with the body not maintaining a straight line and the arms extending too far forward.
#
# [145/250] Evaluating BAD video: 00236478.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The person maintains a straight back and controlled movements throughout the exercise.
#
# [146/250] Evaluating BAD video: 00237147.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are not moving in a controlled manner; they appear to be extending and retracting without proper form.
#
# [147/250] Evaluating BAD video: 00237715.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of control and potential strain.
#
# [148/250] Evaluating BAD video: 00239371.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor form and potential risk of injury.
#
# [149/250] Evaluating BAD video: 00239570.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [150/250] Evaluating BAD video: 00240207.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [151/250] Evaluating BAD video: 00240669.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [152/250] Evaluating BAD video: 00240744.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in a way that may not be efficient or safe.
#
# [153/250] Evaluating BAD video: 00240963.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [154/250] Evaluating BAD video: 00241232.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
#
# [155/250] Evaluating BAD video: 00242286.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [156/250] Evaluating BAD video: 00242685.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [157/250] Evaluating BAD video: 00242795.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and the head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [158/250] Evaluating BAD video: 00242829.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their knees are caving in, indicating poor posture and form.
#
# [159/250] Evaluating BAD video: 00243778.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [160/250] Evaluating BAD video: 00244851.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [161/250] Evaluating BAD video: 00245197.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [162/250] Evaluating BAD video: 00245832.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [163/250] Evaluating BAD video: 00246007.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their core is not engaged, which can lead to poor posture and potential injury.
#
# [164/250] Evaluating BAD video: 00246599.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [165/250] Evaluating BAD video: 00248119.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [166/250] Evaluating BAD video: 00248276.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [167/250] Evaluating BAD video: 00248933.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [168/250] Evaluating BAD video: 00249410.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's knees are bending too much, and their arms are not staying in a neutral position, which could lead to potential form issues and reduced efficiency.
#
# [169/250] Evaluating BAD video: 00250794.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's form appears to be inconsistent, with exaggerated movements and potential overextension, which may reduce the safety and efficiency of the exercise.
#
# [170/250] Evaluating BAD video: 00250849.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not aligned properly, which can lead to poor posture and potential injury.
#
# [171/250] Evaluating BAD video: 00251717.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with overextension and potential lack of control, which may reduce the safety and efficiency of the exercise.
#
# [172/250] Evaluating BAD video: 00252402.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their arms moving too far away from their body and their knees bending too much. This could potentially lead to injury or inefficiency.
#
# [173/250] Evaluating BAD video: 00254444.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor form and potential risk of injury.
#
# [174/250] Evaluating BAD video: 00254654.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The individual's form appears to be lacking control, particularly in the arm movements, which may reduce the exercise's safety and efficiency.
#
# [175/250] Evaluating BAD video: 00255147.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with knees bending too much and arms extending too far, which may reduce the safety and efficiency of the exercise.
#
# [176/250] Evaluating BAD video: 00257040.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in an inconsistent manner.
#
# [177/250] Evaluating BAD video: 00258086.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, which can lead to strain on the back and neck.
#
# [178/250] Evaluating BAD video: 00258099.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [179/250] Evaluating BAD video: 00258716.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [180/250] Evaluating BAD video: 00258726.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms extending too far, which may reduce the safety and efficiency of the exercise.
#
# [181/250] Evaluating BAD video: 00259695.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [182/250] Evaluating BAD video: 00260575.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The person maintains a steady posture with controlled movements, ensuring safety and efficiency during the exercise.
#
# [183/250] Evaluating BAD video: 00260961.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [184/250] Evaluating BAD video: 00261056.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's legs are not fully extended, and the arms are not reaching towards the feet, indicating poor form and control.
#
# [185/250] Evaluating BAD video: 00261500.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [186/250] Evaluating BAD video: 00261840.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [187/250] Evaluating BAD video: 00263762.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in an exaggerated manner. This could potentially reduce the safety and efficiency of the exercise.
#
# [188/250] Evaluating BAD video: 00263916.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with arms extending too far and potential overextension, which may reduce safety and efficiency.
#
# [189/250] Evaluating BAD video: 00264059.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [190/250] Evaluating BAD video: 00264754.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
#
# [191/250] Evaluating BAD video: 00265878.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their knees are bending too much, indicating poor posture and potential strain on the lower back.
#
# [192/250] Evaluating BAD video: 00266536.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [193/250] Evaluating BAD video: 00266745.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms are not moving in a controlled manner, and their posture is not optimal.
#
# [194/250] Evaluating BAD video: 00268233.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in a way that may not be efficient or safe.
#
# [195/250] Evaluating BAD video: 00268346.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [196/250] Evaluating BAD video: 00268401.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [197/250] Evaluating BAD video: 00268668.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, which can lead to strain on the back and neck.
#
# [198/250] Evaluating BAD video: 00268834.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can indicate a lack of proper form and control during the exercise.
#
# [199/250] Evaluating BAD video: 00269402.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched excessively, and their head is not aligned with their spine, indicating poor posture and potential strain on the back.
#
# [200/250] Evaluating BAD video: 00269555.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not in a neutral position, which can lead to strain on the neck and back.
#
# [201/250] Evaluating BAD video: 00270333.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [202/250] Evaluating BAD video: 00270565.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [203/250] Evaluating BAD video: 00271181.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's lower back is arched, which can lead to strain and is not a safe form for the exercise.
#
# [204/250] Evaluating BAD video: 00271224.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their knees are not aligned with their ankles, indicating poor posture and potential strain on the lower back.
#
# [205/250] Evaluating BAD video: 00271327.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is rounded, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [206/250] Evaluating BAD video: 00271676.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's form appears to be exaggerated, with their knees bending too much and their arms moving in an inconsistent manner.
#
# [207/250] Evaluating BAD video: 00272177.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [208/250] Evaluating BAD video: 00272310.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [209/250] Evaluating BAD video: 00272874.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
# ...
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's back is arched, and the head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [180/250] Evaluating GOOD video: 00257003.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's knees are bending too much, and their arms are not maintaining a consistent position, indicating a lack of control and potential safety issues.
#
# [181/250] Evaluating GOOD video: 00257328.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [182/250] Evaluating GOOD video: 00257611.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's arms are moving in a circular motion, but their body is not maintaining a stable posture. The knees are bending excessively, which could lead to strain or injury.
#
# [183/250] Evaluating GOOD video: 00257654.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The individual maintains a steady posture with controlled movements, ensuring proper body alignment during the exercise.
#
# [184/250] Evaluating GOOD video: 00257698.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's form appears to be inconsistent, with exaggerated movements and potential lack of control.
#
# [185/250] Evaluating GOOD video: 00257755.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [186/250] Evaluating GOOD video: 00258556.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [187/250] Evaluating GOOD video: 00258808.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [188/250] Evaluating GOOD video: 00259084.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [189/250] Evaluating GOOD video: 00259563.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's elbows are flaring out too much, indicating a lack of control and potential strain on the shoulders.
#
# [190/250] Evaluating GOOD video: 00259903.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, and their arms are not locked out properly, which could lead to poor form and potential injury.
#
# [191/250] Evaluating GOOD video: 00260493.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [192/250] Evaluating GOOD video: 00260772.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, and their arms are not staying straight, which can lead to poor posture and potential injury.
#
# [193/250] Evaluating GOOD video: 00261328.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is not straight, and their arms are not positioned correctly, which can lead to poor posture and potential injury.
#
# [194/250] Evaluating GOOD video: 00261807.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their knees are not aligned with their ankles, indicating poor posture and potential strain on the lower back.
#
# [195/250] Evaluating GOOD video: 00262259.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is rounded, and their arms are not fully extended, indicating poor posture and form.
#
# [196/250] Evaluating GOOD video: 00262707.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [197/250] Evaluating GOOD video: 00263249.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [198/250] Evaluating GOOD video: 00263687.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is rounded, and their arms are not fully extended, indicating poor posture and form.
#
# [199/250] Evaluating GOOD video: 00263697.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
#
# [200/250] Evaluating GOOD video: 00263892.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's form appears to be lacking control, with exaggerated movements and potential poor posture.
#
# [201/250] Evaluating GOOD video: 00263987.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is rounded, and their knees are bending too much, indicating poor posture and form.
#
# [202/250] Evaluating GOOD video: 00264987.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's knees are bending too much, and their arms are not maintaining a consistent position, indicating a lack of control and potential safety issues.
#
# [203/250] Evaluating GOOD video: 00265386.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to excessive strain on the joints.
#
# [204/250] Evaluating GOOD video: 00265910.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's knees are caving inwards, which can lead to knee strain and is indicative of poor form.
#
# [205/250] Evaluating GOOD video: 00266224.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's knees are bending too much, which can lead to excessive strain on the joints and potential injury.
#
# [206/250] Evaluating GOOD video: 00266299.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
#
# [207/250] Evaluating GOOD video: 00266979.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is standing still with their hands on their hips, not performing any exercise.
#
# [208/250] Evaluating GOOD video: 00267238.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are caving in and their back is rounded, indicating poor posture and form.
#
# [209/250] Evaluating GOOD video: 00267812.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
#
# [210/250] Evaluating GOOD video: 00267837.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [211/250] Evaluating GOOD video: 00268215.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to excessive strain on the joints.
#
# [212/250] Evaluating GOOD video: 00268539.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's form appears to be lacking control, with excessive arm movements and potential overextension.
#
# [213/250] Evaluating GOOD video: 00268605.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's back is arched, and their arms are not positioned correctly, indicating poor posture and form.
#
# [214/250] Evaluating GOOD video: 00269617.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's knees are caving inwards, which can lead to potential knee injuries and is not a safe form for the exercise.
#
# [215/250] Evaluating GOOD video: 00269915.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [216/250] Evaluating GOOD video: 00270349.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [217/250] Evaluating GOOD video: 00270383.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [218/250] Evaluating GOOD video: 00271540.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, and their arms are not staying in a neutral position, which can lead to poor posture and potential injury.
#
# [219/250] Evaluating GOOD video: 00272187.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to excessive strain on the joints.
#
# [220/250] Evaluating GOOD video: 00273352.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor form and potential risk of injury.
#
# [221/250] Evaluating GOOD video: 00275269.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [222/250] Evaluating GOOD video: 00278044.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's elbows are flaring out too much, indicating a lack of control and potential strain on the shoulders.
#
# [223/250] Evaluating GOOD video: 00279289.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is rounded, and their arms are not straight, indicating poor posture and form.
#
# [224/250] Evaluating GOOD video: 00281620.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their wrists are not aligned properly, which can lead to discomfort or injury.
#
# [225/250] Evaluating GOOD video: 00281779.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their arms are not positioned correctly, which can lead to poor posture and potential injury.
#
# [226/250] Evaluating GOOD video: 00283308.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's form appears to be inconsistent, with the knee bending too much and the upper body leaning forward, which may reduce the safety and efficiency of the exercise.
#
# [227/250] Evaluating GOOD video: 00284692.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [228/250] Evaluating GOOD video: 00284717.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their knees are caving in, indicating poor posture and potential strain on the lower back.
#
# [229/250] Evaluating GOOD video: 00285187.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their knees are not aligned with their hips, indicating poor posture and potential strain on the lower back.
#
# [230/250] Evaluating GOOD video: 00286898.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's arms are swinging too high and their upper body is leaning forward, which can lead to poor posture and potential strain.
#
# [231/250] Evaluating GOOD video: 00287922.mp4
# Predicted: Good | GT: Good | Correct: True
# Explanation: 2. The person maintains a consistent squat depth and keeps their back straight, demonstrating controlled and safe form.
#
# [232/250] Evaluating GOOD video: 00290060.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [233/250] Evaluating GOOD video: 00290095.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is not straight, and their arm is not fully extended, which can lead to poor posture and ineffective exercise.
#
# [234/250] Evaluating GOOD video: 00290856.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched excessively, and their arms are not straight, indicating poor posture and form.
#
# [235/250] Evaluating GOOD video: 00292785.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are caving in, which can lead to knee pain and injury.
#
# [236/250] Evaluating GOOD video: 00293054.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's form appears to be inconsistent, with exaggerated movements and potential overextension, which may reduce the safety and efficiency of the exercise.
#
# [237/250] Evaluating GOOD video: 00293404.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to excessive strain on the joints and potential injury.
#
# [238/250] Evaluating GOOD video: 00293483.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their knees are not aligned properly, indicating poor form and potential risk of injury.
#
# [239/250] Evaluating GOOD video: 00294086.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's knees are bending too much, which can lead to excessive strain on the joints and potential injury.
#
# [240/250] Evaluating GOOD video: 00294368.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is rounded, and their arms are not fully extended, indicating poor posture and form.
#
# [241/250] Evaluating GOOD video: 00295046.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to excessive stress on the joints and potential injury.
#
# [242/250] Evaluating GOOD video: 00295189.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The individual's form appears to be inconsistent, with exaggerated movements and potential overextension, which may reduce the safety and efficiency of the exercise.
#
# [243/250] Evaluating GOOD video: 00295191.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's form appears to be sloppy, with exaggerated movements and lack of control, particularly noticeable in the leg movements and balance.
#
# [244/250] Evaluating GOOD video: 00296201.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [245/250] Evaluating GOOD video: 00296639.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's elbows are flaring out too much, which can put unnecessary stress on the shoulders and wrists.
#
# [246/250] Evaluating GOOD video: 00297061.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and form.
#
# [247/250] Evaluating GOOD video: 00297255.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to excessive strain and potential injury.
#
# [248/250] Evaluating GOOD video: 00297303.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their head is not in a neutral position, indicating poor posture and potential strain on the neck and back.
#
# [249/250] Evaluating GOOD video: 00297405.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's knees are bending too much, which can lead to overextension and potential injury.
#
# [250/250] Evaluating GOOD video: 00298058.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's back is arched, and their arms are not straight, indicating poor posture and lack of control.

# %%
# Evaluate Range of Motion
prompt = f"""

You are a highly experienced personal trainer. Your task is to evaluate the **range of motion** (ROM) of the exercise shown in this video clip.

Focus only on **how much the limbs or body move** during each repetition.

Guidelines:
- Good ROM means completing the movement fully — from start to finish — without cutting it short.
- Flag any **clearly limited motion**, such as not going deep enough in a squat or a push up.
- Ignore all other aspects like form (e.g., posture) or tempo (e.g., speed of the movement).

Note:
These videos are performed by **amateurs**, not professionals, but they are trying to exercise safely and effectively.
Only call out **obvious issues in range of motion** (clearly too short or excessively exaggerated).
Do not penalize small errors. Be lenient! If you see something coming a bit short of range of motion, that's fine. Keep it as good ROM. Only mark bad range of motion when something is CLEARLY wrong.

Now answer the following:

**Is this exercise being performed with a correct and effective range of motion?**

Respond using only the following format:
1. Yes / No
2. One-sentence explanation describing your reasoning.
"""

evaluate_category("rom", prompt)
# Out:
# === Evaluating Category: ROM ===
#
# [1/250] Evaluating BAD video: 00000069.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not extending their legs fully during the exercise, which limits the range of motion.
#
# [2/250] Evaluating BAD video: 00000581.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward movement of the legs. The legs do not reach a full extension during the exercise.
#
# [3/250] Evaluating BAD video: 00000999.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person in the video is not moving their limbs or body enough to complete the exercise fully, indicating a limited range of motion.
#
# [4/250] Evaluating BAD video: 00001497.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the legs not extending fully during the exercise.
#
# [5/250] Evaluating BAD video: 00002117.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are limited and do not appear to be fully extended or retracted during the exercise.
#
# [6/250] Evaluating BAD video: 00004677.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [7/250] Evaluating BAD video: 00004965.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the legs and arms not extending fully during the exercise.
#
# [8/250] Evaluating BAD video: 00005496.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with a full range of motion.
#
# [9/250] Evaluating BAD video: 00006341.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements. The arm movements seem to be repetitive and not fully extended or flexed, indicating a lack of full range of motion.
#
# [10/250] Evaluating BAD video: 00006821.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [11/250] Evaluating BAD video: 00008123.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not extending their leg fully, which limits the range of motion for the exercise.
#
# [12/250] Evaluating BAD video: 00009683.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [13/250] Evaluating BAD video: 00009696.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully up and down.
#
# [14/250] Evaluating BAD video: 00011569.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with a full range of motion.
#
# [15/250] Evaluating BAD video: 00011758.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, as they do not seem to be moving fully from start to finish.
#
# [16/250] Evaluating BAD video: 00014064.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms fully during the exercise, indicating a limited range of motion.
#
# [17/250] Evaluating BAD video: 00015772.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [18/250] Evaluating BAD video: 00015792.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arms do not reach the full height above their head during the exercise, indicating a limited range of motion.
#
# [19/250] Evaluating BAD video: 00017235.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and hands through a full range of motion during the exercise.
#
# [20/250] Evaluating BAD video: 00018259.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [21/250] Evaluating BAD video: 00018912.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not extending their leg fully during the exercise, which limits the range of motion.
#
# [22/250] Evaluating BAD video: 00019086.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, suggesting that the exercise is not being performed fully.
#
# [23/250] Evaluating BAD video: 00019193.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears to be limited, particularly in the upward and downward movements. The exercise is not being performed with a full range of motion.
#
# [24/250] Evaluating BAD video: 00019749.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are limited and do not reach a full range of motion.
#
# [25/250] Evaluating BAD video: 00020658.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, as they do not seem to be moving fully from start to finish.
#
# [26/250] Evaluating BAD video: 00020808.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [27/250] Evaluating BAD video: 00021527.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, suggesting that the exercise is not being performed fully.
#
# [28/250] Evaluating BAD video: 00021967.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their limbs or body enough during the exercise, indicating a limited range of motion.
#
# [29/250] Evaluating BAD video: 00023275.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements. The exercise is not being performed with a full range of motion.
#
# [30/250] Evaluating BAD video: 00023634.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [31/250] Evaluating BAD video: 00024646.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, as they do not seem to be moving fully from start to finish.
#
# [32/250] Evaluating BAD video: 00025724.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upper body movements. The arm movements are not fully extended or retracted, indicating a restricted range of motion.
#
# [33/250] Evaluating BAD video: 00025730.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements. The arms do not reach the full height above the head and do not go low enough during the downward motion.
#
# [34/250] Evaluating BAD video: 00025878.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [35/250] Evaluating BAD video: 00027654.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, as the person does not fully extend or flex their arms during the exercise.
#
# [36/250] Evaluating BAD video: 00027676.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward movement of the legs. The legs do not reach a full extension during the exercise.
#
# [37/250] Evaluating BAD video: 00028182.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward and downward movements of the arms.
#
# [38/250] Evaluating BAD video: 00028611.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [39/250] Evaluating BAD video: 00029154.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, as the movement is not fully completed from start to finish.
#
# [40/250] Evaluating BAD video: 00029470.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not extending their arms fully during the exercise, limiting the range of motion.
#
# [41/250] Evaluating BAD video: 00029757.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [42/250] Evaluating BAD video: 00029858.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and body enough to complete the exercise effectively.
#
# [43/250] Evaluating BAD video: 00029910.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with a full range of motion.
#
# [44/250] Evaluating BAD video: 00030686.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully during the exercise.
#
# [45/250] Evaluating BAD video: 00031179.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, suggesting that the exercise is not being performed fully.
#
# [46/250] Evaluating BAD video: 00033040.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [47/250] Evaluating BAD video: 00033397.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [48/250] Evaluating BAD video: 00033676.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [49/250] Evaluating BAD video: 00034540.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [50/250] Evaluating BAD video: 00034999.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [51/250] Evaluating BAD video: 00035725.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, which do not extend fully.
#
# [52/250] Evaluating BAD video: 00035760.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [53/250] Evaluating BAD video: 00035837.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward arm movements. The arms do not reach a full extension above the head.
#
# [54/250] Evaluating BAD video: 00036305.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, as the person does not fully extend or flex their arms during the exercise.
#
# [55/250] Evaluating BAD video: 00037092.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [56/250] Evaluating BAD video: 00038045.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are limited and do not reach a full range of motion.
#
# [57/250] Evaluating BAD video: 00039415.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, as the movement is not fully completed from start to finish.
#
# [58/250] Evaluating BAD video: 00040364.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [59/250] Evaluating BAD video: 00041490.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [60/250] Evaluating BAD video: 00041598.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the upward movement and not reaching as low as they could during the downward movement.
#
# [61/250] Evaluating BAD video: 00043495.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully to the sides.
#
# [62/250] Evaluating BAD video: 00043550.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [63/250] Evaluating BAD video: 00043554.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [64/250] Evaluating BAD video: 00044079.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [65/250] Evaluating BAD video: 00044207.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, suggesting that the exercise is not being performed fully.
#
# [66/250] Evaluating BAD video: 00044519.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the leg not extending fully during the exercise.
#
# [67/250] Evaluating BAD video: 00044580.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the leg not extending fully during the exercise.
#
# [68/250] Evaluating BAD video: 00045093.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward punching motion. The individual does not seem to be fully extending their arm or reaching the full height of the punch.
#
# [69/250] Evaluating BAD video: 00045145.mp4
# Predicted: Good | GT: Bad | Correct: False
# Explanation: 2. The exercise is being performed with a correct and effective range of motion, as the person completes the arm movements fully from start to finish without any clear limitations.
#
# [70/250] Evaluating BAD video: 00045196.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [71/250] Evaluating BAD video: 00045403.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [72/250] Evaluating BAD video: 00047144.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and hands enough to complete the exercise effectively.
#
# [73/250] Evaluating BAD video: 00047292.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [74/250] Evaluating BAD video: 00048708.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [75/250] Evaluating BAD video: 00048840.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed fully.
#
# [76/250] Evaluating BAD video: 00049502.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with a full range of motion.
#
# [77/250] Evaluating BAD video: 00050457.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [78/250] Evaluating BAD video: 00050587.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [79/250] Evaluating BAD video: 00051144.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed fully.
#
# [80/250] Evaluating BAD video: 00051484.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, as the movement is not fully completed from start to finish.
#
# [81/250] Evaluating BAD video: 00051551.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [82/250] Evaluating BAD video: 00052403.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [83/250] Evaluating BAD video: 00053240.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the leg not extending fully during the exercise.
#
# [84/250] Evaluating BAD video: 00053261.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, which do not seem to reach full extension or flexion.
#
# [85/250] Evaluating BAD video: 00053394.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the shoulder and elbow movements, indicating that the exercise is not being performed fully.
#
# [86/250] Evaluating BAD video: 00054298.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the leg movements, as the leg does not extend fully during the exercise.
#
# [87/250] Evaluating BAD video: 00054859.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms fully in the exercise, indicating a limited range of motion.
#
# [88/250] Evaluating BAD video: 00054879.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully to the sides during the exercise.
#
# [89/250] Evaluating BAD video: 00056136.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [90/250] Evaluating BAD video: 00056627.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears to be limited, particularly in the upward and downward movements. The exercise is not being performed with a full range of motion.
#
# [91/250] Evaluating BAD video: 00056715.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are not fully extended, indicating a limited range of motion.
#
# [92/250] Evaluating BAD video: 00057535.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, as they do not seem to be moving fully from start to finish.
#
# [93/250] Evaluating BAD video: 00057923.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [94/250] Evaluating BAD video: 00057934.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range during the exercise.
#
# [95/250] Evaluating BAD video: 00058282.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears to be limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [96/250] Evaluating BAD video: 00059158.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [97/250] Evaluating BAD video: 00060864.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their limbs or body enough during each repetition, indicating a limited range of motion.
#
# [98/250] Evaluating BAD video: 00061316.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [99/250] Evaluating BAD video: 00062149.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully during the exercise.
#
# [100/250] Evaluating BAD video: 00062434.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, as they do not seem to be moving fully from start to finish.
#
# [101/250] Evaluating BAD video: 00063225.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms up and down fully, indicating a limited range of motion.
#
# [102/250] Evaluating BAD video: 00063638.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [103/250] Evaluating BAD video: 00064049.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the leg not extending fully during the exercise.
#
# [104/250] Evaluating BAD video: 00064236.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the shoulder and arm movements. The arm does not move fully through its range, and the shoulder does not reach the full extent of its motion.
#
# [105/250] Evaluating BAD video: 00064409.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are not fully extended, indicating a limited range of motion.
#
# [106/250] Evaluating BAD video: 00065173.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [107/250] Evaluating BAD video: 00065194.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, which do not reach full extension.
#
# [108/250] Evaluating BAD video: 00065353.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed fully.
#
# [109/250] Evaluating BAD video: 00065415.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [110/250] Evaluating BAD video: 00065480.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [111/250] Evaluating BAD video: 00066055.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms fully in the exercise, indicating a limited range of motion.
#
# [112/250] Evaluating BAD video: 00066218.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, which do not reach a full extension.
#
# [113/250] Evaluating BAD video: 00066997.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully up and down.
#
# [114/250] Evaluating BAD video: 00068059.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms fully during the exercise, indicating a limited range of motion.
#
# [115/250] Evaluating BAD video: 00068097.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their limbs or body enough to complete the exercise fully.
#
# [116/250] Evaluating BAD video: 00068817.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms enough to complete the exercise effectively.
#
# [117/250] Evaluating BAD video: 00069667.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the movement of the arms and upper body. The individual does not seem to be moving their arms fully or deeply during the exercise.
#
# [118/250] Evaluating BAD video: 00069816.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [119/250] Evaluating BAD video: 00069890.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's movements are limited, and they do not complete the full range of motion in their arm movements.
#
# [120/250] Evaluating BAD video: 00071726.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their limbs or body in a full range of motion during the exercise.
#
# [121/250] Evaluating BAD video: 00071768.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements of the arms. The exercise is not being performed with a full range of motion.
#
# [122/250] Evaluating BAD video: 00072122.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward arm movements, which do not reach full extension.
#
# [123/250] Evaluating BAD video: 00072273.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the arm movements, as they do not seem to be moving fully from start to finish.
#
# [124/250] Evaluating BAD video: 00072283.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the leg movement, indicating that the exercise is not being performed fully.
#
# [125/250] Evaluating BAD video: 00072569.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [126/250] Evaluating BAD video: 00072662.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are not reaching full extension, indicating limited range of motion.
#
# [127/250] Evaluating BAD video: 00072845.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [128/250] Evaluating BAD video: 00072874.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [129/250] Evaluating BAD video: 00073197.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward punching motion, which is not fully extended.
#
# [130/250] Evaluating BAD video: 00074243.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [131/250] Evaluating BAD video: 00074725.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [132/250] Evaluating BAD video: 00075307.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and hands through a full range of motion. The movements are limited to the upper chest and head area.
#
# [133/250] Evaluating BAD video: 00075498.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully upwards or bending deeply at the elbows.
#
# [134/250] Evaluating BAD video: 00228275.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully up and down.
#
# [135/250] Evaluating BAD video: 00228505.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [136/250] Evaluating BAD video: 00228706.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's arm movements are not fully extended, indicating a limited range of motion.
#
# [137/250] Evaluating BAD video: 00229033.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully to the sides during the exercise.
#
# [138/250] Evaluating BAD video: 00229501.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [139/250] Evaluating BAD video: 00229537.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [140/250] Evaluating BAD video: 00230016.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the arm movements. The person does not seem to be moving their arms fully through the intended range.
#
# [141/250] Evaluating BAD video: 00231630.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, which do not reach a full extension.
#
# [142/250] Evaluating BAD video: 00231645.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [143/250] Evaluating BAD video: 00233014.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the punching motion.
#
# [144/250] Evaluating BAD video: 00233965.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, with the arms not extending fully during the punching motion.
#
# [145/250] Evaluating BAD video: 00234039.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements of the arms. The person does not seem to be moving their arms fully through the intended range.
#
# [146/250] Evaluating BAD video: 00234097.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [147/250] Evaluating BAD video: 00234416.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [148/250] Evaluating BAD video: 00235179.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms fully during the exercise, indicating a limited range of motion.
#
# [149/250] Evaluating BAD video: 00235862.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward and downward movements. The person does not seem to be moving their arms fully through the range of motion.
#
# [150/250] Evaluating BAD video: 00236039.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [151/250] Evaluating BAD video: 00236141.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [152/250] Evaluating BAD video: 00236336.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears to be limited, particularly in the squatting and standing movements. The movements are not fully completed, indicating a restricted range of motion.
#
# [153/250] Evaluating BAD video: 00236587.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, where the arms do not extend fully.
#
# [154/250] Evaluating BAD video: 00236896.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward arm movements. The arms do not reach a full extension above the head.
#
# [155/250] Evaluating BAD video: 00236941.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [156/250] Evaluating BAD video: 00237442.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [157/250] Evaluating BAD video: 00237739.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the punching motion.
#
# [158/250] Evaluating BAD video: 00239124.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [159/250] Evaluating BAD video: 00240835.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [160/250] Evaluating BAD video: 00241350.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, which do not seem to reach full extension or flexion.
#
# [161/250] Evaluating BAD video: 00242537.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, which do not seem to reach full extension or flexion.
#
# [162/250] Evaluating BAD video: 00242916.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [163/250] Evaluating BAD video: 00243338.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the individual not moving their arms fully during the exercise.
#
# [164/250] Evaluating BAD video: 00243772.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, with the arms not extending fully during the exercise.
#
# [165/250] Evaluating BAD video: 00244303.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [166/250] Evaluating BAD video: 00244749.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, particularly in the upward and downward movements. The exercise is not being performed with a full range of motion.
#
# [167/250] Evaluating BAD video: 00244771.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [168/250] Evaluating BAD video: 00244911.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and hands in a full range of motion during the exercise.
#
# [169/250] Evaluating BAD video: 00246562.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the shoulder and arm movements, indicating that the exercise is not being performed fully.
#
# [170/250] Evaluating BAD video: 00247634.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the punching motion.
#
# [171/250] Evaluating BAD video: 00247770.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the arm movements, which do not seem to reach full extension or flexion.
#
# [172/250] Evaluating BAD video: 00248043.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the shoulder and arm movements. The person does not seem to be moving their arms fully through the intended range.
#
# [173/250] Evaluating BAD video: 00248318.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [174/250] Evaluating BAD video: 00249905.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [175/250] Evaluating BAD video: 00251566.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [176/250] Evaluating BAD video: 00251587.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range during the exercise.
#
# [177/250] Evaluating BAD video: 00251797.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [178/250] Evaluating BAD video: 00252396.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed fully.
#
# [179/250] Evaluating BAD video: 00252547.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, with the arms not extending fully during the punching motion.
#
# [180/250] Evaluating BAD video: 00252700.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not moving fully through the intended range.
#
# [181/250] Evaluating BAD video: 00252818.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the individual not extending their arms fully forward and not bending their knees deeply.
#
# [182/250] Evaluating BAD video: 00254606.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [183/250] Evaluating BAD video: 00254732.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed with full range of motion.
#
# [184/250] Evaluating BAD video: 00255064.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the shoulder and arm movements. The person does not seem to be moving their arms fully through the intended range.
#
# [185/250] Evaluating BAD video: 00256340.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements. The individual does not seem to be fully extending their arms upwards during the exercise.
#
# [186/250] Evaluating BAD video: 00256918.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward arm movements. The arms do not reach a full extension above the head.
#
# [187/250] Evaluating BAD video: 00257230.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [188/250] Evaluating BAD video: 00257237.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, particularly in the upward arm movements. The arms do not reach a full extension above the head during the exercise.
#
# [189/250] Evaluating BAD video: 00257776.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the punching motion.
#
# [190/250] Evaluating BAD video: 00258831.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, which do not reach a full extension.
#
# [191/250] Evaluating BAD video: 00259971.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward punching motion. The individual does not seem to be fully extending their arms or reaching the full height of the punch.
#
# [192/250] Evaluating BAD video: 00260041.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the punching motion.
#
# [193/250] Evaluating BAD video: 00260651.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, with the arms not extending fully during the punching motion.
#
# [194/250] Evaluating BAD video: 00263578.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [195/250] Evaluating BAD video: 00263694.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [196/250] Evaluating BAD video: 00264460.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [197/250] Evaluating BAD video: 00265695.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their legs and arms to the full extent required for an effective range of motion.
#
# [198/250] Evaluating BAD video: 00265996.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully during the exercise.
#
# [199/250] Evaluating BAD video: 00266667.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward arm movements, which do not reach a full extension.
#
# [200/250] Evaluating BAD video: 00267212.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person's range of motion appears limited, as the movements are not fully extended or retracted.
#
# [201/250] Evaluating BAD video: 00267333.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms through a full range of motion during the exercise.
#
# [202/250] Evaluating BAD video: 00267608.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and head in a full range of motion. The movements are limited and repetitive.
#
# [203/250] Evaluating BAD video: 00270060.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [204/250] Evaluating BAD video: 00270085.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The person is not moving their arms and head in a full range of motion. The movements are limited and repetitive.
#
# [205/250] Evaluating BAD video: 00272226.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully forward and the body not twisting sufficiently.
#
# [206/250] Evaluating BAD video: 00273928.mp4
# Predicted: Bad | GT: Bad | Correct: True
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements of the arms.
#
# [207/250] Evaluating BAD video: 00273970.mp4
# Predicted: Bad | GT: Bad | Correct: True
# ...
#
# [182/250] Evaluating GOOD video: 00263353.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, particularly in the lowering phase of the push-up, where the chest does not reach as close to the floor as it should.
#
# [183/250] Evaluating GOOD video: 00264956.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the push-up not going deep enough.
#
# [184/250] Evaluating GOOD video: 00265251.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's legs do not extend fully during the exercise, indicating a limited range of motion.
#
# [185/250] Evaluating GOOD video: 00265649.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion is limited, particularly in the leg movements, where the leg does not extend fully.
#
# [186/250] Evaluating GOOD video: 00266196.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the depth of the lunge and the extension of the arms.
#
# [187/250] Evaluating GOOD video: 00266206.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's range of motion appears limited, particularly in the lunges, where the depth is not sufficient.
#
# [188/250] Evaluating GOOD video: 00266254.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not fully extending their body during the push-up and bridge movements, indicating a limited range of motion.
#
# [189/250] Evaluating GOOD video: 00266289.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, which do not reach full extension.
#
# [190/250] Evaluating GOOD video: 00267425.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their body low enough to the ground during the push-up exercise, indicating a limited range of motion.
#
# [191/250] Evaluating GOOD video: 00267467.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up.
#
# [192/250] Evaluating GOOD video: 00267773.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest enough towards the floor during the push-up.
#
# [193/250] Evaluating GOOD video: 00268269.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the depth of the lunge. The front leg does not extend fully forward, and the back leg does not bend deeply enough.
#
# [194/250] Evaluating GOOD video: 00270234.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not moving their limbs to the full extent during each repetition, indicating a limited range of motion.
#
# [195/250] Evaluating GOOD video: 00270405.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion is limited, particularly in the downward phase of the push-up, where the chest does not reach close enough to the floor.
#
# [196/250] Evaluating GOOD video: 00271463.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the push-up not going deep enough.
#
# [197/250] Evaluating GOOD video: 00271516.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, particularly in the depth of the stretch and the height of the arm movements.
#
# [198/250] Evaluating GOOD video: 00271895.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up, indicating a limited range of motion.
#
# [199/250] Evaluating GOOD video: 00272644.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest enough towards the floor during the push-up, indicating a limited range of motion.
#
# [200/250] Evaluating GOOD video: 00272748.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the push-up not going deep enough.
#
# [201/250] Evaluating GOOD video: 00273123.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the depth of the lunge. The individual does not extend their front leg far enough, and the back leg does not bend deeply enough, which could reduce the effectiveness of the exercise.
#
# [202/250] Evaluating GOOD video: 00273149.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up.
#
# [203/250] Evaluating GOOD video: 00274424.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the chest not lowering close enough to the floor during the push-up movement.
#
# [204/250] Evaluating GOOD video: 00274677.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, as the leg does not move fully up and down during the exercise.
#
# [205/250] Evaluating GOOD video: 00275570.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up, indicating a limited range of motion.
#
# [206/250] Evaluating GOOD video: 00275587.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the downward and upward movements, indicating that the exercise is not being performed fully.
#
# [207/250] Evaluating GOOD video: 00275781.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's range of motion appears to be limited, particularly in the upward and downward movements. The arms do not reach the maximum height, and the legs do not extend fully, indicating a restricted range of motion.
#
# [208/250] Evaluating GOOD video: 00275903.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not fully extending their arms and legs during the exercise, which limits the range of motion.
#
# [209/250] Evaluating GOOD video: 00276041.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the legs not extending fully during the exercise.
#
# [210/250] Evaluating GOOD video: 00276348.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up, indicating a limited range of motion.
#
# [211/250] Evaluating GOOD video: 00276540.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up, indicating a limited range of motion.
#
# [212/250] Evaluating GOOD video: 00277376.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the chest not lowering fully towards the floor during the push-up repetitions.
#
# [213/250] Evaluating GOOD video: 00277589.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the push-up not going deep enough.
#
# [214/250] Evaluating GOOD video: 00277701.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not lowering their chest close to the floor during the push-up.
#
# [215/250] Evaluating GOOD video: 00278129.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the chest not lowering fully towards the floor during the push-up.
#
# [216/250] Evaluating GOOD video: 00278776.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the downward phase of the push-up, where the chest does not reach close enough to the floor.
#
# [217/250] Evaluating GOOD video: 00279843.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not lowering their chest close enough to the floor during the push-up.
#
# [218/250] Evaluating GOOD video: 00281516.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the squatting and lunging movements, indicating that the exercise is not being performed with full range of motion.
#
# [219/250] Evaluating GOOD video: 00282164.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not moving their legs up and down enough to achieve a full range of motion for the exercise.
#
# [220/250] Evaluating GOOD video: 00282216.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the leg movements, indicating that the exercise is not being performed fully.
#
# [221/250] Evaluating GOOD video: 00282491.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not lowering their body fully during the push-up movement.
#
# [222/250] Evaluating GOOD video: 00282706.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not moving their legs up and down enough to achieve a full range of motion for the exercise.
#
# [223/250] Evaluating GOOD video: 00282844.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the legs not extending fully during the exercise.
#
# [224/250] Evaluating GOOD video: 00283081.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not lowering their chest close enough to the floor during the push-up, indicating a limited range of motion.
#
# [225/250] Evaluating GOOD video: 00283238.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the leg not extending fully during the exercise.
#
# [226/250] Evaluating GOOD video: 00283617.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the movement of the legs, which do not extend fully during the exercise.
#
# [227/250] Evaluating GOOD video: 00283806.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the legs not extending fully during the exercise.
#
# [228/250] Evaluating GOOD video: 00283978.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the push-up not going deep enough.
#
# [229/250] Evaluating GOOD video: 00284120.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the legs not extending fully during the exercise.
#
# [230/250] Evaluating GOOD video: 00284344.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's arms are not moving fully in the exercise, indicating a limited range of motion.
#
# [231/250] Evaluating GOOD video: 00284358.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not fully extending their arms or lowering themselves deeply enough during the push-up repetitions.
#
# [232/250] Evaluating GOOD video: 00284371.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not lowering their body fully during the push-up movement.
#
# [233/250] Evaluating GOOD video: 00284946.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, where the arm does not extend fully upwards.
#
# [234/250] Evaluating GOOD video: 00285428.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person's range of motion appears limited, particularly in the upward arm movements, indicating that the exercise is not being performed with full range of motion.
#
# [235/250] Evaluating GOOD video: 00285478.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the arm movements, as the arms do not reach full extension upwards or outwards.
#
# [236/250] Evaluating GOOD video: 00286035.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not fully extending their body during the push-up movement.
#
# [237/250] Evaluating GOOD video: 00286145.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not extending their leg fully during the side lunges, which limits the range of motion.
#
# [238/250] Evaluating GOOD video: 00287722.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not extending their body fully during the push-up repetitions, indicating a limited range of motion.
#
# [239/250] Evaluating GOOD video: 00288702.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, particularly in the depth of the squat and the extension of the arms during the push-up.
#
# [240/250] Evaluating GOOD video: 00289343.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, particularly in the upward leg movement, which is not reaching a full extension.
#
# [241/250] Evaluating GOOD video: 00289570.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The person is not fully extending their arms and legs during the exercise, indicating a limited range of motion.
#
# [242/250] Evaluating GOOD video: 00291183.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the arms not extending fully upwards and the jumps not reaching significant height.
#
# [243/250] Evaluating GOOD video: 00291624.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the depth of the lunge. The individual does not achieve full extension in the front leg and the back leg does not reach a deep enough position.
#
# [244/250] Evaluating GOOD video: 00292854.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the person not fully extending their arms and legs during the push-up movement.
#
# [245/250] Evaluating GOOD video: 00293326.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion is limited, particularly in the upward arm movement, which does not reach a full extension.
#
# [246/250] Evaluating GOOD video: 00293371.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the depth of the lunge. The individual does not achieve full extension in the front leg and the back leg does not reach a parallel position to the floor.
#
# [247/250] Evaluating GOOD video: 00293420.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the elevation of the knee. The knee does not reach a high enough position relative to the hip during the exercise.
#
# [248/250] Evaluating GOOD video: 00295266.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
#
# [249/250] Evaluating GOOD video: 00296500.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears to be limited, with the leg not extending fully during the exercise.
#
# [250/250] Evaluating GOOD video: 00297658.mp4
# Predicted: Bad | GT: Good | Correct: False
# Explanation: 2. The range of motion appears limited, particularly in the upward and downward movements, indicating that the exercise is not being performed fully.
